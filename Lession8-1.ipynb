# %% [markdown]
# # <center>Python课程实践--Gensim</center>

# %% [markdown]
# ## 课程内容
#
# * 1.Gensim简介
# * 2.词袋模型
# * 3.主题模型
# * 4.词向量模型
# * 5.文档向量模型
# * 6.案例实践

# %% [markdown]
# ## 1.Gensim简介

# %% [markdown]
# ### 1.1 常用自然语言处理工具
# 自然语言处理（NLP）如今越来越流行，在深度学习开发的背景下变得尤为引人注目。在人工智能领域中，自然语言处理（NLP）从文本中理解和提取重要信息，并基于文本数据进行进一步的数据训练，其主要任务包括语音识别和生成、文本分析、情感分析、机器翻译等。
#
# * NLTK（Python自然语言工具包）用于诸如标记化、词形还原、词干化、解析、POS标注等任务。该库具有几乎所有NLP任务的工具。
#
# * Spacy是NLTK的主要竞争对手。这两个库可用于相同的任务。
#
# * Scikit-learn为机器学习提供了一个大型库。此外还提供了用于文本预处理的工具。
#
# * **Gensim**是一个主题和向量空间建模、文档集合相似性的工具包。
#
# * Pattern库的一般任务是充当Web挖掘模块。因此，它仅支持自然语言处理（NLP）作为辅助任务。
#
# * Polyglot是自然语言处理（NLP）的另一个Python工具包。它不是很受欢迎，但也可以用于各种NLP任务。

# %% [markdown]
# ### 1.2 Gensim主要功能
# 作为自然语言处理爱好者，大家都应该听说过或使用过大名鼎鼎的Gensim吧，这是一款具备多种功能的神器。
#
# Gensim是一款开源的第三方Python工具包，用于从原始的非结构化的文本中，无监督地学习到文本隐层的主题向量表达。
#
# 它支持包括TF-IDF，LSA，LDA，和word2vec在内的多种主题模型算法，支持流式训练，并提供了诸如相似度计算，信息检索等一些常用任务的API接口。

# %% [markdown]
# #### 基本概念
#
# * 语料（Corpus）：一组原始文本的集合，用于无监督地训练文本主题的隐层结构。语料中不需要人工标注的附加信息。在Gensim中，Corpus通常是一个可迭代的对象（比如列表）。每一次迭代返回一个可用于表达文本对象的稀疏向量。
#
# * 向量（Vector）：由一组文本特征构成的列表。是一段文本在Gensim中的内部表达。
#
# * 稀疏向量（SparseVector）：通常，我们可以略去向量中多余的0元素。此时，向量中的每一个元素是一个(key, value)的元组
#
# * 模型（Model）：是一个抽象的术语。定义了两个向量空间的变换（即从文本的一种向量表达变换为另一种向量表达）。

# %% [markdown]
# ## 2.词袋模型
#
# ![](images/wordbag.png)

# %% [markdown]
# ### 2.1 语料预处理
# 这一次，让我们从表示为字符串的文档开始：

# %%
from gensim import corpora
documents = ["Human machine interface for lab abc computer applications",
             "A survey of user opinion of computer system response time",
             "The EPS user interface management system",
             "System and human system engineering testing of EPS",
             "Relation of user perceived response time to error measurement",
             "The generation of random binary unordered trees",
             "The intersection graph of paths in trees",
             "Graph minors IV Widths of trees and well quasi ordering",
             "Graph minors A survey"]

# %% [markdown]
# 这是一个由九个文档组成的小型语料库，每个文档只包含一个句子。
#
# 首先，让我们对文档进行标记，删除常用单词（使用停止词列表）以及仅在语料库中出现一次的单词：

# %%
# remove common words and tokenize
stoplist = set('for a of the and to in'.split()) #常用词列表
texts = [[word for word in document.lower().split() if word not in stoplist] #删除常用单词（使用停止词列表）
         for document in documents]
print(stoplist)
print(texts)
# Out:
# {'for', 'to', 'in', 'a', 'and', 'of', 'the'}
# [['human', 'machine', 'interface', 'lab', 'abc', 'computer', 'applications'], ['survey', 'user', 'opinion', 'computer', 'system', 'response', 'time'], ['eps', 'user', 'interface', 'management', 'system'], ['system', 'human', 'system', 'engineering', 'testing', 'eps'], ['relation', 'user', 'perceived', 'response', 'time', 'error', 'measurement'], ['generation', 'random', 'binary', 'unordered', 'trees'], ['intersection', 'graph', 'paths', 'trees'], ['graph', 'minors', 'iv', 'widths', 'trees', 'well', 'quasi', 'ordering'], ['graph', 'minors', 'survey']]

# %%
stoplist
# Out:
# {'a', 'and', 'for', 'in', 'of', 'the', 'to'}

# %%
texts
# Out:
# [['human', 'machine', 'interface', 'lab', 'abc', 'computer', 'applications'],
#  ['survey', 'user', 'opinion', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'management', 'system'],
#  ['system', 'human', 'system', 'engineering', 'testing', 'eps'],
#  ['relation', 'user', 'perceived', 'response', 'time', 'error', 'measurement'],
#  ['generation', 'random', 'binary', 'unordered', 'trees'],
#  ['intersection', 'graph', 'paths', 'trees'],
#  ['graph', 'minors', 'iv', 'widths', 'trees', 'well', 'quasi', 'ordering'],
#  ['graph', 'minors', 'survey']]

# %%
# remove words that appear only once
from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [[token for token in text if frequency[token] > 1]#删除仅在语料库中出现一次的单词
         for text in texts]
texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %%
from pprint import pprint  # pretty-printer
pprint(texts)
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %% [markdown]
# ### 2.2 词袋模型
# 要将文档转换为向量，我们将使用名为bag-of-words的文档表示 。在此表示中，每个文档由一个向量表示，其中每个向量元素表示问题 - 答案对，仅通过它们的（整数）id来表示问题是有利的。问题和ID之间的映射称为字典：

# %%
dictionary = corpora.Dictionary(texts) #创建一个映射字典
dictionary.save('tmp/deerwester.dict')  # store the dictionary, for future reference
print(dictionary)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...)

# %%
dictionary

# %% [markdown]
# 在这里，我们为语料库中出现的所有单词分配了一个唯一的整数id gensim.corpora.dictionary.Dictionary。这会扫描文本，收集字数和相关统计数据。最后，我们看到在处理过的语料库中有12个不同的单词，这意味着每个文档将由12个数字表示（即，通过12-D向量）。要查看单词及其ID之间的映射：

# %%
print(dictionary.token2id)
# Out:
# {'computer': 0, 'human': 1, 'interface': 2, 'response': 3, 'survey': 4, 'system': 5, 'time': 6, 'user': 7, 'eps': 8, 'trees': 9, 'graph': 10, 'minors': 11}

# %% [markdown]
# 要将标记化文档实际转换为向量：

# %%
new_doc = "Human computer interaction"
new_vec = dictionary.doc2bow(new_doc.lower().split())  #使用我们刚构造的字典来进行编码
print(new_vec)
# Out:
# [(0, 1), (1, 1)]

# %% [markdown]
# 该函数doc2bow()只计算每个不同单词的出现次数，将单词转换为整数单词id，并将结果作为稀疏向量返回。 因此，稀疏向量 [(0, 1), (1, 1)] 读取：在文档“人机交互”中，单词computer （id 0）和human（id 1）出现一次; 其他十个字典单词（隐含地）出现零次。

# %%
print(texts)
corpus = [dictionary.doc2bow(text) for text in texts]
corpora.MmCorpus.serialize('tmp/deerwester.mm', corpus)  # store to disk, for later use
print(corpus)
# Out:
# [['human', 'interface', 'computer'], ['survey', 'user', 'computer', 'system', 'response', 'time'], ['eps', 'user', 'interface', 'system'], ['system', 'human', 'system', 'eps'], ['user', 'response', 'time'], ['trees'], ['graph', 'trees'], ['graph', 'minors', 'trees'], ['graph', 'minors', 'survey']]
# [[(0, 1), (1, 1), (2, 1)], [(0, 1), (3, 1), (4, 1), (5, 1), (6, 1), (7, 1)], [(2, 1), (5, 1), (7, 1), (8, 1)], [(1, 1), (5, 2), (8, 1)], [(3, 1), (6, 1), (7, 1)], [(9, 1)], [(9, 1), (10, 1)], [(9, 1), (10, 1), (11, 1)], [(4, 1), (10, 1), (11, 1)]]

# %% [markdown]
# ## 3.主题模型
#
# 对文本向量的变换是Gensim的核心。通过挖掘语料中隐藏的语义结构特征，我们最终可以变换出一个简洁高效的文本向量。

# %% [markdown]
# ### 3.1 TF-IDF模型
#
# 在Gensim中，每一个向量变换的操作都对应着一个主题模型，例如上一小节提到的对应着词袋模型的doc2bow变换。每一个模型又都是一个标准的Python对象。下面以TF-IDF模型为例，介绍Gensim模型的一般使用方法。
#
# 首先是模型对象的初始化。通常，Gensim模型都接受一段训练语料（注意在Gensim中，语料对应着一个稀疏向量的迭代器）作为初始化的参数。显然，越复杂的模型需要配置的参数越多。

# %%
# 创建转换
from gensim import models
tfidf = models.TfidfModel(corpus)

# %% [markdown]
# 其中，corpus是一个返回bow向量的迭代器。这两行代码将完成对corpus中出现的每一个特征的IDF值的统计工作。
#
# 接下来，我们可以调用这个模型将任意一段语料（依然是bow向量的迭代器）转化成TFIDF向量（的迭代器）。需要注意的是，这里的bow向量必须与训练语料的bow向量共享同一个特征字典（即共享同一个向量空间）。
#
#
# TF-IDF用以评估一字词对于一个文件集或一个语料库中的其中一份文件的重要程度。字词的重要性随着它在文件中出现的次数成正比增加，但同时会随着它在语料库中出现的频率成反比下降。
#
# TF:词频，指的是某一个给定的词语在该文件中出现的频率
#
# IDF:倒文档词频，是一个词语普遍重要性的度量，可以由总文件数目除以包含该词语之文件的数目，再将得到的商取对数得到。
#
# 挑选文档的特征词：某一特定文件内的高词语频率，以及该词语在整个文件集合中的低文件频率，可以产生出高权重的TF-IDF。
#
# TF-IDE=TF*IDF

# %%
# 变换向量
doc_bow = [(0, 1), (1, 1)]
print(tfidf[doc_bow]) # step 2 -- use the model to transform vectors
#输出每个词 在这个文档中重要性
# Out:
# [(0, 0.7071067811865476), (1, 0.7071067811865476)]

# %%
# 或者将转换应用于整个语料库：
corpus_tfidf = tfidf[corpus]
for doc in corpus_tfidf:
    print(doc)
# Out:
# [(0, 0.5773502691896257), (1, 0.5773502691896257), (2, 0.5773502691896257)]
# [(0, 0.44424552527467476), (3, 0.44424552527467476), (4, 0.44424552527467476), (5, 0.3244870206138555), (6, 0.44424552527467476), (7, 0.3244870206138555)]
# [(2, 0.5710059809418182), (5, 0.4170757362022777), (7, 0.4170757362022777), (8, 0.5710059809418182)]
# [(1, 0.49182558987264147), (5, 0.7184811607083769), (8, 0.49182558987264147)]
# [(3, 0.6282580468670046), (6, 0.6282580468670046), (7, 0.45889394536615247)]
# [(9, 1.0)]
# [(9, 0.7071067811865475), (10, 0.7071067811865475)]
# [(9, 0.5080429008916749), (10, 0.5080429008916749), (11, 0.695546419520037)]
# [(4, 0.6282580468670046), (10, 0.45889394536615247), (11, 0.6282580468670046)]

# %%
# 可以将训练好的模型持久化到磁盘上，以便下一次使用：
tfidf.save("tmp/model.tfidf")
new_tfidf = models.TfidfModel.load("tmp/model.tfidf")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# ### 3.2 LSA模型
#
# 词袋模型有几个明显的缺点：
#
# * 稀疏性(Sparseness)：对于大词袋，尤其是包含了生僻字的词袋，文档稀疏性不可避免。
# * 一词多义：一词多义是一种常见的现象，但是BOW模型只统计单词出现的次数，而忽略了他们之间的区别；
# * 多词一义：在不同或相同文档中，可能存在多种单词存在同一个意思。
#
# 为了解决同义词以及文档稀疏性的问题，在BOW模型中引入“主题”的概念，提出了潜在语义分析LSA(Latent semantic analysis)模型，，其通过“矢量语义空间”来提取文档与词中的“概念”，进而分析文档与词之间的关系。LSA的基本假设是，如果两个词多次出现在同一文档中，则这两个词在语义上具有相似性。LSA使用大量的文本上构建一个矩阵，这个矩阵的一行代表一个词，一列代表一个文档，矩阵元素代表该词在该文档中出现的次数，然后再此矩阵上使用奇异值分解（SVD）来保留列信息的情况下减少矩阵行数，之后每两个词语的相似性则可以通过其行向量的cos值（或者归一化之后使用向量点乘）来进行标示，此值越接近于1则说明两个词语越相似，越接近于0则说明越不相似。

# %%
lsi = models.LsiModel(corpus=corpus, id2word=dictionary, num_topics=5)
lsi

# %%
# 变换向量
doc_bow = [(0, 1), (1, 1)]
print(lsi[doc_bow]) # step 2 -- use the model to transform vectors
#输出每个词 在这个文档中重要性
# Out:
# [(0, 0.4618210045327158), (1, 0.07002766527899965), (2, -0.12452907551899137), (3, 1.0097125584438555), (4, -0.2130304060562643)]

# %%
# 或者将转换应用于整个语料库：
corpus_lsi = lsi[corpus]
for doc in corpus_lsi:
    print(doc)
# Out:
# [(0, 0.6594664059797395), (1, 0.14211544403729823), (2, -0.259568714208422), (3, 1.561952142099365), (4, 0.06873853289228224)]
# [(0, 2.024543043382876), (1, -0.4208875824630211), (2, 1.1706784758367), (3, 0.04711403946278517), (4, -0.3104877971509376)]
# [(0, 1.5465535813286544), (1, 0.3235891942571181), (2, -0.4886926871430969), (3, -0.06842766506520662), (4, 0.5693322998862521)]
# [(0, 1.8111412473028827), (1, 0.589052496993243), (2, -1.3415628918291795), (3, -0.44026438019664316), (4, -0.3094004567039055)]
# [(0, 0.9336738035634353), (1, -0.2713894049937495), (2, 1.189800531276366), (3, -0.24673811387727104), (4, 0.4923724704004483)]
# [(0, 0.012746183038294471), (1, -0.490161792453105), (2, -0.231120154886051), (3, -0.02480199852746337), (4, 0.5941695155888926)]
# [(0, 0.04888203206047028), (1, -1.112947026992956), (2, -0.45420651747622043), (3, -0.025502070648909945), (4, 0.5259165773893245)]
# [(0, 0.08063836099410607), (1, -1.5634559463442665), (2, -0.5953216813655241), (3, -0.016772600038339067), (4, 0.2254214673588512)]
# [(0, 0.2738100392127568), (1, -1.34694158495377), (2, -0.1866045094072548), (3, 0.04038133511331627), (4, -0.9058980515363366)]

# %%
# 可以将训练好的模型持久化到磁盘上，以便下一次使用：
lsi.save("tmp/model.lsi")
new_lsi = models.LsiModel.load("tmp/model.lsi")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# ### 3.3 LDA模型
# 人类是怎么生成文档的呢？
#
# 比如假设事先给定了这几个主题：Arts、Budgets、Children、Education，然后通过学习训练，获取每个主题Topic对应的词语。如下图所示：
# ![](images/lda2.jpg)
#
# 然后以一定的概率选取上述某个主题，再以一定的概率选取那个主题下的某个单词，不断的重复这两步，最终生成如下图所示的一篇文章（其中不同颜色的词语分别对应上图中不同主题下的词）
# ![](images/lda1.jpg)

# %%
lda = models.LdaModel(corpus=corpus, id2word=dictionary, num_topics=20)
print(corpus)
# Out:
# MmCorpus(9 documents, 12 features, 28 non-zero entries)

# %%
print(dictionary)
# Out:
# Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...)

# %%
# 变换向量
doc_bow = [(0, 1), (1, 1)]
print(lda[doc_bow]) # step 2 -- use the model to transform vectors
#输出每个词 在这个文档中重要性
# Out:
# [(0, 0.016666677), (1, 0.016666677), (2, 0.016666677), (3, 0.016666677), (4, 0.016666677), (5, 0.016666677), (6, 0.016666677), (7, 0.016666677), (8, 0.016666677), (9, 0.016666677), (10, 0.016666677), (11, 0.016666677), (12, 0.6833331), (13, 0.016666677), (14, 0.016666677), (15, 0.016666677), (16, 0.016666677), (17, 0.016666677), (18, 0.016666677), (19, 0.016666677)]

# %%
# 或者将转换应用于整个语料库：
corpus_lda = lda[corpus]
for doc in corpus_lda:
    print(doc)
# Out:
# [(0, 0.012500009), (1, 0.012500009), (2, 0.012500009), (3, 0.012500009), (4, 0.012500009), (5, 0.012500009), (6, 0.012500009), (7, 0.012500009), (8, 0.012500009), (9, 0.012500009), (10, 0.012500009), (11, 0.012500009), (12, 0.7624998), (13, 0.012500009), (14, 0.012500009), (15, 0.012500009), (16, 0.012500009), (17, 0.012500009), (18, 0.012500009), (19, 0.012500009)]
# [(15, 0.8642855)]
# [(0, 0.010000009), (1, 0.010000009), (2, 0.010000009), (3, 0.010000009), (4, 0.010000009), (5, 0.010000009), (6, 0.010000009), (7, 0.010000009), (8, 0.010000009), (9, 0.010000009), (10, 0.010000009), (11, 0.010000009), (12, 0.010000009), (13, 0.010000009), (14, 0.010000009), (15, 0.010000009), (16, 0.010000009), (17, 0.8099999), (18, 0.010000009), (19, 0.010000009)]
# [(0, 0.010000013), (1, 0.010000013), (2, 0.010000013), (3, 0.010000013), (4, 0.010000013), (5, 0.010000013), (6, 0.010000013), (7, 0.010000013), (8, 0.010000013), (9, 0.010000013), (10, 0.010000013), (11, 0.010000013), (12, 0.010000013), (13, 0.010000013), (14, 0.010000013), (15, 0.8099998), (16, 0.010000013), (17, 0.010000013), (18, 0.010000013), (19, 0.010000013)]
# [(0, 0.012500009), (1, 0.012500009), (2, 0.012500009), (3, 0.012500009), (4, 0.7624998), (5, 0.012500009), (6, 0.012500009), (7, 0.012500009), (8, 0.012500009), (9, 0.012500009), (10, 0.012500009), (11, 0.012500009), (12, 0.012500009), (13, 0.012500009), (14, 0.012500009), (15, 0.012500009), (16, 0.012500009), (17, 0.012500009), (18, 0.012500009), (19, 0.012500009)]
# [(0, 0.52499986), (1, 0.025000006), (2, 0.025000006), (3, 0.025000006), (4, 0.025000006), (5, 0.025000006), (6, 0.025000006), (7, 0.025000006), (8, 0.025000006), (9, 0.025000006), (10, 0.025000006), (11, 0.025000006), (12, 0.025000006), (13, 0.025000006), (14, 0.025000006), (15, 0.025000006), (16, 0.025000006), (17, 0.025000006), (18, 0.025000006), (19, 0.025000006)]
# [(0, 0.016666677), (1, 0.016666675), (2, 0.016666675), (3, 0.016666675), (4, 0.016666675), (5, 0.016666675), (6, 0.016666675), (7, 0.016666675), (8, 0.016666675), (9, 0.016666675), (10, 0.016666675), (11, 0.016666675), (12, 0.016666675), (13, 0.016666675), (14, 0.016666675), (15, 0.016666675), (16, 0.016666675), (17, 0.016666675), (18, 0.68333316), (19, 0.016666675)]
# [(0, 0.012500008), (1, 0.76249987), (2, 0.012500008), (3, 0.012500008), (4, 0.012500008), (5, 0.012500008), (6, 0.012500008), (7, 0.012500008), (8, 0.012500008), (9, 0.012500008), (10, 0.012500008), (11, 0.012500008), (12, 0.012500008), (13, 0.012500008), (14, 0.012500008), (15, 0.012500008), (16, 0.012500008), (17, 0.012500008), (18, 0.012500008), (19, 0.012500008)]
# [(0, 0.012500009), (1, 0.012500009), (2, 0.012500009), (3, 0.7624998), (4, 0.012500009), (5, 0.012500009), (6, 0.012500009), (7, 0.012500009), (8, 0.012500009), (9, 0.012500009), (10, 0.012500009), (11, 0.012500009), (12, 0.012500009), (13, 0.012500009), (14, 0.012500009), (15, 0.012500009), (16, 0.012500009), (17, 0.012500009), (18, 0.012500009), (19, 0.012500009)]

# %%
# 可以将训练好的模型持久化到磁盘上，以便下一次使用：
lda.save("tmp/model.lda")
new_lda = models.LdaModel.load("tmp/model.lda")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# ### 3.4 文档相似度的计算
# 在得到每一篇文档对应的主题向量后，我们就可以计算文档之间的相似度，进而完成如文本聚类、信息检索之类的任务。在Gensim中，也提供了这一类任务的API接口。
#
# 以信息检索为例。对于一篇待检索的query，我们的目标是从文本集合中检索出主题相似度最高的文档。
#
# 首先，我们需要将待检索的query和文本放在同一个向量空间里进行表达（以LSI向量空间为例）：

# %%
from gensim import corpora, models, similarities
dictionary = corpora.Dictionary.load('tmp/deerwester.dict')
corpus = corpora.MmCorpus('tmp/deerwester.mm') # comes from the first tutorial, "From strings to vectors"
print(corpus)
# Out:
# MmCorpus(9 documents, 12 features, 28 non-zero entries)

# %%
# 定义一个二维LSI空间：
new_lsi = models.LsiModel.load("tmp/model.lsi")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
doc = "Human computer interaction"
vec_bow = dictionary.doc2bow(doc.lower().split())
vec_lsi = new_lsi[vec_bow] # convert the query to LSI space
print(vec_lsi)
# Out:
# [(0, 0.4618210045327158), (1, 0.07002766527899965), (2, -0.12452907551899137), (3, 1.0097125584438555), (4, -0.2130304060562643)]

# %%
# 初始化查询
index = similarities.MatrixSimilarity(new_lsi[corpus])

# %% [markdown]
# * similarities.MatrixSimilarity只有当整个向量集适合内存时，该类才适用。例如，当与此类一起使用时，一百万个文档的语料库在256维LSI空间中将需要2GB的RAM。
# * 如果没有2GB的可用RAM，则需要使用similarities.Similarity该类。此类通过在磁盘上的多个文件（称为分片）之间拆分索引，在固定内存中运行。它使用similarities.MatrixSimilarity和similarities.SparseMatrixSimilarity内部，所以它仍然很快，虽然稍微复杂一点。

# %%
# 要获得我们的查询文档与九个索引文档的相似性：
sims = index[vec_lsi] # perform a similarity query against the corpus
print(list(enumerate(sims))) # print (document_number, document_similarity) 2-tuples

#余弦测量返回范围中的相似度（越大，越相似）
# Out:
# [(0, 0.9727242), (1, 0.31977737), (2, 0.30448094), (3, 0.24447846), (4, -0.048387423), (5, -0.16497497), (6, -0.09127022), (7, -0.03274583), (8, 0.15309833)]

# %%
# 将这些相似性按降序排序，并获得查询 人机交互 的最终答案：
sims = sorted(enumerate(sims), key=lambda item: -item[1])
print(sims) # print sorted (document number, similarity score) 2-tuples
# Out:
# [(0, 0.9727242), (1, 0.31977737), (2, 0.30448094), (3, 0.24447846), (8, 0.15309833), (7, -0.03274583), (4, -0.048387423), (6, -0.09127022), (5, -0.16497497)]

# %% [markdown]
# ## 4.词向量模型

# %% [markdown]
# ### 4.1 词向量简介
#
# 词向量指的是一个词的向量表示。如果你希望计算机能够进行一些复杂点的文本语义学习，你必须得将文本数据编码成计算机能够处理的数值向量吧，所以词向量是一个自然语言处理任务中非常重要的一环。
#
# 如何得到上述具有语义Distributional  representations的词向量呢，2013年提出的word2vec的方法就是一种非常方便得到高质量词向量的方式。其主要思想是：一个词的上下文可以很好的表达出词的语义，它是一种通过无监督的学习文本来用产生词向量的方式。
#
# 100+ Chinese Word Vectors 上百种预训练中文词向量
# https://github.com/Embedding/Chinese-Word-Vectors

# %%
from gensim import models
new_model = models.KeyedVectors.load_word2vec_format('tmp/zhwiki_2017_03.sg_50d.word2vec',binary=False)  #sgns.wiki.bigram-char

# %%
print(new_model['软件'])
# Out:
# [-0.36093   0.105888  0.388663 -0.117126  0.106318  0.350478 -0.081701
#  -0.059811  0.847456  0.848872  0.607633 -1.150333  0.781525  0.037457
#   0.047236 -0.458902  0.412925  0.163321 -0.007959  0.23333  -0.416148
#  -0.441578 -0.828599 -0.003355  0.536412 -0.288777 -0.007912 -0.116614
#   0.749254 -0.453145 -0.368196  0.273862 -0.859477  0.776925 -0.229281
#   0.532504 -0.775858  0.08166  -0.160816 -0.441611  0.156932  0.493826
#   0.572834 -0.218519 -0.174441 -0.153281 -0.239637 -0.185816 -0.013873
#  -0.146506]

# %%
# 得到与一个词最相关的若干词及相似程度
print(new_model.similar_by_word('北京'), 10)
# Out:
# [('上海', 0.85248863697052), ('广州', 0.8133988380432129), ('南京', 0.8087798953056335), ('沈阳', 0.8043987154960632), ('长春', 0.7917946577072144), ('哈尔滨', 0.7850497364997864), ('杭州', 0.7794261574745178), ('济南', 0.7794216871261597), ('福寿园', 0.7779054045677185), ('潞河', 0.7772673964500427)] 10

# %%
print(new_model.similar_by_word('王敬'), 10)
# Out:
# [('张亮', 0.8167524337768555), ('郭丹', 0.800384521484375), ('颜高', 0.7938944101333618), ('朱俊', 0.7935847043991089), ('王成', 0.7926192879676819), ('瑕', 0.7872204184532166), ('李云', 0.7860795855522156), ('王亮', 0.7809092998504639), ('张雕', 0.7777642011642456), ('又击', 0.7747111320495605)] 10

# %%
new_model.similar_by_word('Python')
# Out:
# [('Tcl', 0.9650475978851318),
#  ('Java', 0.9643802642822266),
#  ('Perl', 0.9631242752075195),
#  ('Lua', 0.9580066800117493),
#  ('C#', 0.9556556940078735),
#  ('java', 0.9553079605102539),
#  ('脚本语言', 0.9521129131317139),
#  ('C语言', 0.9500064849853516),
#  ('程式库', 0.947653591632843),
#  ('JavaScript', 0.9476410150527954)]

# %%
# 得到两组词的相似度
list1 = [u'核能']
list2 = [u'电能']
list3 = [u'电力']
list_sim1 =  new_model.n_similarity(list1, list2)
print(list_sim1)
list_sim2 = new_model.n_similarity(list2, list3)
print(list_sim2)
# Out:
# 0.59094995
# 0.83814484

# %%
y2 = new_model.wv.similarity(u"时期", u"种类")
print(y2)
# Out:
# 0.23437281
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.

# %%
for i in new_model.wv.most_similar(u"戏剧"):
    print (i[0],i[1])
# Out:
# 话剧 0.8621609807014465
# 舞台剧 0.8580252528190613
# 表演艺术 0.8423406481742859
# 舞台艺术 0.8419910073280334
# 戏曲 0.8403540849685669
# 音乐剧 0.8395066857337952
# 编导 0.8327195644378662
# 喜剧 0.8309129476547241
# 儿童剧 0.8290919065475464
# 剧作 0.8268210291862488
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.

# %%
# 得到一组词中最无关的词
list4 = [u'汽车', u'火车', u'飞机', u'北京']
print(new_model.doesnt_match(list4))
# Out:
# 北京
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\keyedvectors.py:858: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %% [markdown]
# #### 词语的加减游戏
# 英文词类比中最有名的一个例子大概就是: king - man + woman = queen
#
# 当我把这个例子换成中文映射到腾讯的中文词向量中并且用gensim来计算，竟然能完美复现：国王 - 男人 + 女人 = 王后

# %%
new_model.most_similar(positive=[u'国王', '女人'], negative=[u'男人'])
# Out:
# [('三世', 0.9416244029998779),
#  ('一世', 0.9366082549095154),
#  ('二世', 0.9362475872039795),
#  ('四世', 0.9269468784332275),
#  ('五世', 0.9181405305862427),
#  ('六世', 0.9168587923049927),
#  ('王位', 0.914807915687561),
#  ('王室', 0.9138323068618774),
#  ('七世', 0.9131208658218384),
#  ('王路易', 0.9111517667770386)]

# %%
new_model.most_similar(positive=[u'皇帝', '女人'], negative=[u'男人'])
# Out:
# [('登基', 0.8970834016799927),
#  ('王太子', 0.8666362762451172),
#  ('储君', 0.8532828688621521),
#  ('新君', 0.8518441319465637),
#  ('尊号', 0.8511227369308472),
#  ('继位', 0.8454713821411133),
#  ('废黜', 0.845383882522583),
#  ('即位', 0.8407121896743774),
#  ('帝号', 0.839134693145752),
#  ('死后', 0.8382000923156738)]

# %%
new_model.most_similar(positive=[u'老婆', '妻子'], negative=[u'老公'])
# Out:
# [('女儿', 0.916805624961853),
#  ('丈夫', 0.9024686813354492),
#  ('母亲', 0.9016439914703369),
#  ('父亲', 0.8894546627998352),
#  ('儿子', 0.8886772394180298),
#  ('哥哥', 0.886040449142456),
#  ('小儿子', 0.8813856840133667),
#  ('叔叔', 0.8799700736999512),
#  ('小女儿', 0.8782185316085815),
#  ('舅舅', 0.8779697418212891)]

# %% [markdown]
# 然后把国王换成皇帝，将输出什么？
# ```
# 机场-飞机+火车
# 老婆-老公+丈夫
# 北京-中国+法国
# 上海-中国+美国
# 小龙女-杨过+郭靖
# 汽车-轮胎+翅膀
# ```

# %% [markdown]
# ### 4.2 训练词向量
#
# word2vec中有两个非常经典的模型：skip-gram和cbow。
#
# * skip-gram：已知中心词预测周围词。
# * cbow：已知周围词预测中心词。
#
# 比如 "the quick brown fox jumps over the lazy dog" 如果定义window-size为2的话，就会产生如下图所示的数据集，window-size决定了目标词会与多远距离的上下文产生关系：
#
# ```
# Skip-Gram:(the,quick) ,其中the 是模型的输入，quick是模型的输出。
# Cbow： ((quick,brown),the) ,其中 （quick，brown）是模型的输入，the是模型的输出。
# ```
# ![](images/word2vec.png)

# %% [markdown]
# 使用word2vec.Word2Vec这个API的来训练词向量，参数说明如下
# ```
# size: 表示词向量的维度，默认值是100。
# window：决定了目标词会与多远距离的上下文产生关系，默认值是5。
# sg: 如果是0， 则是CBOW模型，是1则是Skip-Gram模型，默认是0即CBOW模型。
# ```
# 采用CBOW模型——通过周围词预测中心词的方式训练词向量。

# %%
import os
fpath = 'data/IT'
flist = os.listdir(fpath)
flist
# Out:
# ['IT_10.txt',
#  'IT_100.txt',
#  'IT_1000.txt',
#  'IT_1010.txt',
#  'IT_1020.txt',
#  'IT_1030.txt',
#  'IT_1040.txt',
#  'IT_1050.txt',
#  'IT_1060.txt',
#  'IT_1070.txt',
#  'IT_1080.txt',
#  'IT_1090.txt',
#  'IT_110.txt',
#  'IT_1100.txt',
#  'IT_1110.txt',
#  'IT_1120.txt',
#  'IT_1130.txt',
#  'IT_1140.txt',
#  'IT_1150.txt',
#  'IT_1160.txt',
#  'IT_1170.txt',
#  'IT_1180.txt',
#  'IT_1190.txt',
#  'IT_120.txt',
#  'IT_1200.txt',
#  'IT_1210.txt',
#  'IT_1220.txt',
#  'IT_1230.txt',
#  'IT_1240.txt',
#  'IT_1250.txt',
#  'IT_1260.txt',
#  'IT_1270.txt',
#  'IT_1280.txt',
#  'IT_1290.txt',
#  'IT_130.txt',
#  'IT_1300.txt',
#  'IT_1310.txt',
#  'IT_1320.txt',
#  'IT_1330.txt',
#  'IT_1340.txt',
#  'IT_1350.txt',
#  'IT_1360.txt',
#  'IT_1370.txt',
#  'IT_1380.txt',
#  'IT_1390.txt',
#  'IT_140.txt',
#  'IT_1400.txt',
#  'IT_1410.txt',
#  'IT_1420.txt',
#  'IT_1430.txt',
#  'IT_1440.txt',
#  'IT_1450.txt',
#  'IT_1460.txt',
#  'IT_1470.txt',
#  'IT_1480.txt',
#  'IT_1490.txt',
#  'IT_150.txt',
#  'IT_1500.txt',
#  'IT_1510.txt',
#  'IT_1520.txt',
#  'IT_1530.txt',
#  'IT_1540.txt',
#  'IT_1550.txt',
#  'IT_1560.txt',
#  'IT_1570.txt',
#  'IT_1580.txt',
#  'IT_1590.txt',
#  'IT_160.txt',
#  'IT_1600.txt',
#  'IT_1610.txt',
#  'IT_1620.txt',
#  'IT_1630.txt',
#  'IT_1640.txt',
#   '笔记本',
#   '电脑',
#   '降价促销',
#   '最高',
#   '降幅',
#   '达到',
#   '降幅',
#   '达到',
#   '42%',
#   '记者',
#   '联想',
#   '美国',
#   '官方',
#   '网站',
#   '发现',
#   '联想',
#   '相关',
#   '人士',
#   '表示',
#   '纪念',
#   '联想',
#   '成立',
#   '美国',
#   '市场',
#   '推出',
#   '促销',
#   '产品',
#   '包括',
#   'THINKPAD',
#   'T',
#   '系列',
#   '笔记本',
#   '促销',
#   '价格战',
#   'THINK',
#   '品牌',
#   '高端',
#   '商务',
#   '路线',
#   '方向',
#   '不会',
#   '改变'],
#  ['赛迪网',
#   '消息',
#   '思科',
#   '周二',
#   '发布',
#   '其财',
#   '第三季度',
#   '财报',
#   '财报',
#   '显示',
#   '股票',
#   '期权',
#   '开支',
#   '收购',
#   '相关',
#   '费用',
#   '影响',
#   '季度',
#   '营收',
#   '实现',
#   '增长',
#   '净利润',
#   '同比',
#   '下降',
#   '据',
#   'Maketwatch',
#   '网站',
#   '报道',
#   '思科',
#   '季度',
#   '实现',
#   '净利润',
#   '低于',
#   '去年',
#   '同期',
#   '本季度',
#   '收益',
#   '去年',
#   '同期',
#   '收益',
#   '思科',
#   '去年',
#   '同期',
#   '发行',
#   '股票',
#   '数量',
#   '于今',
#   'Thomson',
#   'First',
#   'Call',
#   '调查',
#   '分析师',
#   '预计',
#   '收益',
#   '本',
#   '季度',
#   '营收',
#   '同比',
#   '增长',
#   '高于',
#   '华尔街',
#   '分析师',
#   '预计',
#   '思科',
#   '新近',
#   '收购',
#   'Scientific-Atlanta',
#   '公司',
#   '季度',
#   '营收',
#   '增长',
#   '做出',
#   '贡献',
#   '思科',
#   '上个世纪',
#   '年代',
#   '进行',
#   '收购',
#   '实现',
#   '发展',
#   '目的',
#   '现在',
#   '希望',
#   '借助',
#   '价格',
#   '收购',
#   'Scientific-Atlanta',
#   '公司',
#   '扩大',
#   '互联网',
#   '设备',
#   '市场',
#   '份额',
#   '分析师',
#   '投资者',
#   '看好',
#   '思科',
#   'Scientific-Atlanta',
#   '收购',
#   '思科',
#   '股价',
#   '进入',
#   '今年',
#   '上涨',
#   '财报',
#   '发布',
#   '思科',
#   '股票',
#   '盘后',
#   '交易',
#   '上涨'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '国外',
#   '媒体',
#   '报道',
#   '一名',
#   '德国',
#   '数据库安全',
#   '工程师',
#   '日前',
#   '撰文',
#   '指出',
#   '目前',
#   '甲骨文',
#   '软件',
#   '产品',
#   '尚未',
#   '修补',
#   '漏洞',
#   '漏洞',
#   '发现',
#   '不等',
#   '德国',
#   '信息',
#   '安全',
#   '机构',
#   '红色',
#   '数据库安全',
#   '工程师',
#   '亚力山大',
#   '·科布鲁斯特',
#   '日前',
#   'Buqtraq',
#   '安全',
#   '邮件',
#   '列表',
#   '发表',
#   '文章',
#   '漏洞',
#   '集中',
#   '甲骨文',
#   '数据库',
#   '产品',
#   '漏洞',
#   '之前',
#   '发现',
#   '报告',
#   '甲骨文',
#   '最新',
#   '漏洞',
#   '之前',
#   '发现',
#   '科',
#   '布鲁斯特',
#   '谈及',
#   '漏洞',
#   '包括',
#   'SQL',
#   '语句',
#   '插入',
#   '漏洞',
#   '交叉',
#   '脚本',
#   '攻击',
#   '漏洞',
#   '明文',
#   '密码',
#   '泄露',
#   '漏洞',
#   '漏洞',
#   '甲骨文公司',
#   '未来',
#   '安全更新',
#   '中将',
#   '得到',
#   '修补',
#   '清楚',
#   '甲骨文',
#   '升级',
#   '软件',
#   '发布',
#   '修补',
#   '具体',
#   '漏洞',
#   '时间',
#   '去年',
#   '甲骨文',
#   '首席',
#   '安全',
#   '玛丽·安娜·戴维德森',
#   '席话',
#   '信息',
#   '安全界',
#   '引发',
#   '骚动',
#   '安娜',
#   '已经',
#   '发现',
#   '甲骨文',
#   '软件',
#   '漏洞',
#   '有四',
#   '公司',
#   '工程师',
#   '发现',
#   '科布鲁斯特',
#   '计算',
#   '甲骨文',
#   '软件',
#   '尚未',
#   '得到',
#   '修补',
#   '漏洞',
#   '应该',
#   '百六',
#   '左右',
#   '算术',
#   '玛丽·安娜·戴维德森',
#   '说法',
#   '四分',
#   '漏洞',
#   '甲骨文',
#   '发现',
#   '发现',
#   '剩下',
#   '甲骨文',
#   '尚未',
#   '修改',
#   '至少',
#   '百六',
#   '漏洞',
#   '科布鲁斯特',
#   '文章',
#   '写道',
#   '近来',
#   '甲骨文',
#   '软件',
#   '漏洞',
#   '新闻',
#   '涌现',
#   '网络',
#   '周前',
#   '甲骨文',
#   '发布',
#   '安全',
#   '更新包',
#   '号称',
#   '修补',
#   '三十',
#   '漏洞',
#   'NGS',
#   '软件公司',
#   '工程师',
#   '大卫·里奇菲尔德',
#   '甲骨文',
#   '发布',
#   '补丁',
#   '没有',
#   '存在',
#   '年多',
#   '漏洞',
#   '修补',
#   '科布鲁斯特',
#   '文章',
#   '得出',
#   '结论',
#   '修补',
#   '软件',
#   '漏洞',
#   '方面',
#   '甲骨文',
#   '慢条斯理'],
#  ['赛迪网',
#   '外电',
#   '消息',
#   '美国',
#   '媒体',
#   '巨头',
#   '时代华纳公司',
#   '星期',
#   '公布',
#   '截止',
#   '月份',
#   '季度',
#   '财务',
#   '报告',
#   '有线电视',
#   '部门',
#   '强劲',
#   '增长',
#   '出售',
#   '图书',
#   '部门',
#   '资产',
#   '获得',
#   '收益',
#   '推动',
#   '时代华纳',
#   '季度',
#   '利润',
#   '增长',
#   '将近',
#   '60%',
#   '据',
#   '美联社',
#   '报道',
#   '时代华纳',
#   '季度',
#   '利润',
#   '收益',
#   '去年',
#   '同期',
#   '时代华纳',
#   '利润',
#   '收益',
#   '销售',
#   '收入',
#   '增长',
#   '1%',
#   '去年',
#   '同期',
#   '增长',
#   '扣除非',
#   '正常',
#   '收益',
#   '时间',
#   '一次性',
#   '收益',
#   '出售',
#   '图书',
#   '部门',
#   '收益',
#   '时代华纳',
#   '利润',
#   '增长',
#   '32%',
#   '去年',
#   '同期',
#   '增长',
#   '标准',
#   '计算',
#   '时代华纳',
#   '收益',
#   '去年',
#   '同期',
#   '收益',
#   '提高',
#   '收益',
#   '远远',
#   '超过',
#   '华尔街',
#   '分析师',
#   '预测',
#   '金融',
#   '机构',
#   'Thomson',
#   'Financial',
#   '调查',
#   '华尔街',
#   '分析师',
#   '预测',
#   '收益',
#   '时代华纳',
#   '旗下',
#   '子公司',
#   '收入',
#   '最多',
#   '有线电视',
#   '部门',
#   '部门',
#   '销售',
#   '收入',
#   '增长',
#   '15%',
#   '利润',
#   '增长',
#   '25%',
#   '今年',
#   '季度',
#   '时代华纳',
#   '有线电视',
#   '公司',
#   '增加',
#   '基本',
#   '有线电视',
#   '用户',
#   '公司',
#   '数字',
#   '视频',
#   '互联网',
#   '数字',
#   '视频',
#   '录像',
#   '数字电话',
#   '服务',
#   '收费',
#   '较高',
#   '服务',
#   '增加',
#   '用户',
#   '时代华纳',
#   '首席',
#   '执行官',
#   '迪克·帕森斯',
#   'Dick',
#   'Parsons',
#   '分析师',
#   '召开',
#   '电话会议',
#   '证实',
#   '时代华纳',
#   '媒体',
#   '大王',
#   '约翰·马龙',
#   '控股',
#   '位于',
#   '丹佛',
#   '自由',
#   '媒体',
#   '公司',
#   '谈判',
#   '正在',
#   '取得',
#   '进展',
#   '谈判',
#   '内容',
#   '收购',
#   '自由',
#   '媒体',
#   '公司',
#   '旗下',
#   'Court',
#   'TV',
#   '电视',
#   '公司',
#   '50%',
#   '股权',
#   '事宜',
#   '谈判',
#   '成功',
#   '时代华纳',
#   '拥有',
#   '有线电视',
#   '频道',
#   '股权',
#   '美国在线',
#   '继续',
#   '失去',
#   '用户',
#   '美国在线',
#   '重新',
#   '成为',
#   '广告',
#   '收入',
#   '推动',
#   '互联网',
#   '公司',
#   '美国在线',
#   '季度',
#   '用户',
#   '减少',
#   '目前',
#   '用户',
#   '总数',
#   '用户',
#   '收入',
#   '下降',
#   '超过',
#   '广告',
#   '收入',
#   '增长',
#   '美国在线',
#   '季度',
#   '经营',
#   '利润',
#   '减少',
#   '14%',
#   '时代公司',
#   '季度',
#   '利润',
#   '减少',
#   '12%',
#   '原因',
#   '海外',
#   '杂志',
#   '销售',
#   '疲软',
#   '支出',
#   '公司',
#   '重组',
#   '费用',
#   '今年',
#   '月份',
#   '宣布',
#   '出售',
#   '时代华纳',
#   '图书',
#   '集团',
#   '时代华纳',
#   '获得',
#   '收益',
#   '帕森斯',
#   '电话会议',
#   '投资者',
#   '公司',
#   '按计划',
#   '之前',
#   '完成',
#   'Comcast',
#   '一起',
#   '收购',
#   'Adelphia',
#   '通信',
#   '公司',
#   '有线电视',
#   '资产',
#   '交易'],
#  ['五',
#   '期间',
#   '苏宁',
#   '国美',
#   '大中',
#   '永乐',
#   '卖场',
#   '再次',
#   '掀起',
#   '平板',
#   '热卖',
#   '高潮',
#   '最高',
#   '降幅',
#   '50%',
#   '国美',
#   '液晶',
#   '电视',
#   '售价',
#   '每英寸',
#   '售卖',
#   '国美',
#   '平板',
#   '价格',
#   '整体',
#   '下调',
#   '30%',
#   '左右',
#   '最高',
#   '降幅',
#   '超过',
#   '50%',
#   '目前',
#   '市场',
#   '最为',
#   '走俏',
#   '液晶',
#   '等离子',
#   '电视',
#   '液晶',
#   '电视',
#   '成为',
#   '国美',
#   '重点',
#   '推出',
#   '机型',
#   '一款',
#   '液晶',
#   '电视',
#   '跌破',
#   '意味着',
#   '五一',
#   '期间',
#   '国美',
#   '液晶',
#   '电视',
#   '售价',
#   '每英寸',
#   '售卖',
#   '而',
#   '苏宁',
#   '合资',
#   '液晶',
#   '合资',
#   '等离子',
#   '液晶',
#   '跌破',
#   '苏宁',
#   '彩电',
#   '五一',
#   '期间',
#   '特价',
#   '投放',
#   '市场',
#   '新开',
#   '店面',
#   '低于',
#   '特价',
#   '电器',
#   '彩电',
#   '事业部',
#   '负责人',
#   '表示',
#   '大中',
#   '永乐',
#   '联手',
#   '集中',
#   '打压',
#   '等离子',
#   '平板',
#   '电视',
#   '五一',
#   '期间',
#   '预计',
#   '左右',
#   '低价',
#   '敞开',
#   '供应',
#   '大中',
#   '中央电视塔',
#   '集中',
#   '展示',
#   '液晶',
#   '新品',
#   '液晶',
#   '主流',
#   '价位',
#   '集中',
#   '左右',
#   '普及',
#   '价格',
#   '夏普',
#   '三星',
#   'LG',
#   '索尼',
#   '新品',
#   '亮相',
#   '记者',
#   '杨振'],
#  ['明年',
#   '有望',
#   '传回',
#   '中国',
#   '月球',
#   '三维图',
#   '本报讯',
#   '解放',
#   '日报',
#   '报道',
#   '日前',
#   '一支',
#   '上海',
#   '上海',
#   '光机',
#   '组成',
#   '科研',
#   '团队',
#   '正在',
#   '即将',
#   '上天',
#   '嫦娥',
#   '探月',
#   '卫星',
#   '激光',
#   '激光',
#   '我国',
#   '独立',
#   '自主',
#   '研发',
#   '太空',
#   '激光',
#   '高度计',
#   '明年',
#   '有望',
#   '月亮',
#   '传回',
#   '中国',
#   '月球',
#   '图片',
#   '中国人',
#   '未来',
#   '登月',
#   '计划',
#   '寻找',
#   '合适',
#   '落脚点',
#   '据介绍',
#   '国产化',
#   '激光',
#   '高度计',
#   '堪称',
#   '太空',
#   '劳模',
#   '嫦娥',
#   '运转',
#   '高度',
#   '轨道',
#   '长期',
#   '开机',
#   '工作',
#   '白天黑夜',
#   '每隔',
#   '发射',
#   '激光',
#   '激光',
#   '月球',
#   '表面',
#   '留下',
#   '直径',
#   '足印',
#   '千分',
#   '反射',
#   '回来',
#   '卫星',
#   '实时',
#   '处理',
#   '传回',
#   '测得',
#   '大量',
#   '数据',
#   '卫星',
#   '搭载',
#   '激光',
#   '高度计',
#   '绒线',
#   '一圈',
#   '地转',
#   '留下',
#   '激光',
#   '足印',
#   '最终',
#   '月球',
#   '地表',
#   '状况',
#   '扫描',
#   '下来'],
#  ['天极网',
#   '消息',
#   '孙淑艳',
#   '编译',
#   '外电',
#   '报道',
#   '美国纽约',
#   '时间',
#   '本周',
#   '华尔街',
#   '日报',
#   '报道',
#   '盗版',
#   'DVD',
#   '互联网',
#   '下载',
#   '电影',
#   '产业',
#   '造成',
#   '损失',
#   '原来',
#   '预期',
#   '报道',
#   '研究',
#   '显示',
#   '电影',
#   '产业',
#   '损失',
#   '原来',
#   '预期',
#   '75%',
#   '报告',
#   '援引',
#   '匿名',
#   '人士',
#   '指出',
#   '损失',
#   '不仅仅',
#   '票房',
#   'DVD',
#   '销售',
#   '报告',
#   '指出',
#   '美国',
#   '损失',
#   '高达',
#   '报告',
#   '推翻',
#   '常识',
#   '墨西哥',
#   '超过',
#   '中国',
#   '俄罗斯',
#   '成为',
#   '世界',
#   '最大',
#   '美国',
#   '电影',
#   '盗版',
#   '市场',
#   '美国',
#   '电影',
#   '产业',
#   '造成',
#   '损失'],
#  ['消息',
#   '研究',
#   '人员',
#   '星期',
#   '微软',
#   'IE',
#   '浏览器',
#   '发现',
#   '新的',
#   '安全',
#   '漏洞',
#   '之后',
#   '研究',
#   '人员',
#   '现在',
#   'IE',
#   '浏览器',
#   '发现',
#   '安全',
#   '漏洞',
#   '据',
#   'CNET',
#   'News',
#   'com',
#   '网站',
#   '报道',
#   '新的',
#   '安全',
#   '漏洞',
#   '能够',
#   '黑客',
#   '实施',
#   '执行',
#   '代码',
#   '攻击',
#   '微软',
#   '已经',
#   '证实',
#   '安全',
#   '漏洞',
#   '存在',
#   '安全',
#   '漏洞',
#   '安全',
#   '公司',
#   'Secunia',
#   '研究',
#   '人员',
#   'Andreas',
#   'Sandblad',
#   '发现',
#   '上个星期',
#   '安全',
#   '研究',
#   '人员',
#   'Michal',
#   'Zalewski',
#   '发现',
#   '成功',
#   '利用',
#   '安全漏洞',
#   '原来',
#   'Sandblad',
#   '发现',
#   '安全漏洞',
#   'Zalewski',
#   '上个星期',
#   '发现',
#   '安全漏洞',
#   '关联',
#   '微软',
#   '发言人',
#   '证实',
#   '安全漏洞',
#   '不同',
#   '安全',
#   '公司',
#   'Secunia',
#   '星期',
#   '网站',
#   '发表',
#   '文章',
#   '分析',
#   'Secunia',
#   '发现',
#   '安全',
#   '漏洞',
#   '一种',
#   '安全',
#   '漏洞',
#   'Zalewski',
#   '早些',
#   '发现',
#   '安全',
#   '漏洞',
#   '安全',
#   '公司',
#   '证实',
#   '安全',
#   '漏洞',
#   '影响',
#   '完全',
#   '使用',
#   '补丁',
#   'IE',
#   'Windows',
#   'XP',
#   'SP2',
#   'Secunia',
#   '警告',
#   '计算机',
#   '用户',
#   '引诱',
#   '之下',
#   '访问',
#   '恶意',
#   '网站',
#   '安全',
#   '漏洞',
#   '破坏',
#   '用户',
#   '计算机',
#   '内存',
#   '安全',
#   '公司',
#   '补充',
#   '微软',
#   '正在',
#   '制作',
#   '修复',
#   '安全',
#   '漏洞',
#   '补丁',
#   '天虹'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '周二',
#   '美国',
#   '电话',
#   '公司',
#   'Verizon',
#   '通讯',
#   '发布',
#   '报称',
#   '合并',
#   '影响',
#   '季度',
#   '利润',
#   '出现',
#   '下降',
#   '业务',
#   '强劲',
#   '收入',
#   '上升',
#   '沃达丰',
#   '合资',
#   '拥有',
#   'Verizon',
#   'Verizon',
#   '通讯',
#   '公司',
#   '季度',
#   '净利润',
#   '去年',
#   '同期',
#   '下降',
#   '去年',
#   '数字',
#   '包括',
#   'MCI',
#   '利润',
#   '除去',
#   '经常性',
#   '项目',
#   '利润',
#   '高出',
#   'Reuters',
#   'Estimates',
#   '调查',
#   '分析师',
#   '平均',
#   '估计',
#   '收入',
#   '提高',
#   '包括',
#   'MCI',
#   '数字',
#   '季度',
#   '利润',
#   '下降',
#   '3.3%',
#   '收入',
#   '上升',
#   '3.1%',
#   'Verizon',
#   '通讯',
#   'Verizon',
#   '新增',
#   '客户',
#   '高于',
#   '路透社',
#   '分析师',
#   '估计',
#   '上周',
#   '美国',
#   '电话',
#   '公司',
#   'AT&ampT',
#   '发布',
#   '季度',
#   '报告',
#   '利润',
#   '超过',
#   '华尔街',
#   '预期'],
#  ['天极网',
#   '消息',
#   '记者',
#   '顾萌',
#   'PC',
#   '市场',
#   '增长',
#   '减缓',
#   '全球',
#   '四大',
#   '电脑',
#   '厂商',
#   '宏碁',
#   '看好',
#   '平板',
#   '电视',
#   '市场',
#   '发展',
#   '未来',
#   '之内',
#   '进入',
#   '利润',
#   '较高',
#   '市场',
#   '宏碁',
#   '总经理',
#   '兰奇',
#   '上周',
#   '台湾',
#   '表示',
#   '全球',
#   '平板',
#   '电视',
#   '市场',
#   '持续增长',
#   '有助于',
#   '宏碁',
#   '维持',
#   '获利',
#   '能力',
#   '宏碁',
#   '计划',
#   '未来',
#   '完成',
#   '全球',
#   '液晶',
#   '电视',
#   '市场',
#   '布局',
#   '兰奇',
#   '表示',
#   '营收',
#   '角度',
#   '液晶',
#   '电视',
#   '有可能',
#   '成为',
#   '宏碁',
#   '三大',
#   '支柱',
#   '兰奇',
#   '承认',
#   '近期',
#   '抛售',
#   '明基',
#   '关系',
#   '企业',
#   '股票',
#   '资金',
#   '用于',
#   '提升',
#   '个人',
#   '电脑',
#   '电视',
#   '业务',
#   '全球',
#   '市场',
#   '市场',
#   '份额',
#   '宏碁',
#   '手中',
#   '大约',
#   '明基',
#   '关系',
#   '企业',
#   '股票',
#   '股票',
#   '年内',
#   '出售',
#   '分析师',
#   '认为',
#   '今年',
#   '宏碁',
#   '股价',
#   '下滑',
#   '高达',
#   '25%',
#   '未来',
#   '可能',
#   '下滑',
#   '5%',
#   '充分',
#   '反映',
#   '投资者',
#   'PC',
#   '市场',
#   '价格',
#   '持续',
#   '走低',
#   '担心',
#   '预计',
#   '未来',
#   '笔记本',
#   '电脑',
#   '售价',
#   '维持',
#   '电脑',
#   '维持',
#   '500~600',
#   '宏碁',
#   '希望',
#   '进入',
#   '平板',
#   '电视',
#   '市场',
#   '巩固',
#   '营收',
#   '目前',
#   '宏碁',
#   '欧洲和',
#   '北美',
#   '运作',
#   '液晶',
#   '电视',
#   '业务'],
#  ['天极网',
#   '消息',
#   '羽人',
#   '编译',
#   '外电',
#   '报道',
#   '市场',
#   '研究',
#   '机构',
#   'In-Stat',
#   '日前',
#   '表示',
#   '全球',
#   '使用',
#   '硬盘',
#   '闪存',
#   '存储',
#   '文件',
#   '音乐',
#   '播放器',
#   '出货',
#   '预计',
#   '翻番',
#   '市场',
#   '研究',
#   '机构',
#   '推动',
#   '全球',
#   '音乐',
#   '播放器',
#   '市场',
#   '发展',
#   '动力',
#   '包括',
#   '音乐',
#   '播放器',
#   '产品',
#   '价格',
#   '不断',
#   '下降',
#   '合理',
#   '定制',
#   '可行性',
#   '下载',
#   '付费',
#   '预计',
#   '全球',
#   '音乐',
#   '播放器',
#   '出货',
#   '去年',
#   '增加',
#   'In-Stat',
#   '苹果',
#   '公司',
#   '音乐',
#   '播放器',
#   '领域',
#   '居于',
#   '统治',
#   '地位',
#   '竞争',
#   '对手',
#   '面临',
#   '挑战',
#   '包括',
#   '紧俏',
#   '闪存',
#   '供应',
#   '设备',
#   '软件',
#   '融合',
#   '苹果',
#   'iPod',
#   '产品线',
#   '相关',
#   '因素',
#   '项对',
#   '消费者',
#   '调查',
#   '显示',
#   '49%',
#   '音乐',
#   '播放',
#   '用户',
#   '使用',
#   '产品',
#   '苹果',
#   'iPod'],
#  ['思科',
#   '总裁',
#   '首席',
#   '执行官',
#   '钱伯斯',
#   '周二',
#   '拉斯维加斯',
#   '开幕',
#   'Interop',
#   '大会',
#   '表示',
#   '网络',
#   '企业',
#   '成本',
#   '改变',
#   '促进',
#   '通信',
#   '技术',
#   '发展',
#   '引擎',
#   '包括',
#   '数据',
#   '视频',
#   '语音',
#   '移动',
#   '钱伯斯',
#   '表示',
#   '网络',
#   '改变',
#   '社会',
#   '改善',
#   '劳动生产率',
#   '增长',
#   '速度',
#   '协作',
#   '通信',
#   '方式',
#   '更多',
#   '操作',
#   '系统',
#   '进入',
#   '网络',
#   '网络',
#   '成为',
#   '平台',
#   '表示',
#   '网络',
#   '成为',
#   '平台',
#   '意味',
#   '能够',
#   '更快',
#   '速度',
#   '传输',
#   '带来',
#   '增长',
#   '机会',
#   'IT',
#   '职能',
#   '管理成本',
#   '变为',
#   '增长',
#   '动力',
#   '钱伯斯',
#   '表示',
#   '以前',
#   '一种',
#   '内容',
#   '一种',
#   '设备',
#   '联系',
#   '起来',
#   '现在',
#   '设备',
#   '显示屏',
#   '分享',
#   '相同',
#   '体验',
#   '带来',
#   '劳动生产率',
#   '大幅',
#   '提高',
#   '表示',
#   '通信',
#   '协作',
#   '过程',
#   '并不',
#   '轻松',
#   '思科',
#   '苦于',
#   '不同',
#   '部门',
#   '协作',
#   '协作',
#   '关系',
#   '成为',
#   '基础设施',
#   '思科',
#   '劳动生产率',
#   '得到',
#   '很大',
#   '提高',
#   '编译',
#   '搜狐',
#   'IT',
#   'Unifytruth'],
#  ['本报讯',
#   '记者',
#   '王京',
#   '记者',
#   '英特尔',
#   '公司',
#   '证实',
#   '英特尔',
#   '统一',
#   '台式机',
#   '笔记本',
#   'CPU',
#   '品牌',
#   '现有',
#   'Pentium',
#   '4',
#   '奔腾',
#   'Core',
#   'Duo',
#   '酷睿',
#   'Core',
#   'Duo',
#   '酷睿',
#   '双核',
#   '取代',
#   '品牌',
#   '预计',
#   '今年',
#   '季度',
#   '产品',
#   '使用',
#   '已经',
#   '影响',
#   '一代',
#   '电脑',
#   '奔腾',
#   '品牌',
#   '逐渐',
#   '退出',
#   '历史',
#   '舞台',
#   '英特尔',
#   '相关',
#   '人士',
#   '告诉',
#   '记者',
#   '英特尔',
#   '双核',
#   '处理器',
#   '研发',
#   '代号',
#   '分别为',
#   'Conroe',
#   '台式机处理器',
#   'Merom',
#   '笔记本',
#   '电脑',
#   '处理',
#   '采用',
#   '英特尔',
#   '新一代',
#   'Core',
#   '架构',
#   '结束',
#   '以往',
#   '英特尔',
#   '台式机',
#   '笔记本',
#   '电脑',
#   '处理器',
#   '架构',
#   '不一',
#   '导致',
#   '产品',
#   '品牌',
#   '混乱',
#   '局面',
#   '英特尔',
#   '借此机会',
#   '台式机',
#   '笔记本',
#   '电脑',
#   '处理器',
#   '品牌',
#   '统一',
#   'Core',
#   '2',
#   'Duo',
#   '具体',
#   '英文',
#   '数字',
#   '型号',
#   '标明',
#   '台式机',
#   '笔记本',
#   '电脑',
#   '处理器',
#   '区别',
#   '性能',
#   '功耗',
#   '人士',
#   '表示',
#   '英特尔',
#   '新的',
#   '统一',
#   '品牌',
#   '投入',
#   '极大',
#   '人力',
#   '物力',
#   '研发',
#   '能力',
#   '目的',
#   '提高',
#   '处理器',
#   '性能',
#   '今后',
#   'Pentium',
#   '奔腾',
#   '标志',
#   '逐渐',
#   '电脑',
#   '消失',
#   '记者',
#   '透露',
#   '考虑到',
#   '用户',
#   '不同',
#   '需求',
#   '今后',
#   '一段',
#   '时间',
#   '英特尔',
#   '市场',
#   '提供',
#   '奔腾',
#   '系列',
#   '产品'],
#  ['相',
#   '传统',
#   '购买',
#   '方式',
#   '节省',
#   '七成',
#   '费用',
#   '适合',
#   '购买',
#   '意外险',
#   '图',
#   '易保',
#   '网上',
#   '保险',
#   '候车',
#   '站台',
#   '灯箱',
#   '广告',
#   '目前',
#   '网上',
#   '投保',
#   '一项',
#   '新生事物',
#   '投保人',
#   '金额',
#   '较大',
#   '险种',
#   '进行',
#   '网上',
#   '投保',
#   '有所',
#   '顾虑',
#   '意外险',
#   '险种',
#   '保费',
#   '较低',
#   '投保人',
#   '最为',
#   '放心',
#   '陈锋',
#   '黄金周',
#   '老百姓',
#   '出行',
#   '旅游',
#   '时节',
#   '旅行',
#   '险和',
#   '意外险',
#   '销售',
#   '旺季',
#   '今年',
#   '保险公司',
#   '不约而同',
#   '打出',
#   '网络',
#   '保险公司',
#   '网络',
#   '据',
#   '了解',
#   '已经',
#   '保险',
#   '公司',
#   '推广',
#   '在线',
#   '投保',
#   '云网',
#   '专门',
#   '电子',
#   '商务',
#   '网站',
#   '网上',
#   '保险',
#   '有所',
#   '涉足',
#   '五一',
#   '保险公司',
#   '齐推',
#   '网络',
#   '保险',
#   '情况',
#   '前所未有',
#   '中国',
#   '平安',
#   '五一',
#   '推广',
#   '一款',
#   '网上',
#   '购买',
#   '旅游',
#   '意外险',
#   '推出',
#   '旅游',
#   '出行',
#   '保障',
#   '为主',
#   'e-',
#   '神州',
#   '逍遥',
#   'e-',
#   '四海',
#   '逍遥',
#   'e-',
#   '自驾',
#   '逍遥',
#   'e-',
#   '出行',
#   '无忧',
#   '系列',
#   '电子商务',
#   '渠道',
#   '专用',
#   '产品',
#   '太平洋',
#   '产险',
#   '近期',
#   '推行',
#   '网上',
#   '查询',
#   '保单',
#   '服务',
#   '民生',
#   '人寿',
#   '开通',
#   '电子',
#   '商务',
#   '网站',
#   '网站',
#   '在线',
#   '支付',
#   '保险费用',
#   '变更',
#   '保单',
#   '信息',
#   '查询',
#   '代理人',
#   '信息',
#   '民生',
#   '人寿',
#   '总裁',
#   '助理',
#   '李越',
#   '告诉',
#   '记者',
#   '电子',
#   '商务',
#   '网站',
#   '开通',
#   '消费者',
#   '进行',
#   '网上',
#   '支付',
#   '购买',
#   '保单',
#   '平台',
#   '提供',
#   '全天',
#   '小时',
#   '服务',
#   '投保',
#   '处理',
#   '效率',
#   '大幅',
#   '提高',
#   '完成',
#   '投保',
#   '实时',
#   '生成',
#   '保单',
#   '次日',
#   '零点',
#   '生效',
#   '意外险',
#   '适合',
#   '网络',
#   '投保',
#   '业内人士',
#   '表示',
#   '意外险',
#   '适合',
#   '在线',
#   '投保',
#   '险种',
#   '网上',
#   '投保',
#   '一项',
#   '新事物',
#   '投保人',
#   '金额',
#   '较大',
#   '险种',
#   '进行',
#   '网上',
#   '投保',
#   '有所',
#   '顾虑',
#   '意外险',
#   '险种',
#   '保费',
#   '较低',
#   '投保人',
#   '最为',
#   '放心',
#   '意外险',
#   '投保',
#   '不用',
#   '险种',
#   '需要',
#   '进行',
#   '体检',
#   '条款',
#   '相对',
#   '简单',
#   '相对于',
#   '传统',
#   '保单',
#   '在线',
#   '投保',
#   '程序',
#   '更为',
#   '简便',
#   '通常',
#   '情况下',
#   '投保人',
#   '填写',
#   '投保人',
#   '被保险人',
#   '姓名',
#   '身份证',
#   '联系',
#   '方式',
#   '信息',
#   '即可',
#   '快速',
#   '投保',
#   '投保人',
#   '自主',
#   '选择',
#   '保障',
#   '额度',
#   '保险',
#   '期限',
#   '保单',
#   '生效',
#   '时间',
#   '更容易',
#   '出游',
#   '人员',
#   '欢迎',
#   '网络',
#   '投保人',
#   '出售',
#   '保单',
#   '提供',
#   '服务',
#   '跳过',
#   '传统',
#   '中介',
#   '代理人',
#   '环节',
#   '不用',
#   '代理',
#   '人员',
#   '机构',
#   '支付',
#   '手续费',
#   '传统',
#   '营销',
#   '方式',
#   '节省',
#   '大约',
#   '七成',
#   '费用',
#   '保险公司',
#   '经营',
#   '成本',
#   '较大',
#   '幅度',
#   '降低',
#   '投保人',
#   '进行',
#   '让利',
#   '网上',
#   '投保',
#   '价格',
#   '相对',
#   '便宜',
#   '记者',
#   '张嵩浩'],
#  ['熟知',
#   'MSN',
#   '之外',
#   '微软',
#   '酝酿',
#   '今年',
#   '下半年',
#   '在线',
#   '服务',
#   '方面',
#   '推广',
#   '品牌',
#   'WindowsLive',
#   '借此',
#   '传统',
#   '商业',
#   '模式',
#   '软件',
#   '许可',
#   '获益',
#   '方式转',
#   '广告',
#   '日前',
#   '微软',
#   '次在',
#   '披露',
#   'Live',
#   '战略',
#   'MSN',
#   '大中华区',
#   '总监',
#   '罗川',
#   '上海',
#   '东方',
#   '早报',
#   '记者',
#   '透露',
#   '今年',
#   '下半年',
#   '微软',
#   'WindowsLive',
#   '软件',
#   '服务',
#   '全球',
#   '进行',
#   '推广',
#   '罗川',
#   '表示',
#   '具体',
#   '时间',
#   '尚未',
#   '最终',
#   '确定',
#   '相信',
#   '不知不觉',
#   '改变',
#   '网络',
#   '使用',
#   '习惯',
#   'WindowsLive',
#   '推出',
#   '并不',
#   '意味着',
#   'MSN',
#   '消失',
#   '罗川',
#   '透露',
#   'MSN',
#   '提供',
#   '一种',
#   '编排',
#   '信息',
#   'WindowsLive',
#   '提供',
#   '用户',
#   '选择',
#   '信息',
#   'Win-dowsLive',
#   '给予',
#   '用户',
#   '更多',
#   '可选择性',
#   '自由',
#   '设计',
#   '互联网',
#   '应用',
#   '平台',
#   '用户',
#   '兴趣',
#   '建立',
#   '稳定',
#   '群体',
#   '据悉',
#   '去年',
#   '微软',
#   '董事会',
#   '主席',
#   '比尔·盖茨',
#   '已经',
#   '拉开',
#   'Live',
#   '软件',
#   '序幕',
#   '微软',
#   '高级',
#   '副总裁',
#   '大卫·科利',
#   '备忘录',
#   'WindowsLive',
#   '战略',
#   '希望',
#   '互联网',
#   '争夺战',
#   '获胜',
#   '能够',
#   '刺激',
#   '微软',
#   '劳师动众',
#   '网络',
#   '广告',
#   '市场',
#   '突飞猛进',
#   '增长',
#   '过去',
#   '微软',
#   '活动',
#   '不断',
#   '围绕',
#   '视窗',
#   '从今',
#   '往后',
#   '围绕',
#   '广告',
#   '广告',
#   '微软公司',
#   '内部',
#   '传播',
#   '广泛',
#   '一段',
#   '影像',
#   '微软',
#   '副总裁',
#   '激动',
#   '言辞',
#   '已经',
#   '微软',
#   '广告',
#   '野心',
#   '昭告',
#   '天下',
#   '罗川',
#   '说法',
#   'WindowsLive',
#   '微软',
#   '商业',
#   '模式',
#   '广告',
#   '收费',
#   '领域',
#   '转型',
#   '重要',
#   '利器',
#   '固定',
#   '有着',
#   '相同',
#   '兴趣',
#   '快速',
#   '发展',
#   '用户',
#   '广告商',
#   '信息',
#   '恰当',
#   '提供',
#   '用户',
#   '完成',
#   '广告',
#   '配送',
#   '广告',
#   '发布',
#   '有效',
#   '过程',
#   '罗川',
#   '表示',
#   '罗',
#   '表示',
#   'Google',
#   '广告',
#   '方面',
#   '已经',
#   '非常',
#   '出色',
#   '微软',
#   '希望',
#   'WindowsLive',
#   '能够',
#   '赶上',
#   '发展',
#   '步伐',
#   'WindowsLive',
#   '微软',
#   '软件',
#   '相同',
#   '地方',
#   '商业',
#   '模式',
#   '微软',
#   '江山',
#   '软件',
#   '许可',
#   '获准',
#   '方式',
#   '转变',
#   '广告',
#   '收费',
#   '获得',
#   '商业',
#   '价值',
#   'Google',
#   '点击',
#   '付费',
#   '模式',
#   '出现',
#   'WindowsLive',
#   '罗川',
#   '罗川',
#   '表示',
#   '微软',
#   '全球',
#   '软件',
#   '市场',
#   '已经',
#   '占据',
#   '相当',
#   '可观',
#   '市场',
#   '份额',
#   '广告',
#   '市场',
#   '比例',
#   '仍然',
#   '微小',
#   '并称',
#   '希望',
#   '未来',
#   '能够',
#   '网络',
#   '广告',
#   '市场',
#   '份额',
#   '提升',
#   '10%',
#   '左右',
#   '据悉',
#   '目前',
#   '微软',
#   '收入',
#   '软件',
#   '业务',
#   '全球',
#   '网络',
#   '广告',
#   '市场',
#   '规模',
#   '微软',
#   '占据'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '时间',
#   '周一',
#   '美国半导体工业协会',
#   '公布',
#   '全球',
#   '半导体',
#   '贸易',
#   '统计',
#   '机构',
#   '最新',
#   '统计',
#   '数据',
#   '显示',
#   '今年',
#   '季度',
#   '全球',
#   '半导体',
#   '销售',
#   '收入',
#   '达到',
#   '去年',
#   '季度',
#   '销售',
#   '收入',
#   '增长',
#   '7.3%',
#   '季度',
#   '销售',
#   '收入',
#   '去年',
#   '第四季度',
#   '半导体',
#   '收入',
#   '下降',
#   '1.3%',
#   '美国半导体工业协会',
#   '表示',
#   '去年',
#   '第四季度',
#   '半导体',
#   '销售',
#   '假日',
#   '销售',
#   '旺季',
#   '推动',
#   '今年',
#   '季度',
#   '收入',
#   '下降',
#   '反映',
#   '一种',
#   '正常',
#   '季节性',
#   '疲软',
#   '销售',
#   '模式',
#   '今年',
#   '季度',
#   '平均',
#   '销售',
#   '收入',
#   '去年',
#   '季度',
#   '平均',
#   '销售',
#   '收入'],
#  ['摘要',
#   '服务',
#   'Napster',
#   '现有',
#   '预定',
#   '服务',
#   '增加',
#   '用户',
#   '选定',
#   '音乐',
#   '下载',
#   '链接',
#   '发送',
#   '朋友',
#   '用户',
#   '选购',
#   '歌曲',
#   '免费',
#   '网站',
#   '收听',
#   '天极网',
#   '消息',
#   '老沈',
#   '编译',
#   '外电',
#   '报道',
#   '一度',
#   '背叛',
#   '音乐',
#   '下载',
#   '服务',
#   '网站',
#   'Napster',
#   '再次',
#   '服务',
#   '回到',
#   '根基',
#   'Napster',
#   '音乐',
#   '提供',
#   '免费',
#   '欣赏',
#   '多万',
#   '首歌曲',
#   '机会',
#   'Napster',
#   'com',
#   '周一',
#   '推出',
#   '服务',
#   '依靠',
#   '广告',
#   '支持',
#   '唱片',
#   '公司',
#   '谈判',
#   '做出',
#   '决定',
#   'Napster',
#   '歌手',
#   '曲目',
#   '播放',
#   '次数',
#   '基础上',
#   '唱片',
#   '公司',
#   '分享',
#   '广告',
#   '收入',
#   '服务',
#   'Napster',
#   '现有',
#   '预定',
#   '服务',
#   '增加',
#   '用户',
#   '选定',
#   '音乐',
#   '下载',
#   '链接',
#   '发送',
#   '朋友',
#   '用户',
#   '选购',
#   '歌曲',
#   '免费',
#   '网站',
#   '收听',
#   '公司',
#   'CEO',
#   'Gorog',
#   'Napster',
#   'com',
#   '建成',
#   '开放',
#   '平台',
#   'CEO',
#   '媒体',
#   '期望',
#   '免费',
#   '服务',
#   '增加',
#   '用户',
#   '网站',
#   '访问量',
#   'Napster',
#   '网站',
#   '一直',
#   '销售',
#   '下载',
#   '音乐',
#   '目前',
#   '访问',
#   '用户',
#   '更高',
#   '用户',
#   '流量',
#   '公司',
#   '带来',
#   '更多',
#   '广告',
#   '收入',
#   'Napster',
#   '公司',
#   '名列',
#   '美国',
#   '音乐',
#   '下载',
#   '服务',
#   '市场',
#   '远远',
#   '落后',
#   '苹果',
#   '电脑',
#   'iTunes',
#   '70%',
#   '市场',
#   '份额'],
#  ['盛大网络',
#   '周一',
#   '表示',
#   '首席',
#   '财务',
#   '高级',
#   '副总裁',
#   '李曙君',
#   '辞职',
#   '追求',
#   '事业',
#   '生效',
#   '继续',
#   '担任',
#   '公司',
#   '董事',
#   '从',
#   '担任',
#   '公司',
#   '财务',
#   '总监',
#   '张勇',
#   '接替',
#   '李曙君',
#   '张勇',
#   '1991-1995',
#   '毕业',
#   '上海',
#   '财经大学',
#   '取得',
#   '金融学',
#   '学士',
#   '学位',
#   '张勇',
#   '期间',
#   '就职',
#   '安达信',
#   '会计师',
#   '事务所',
#   '担任',
#   '上海',
#   '办事处',
#   '经理',
#   '担任',
#   '普华永道',
#   '会计师',
#   '事务所',
#   '上海',
#   '办事处',
#   '高级',
#   '经理',
#   '李曙君',
#   '担任',
#   '公司',
#   '副总裁',
#   '担任',
#   '公司',
#   '首席',
#   '财务',
#   '之前',
#   '投资',
#   '海外',
#   '业务',
#   '总监',
#   '加入',
#   '之前',
#   '李曙君',
#   '曾在',
#   '期间',
#   '基金',
#   '管理',
#   '公司',
#   '筹建',
#   '期间',
#   '担任',
#   '中国',
#   '南方证券有限公司',
#   '国际业务部',
#   '高级',
#   '经理',
#   '编译',
#   '搜狐',
#   'IT',
#   'Unifytruth'],
#  ['街道',
#   '住宅',
#   '保存',
#   '相当',
#   '完整',
#   '姆大陆',
#   '消失',
#   '文明',
#   '毁于一旦',
#   '消失',
#   '亚特兰蒂斯',
#   '大陆',
#   '令人神往',
#   '吸引',
#   '科学家',
#   '探险家',
#   '追寻',
#   '踪迹',
#   '今天',
#   '探险家',
#   '科学家',
#   '目光',
#   '转向',
#   '失去',
#   '大陆',
#   '传说中',
#   '姆大陆',
#   '越来越',
#   '证据',
#   '显示',
#   '姆大陆',
#   '可能',
#   '连接',
#   '文明',
#   '脐带',
#   '街道',
#   '住宅',
#   '保存',
#   '完整',
#   '城市',
#   '港口',
#   '规模',
#   '庞大',
#   '潜水',
#   '考古学',
#   '发现',
#   '姆大陆',
#   '见解',
#   '提供',
#   '必要',
#   '密克罗尼西亚',
#   '群岛',
#   '波纳佩',
#   '附近',
#   '海底',
#   '一片',
#   '沉没',
#   '古陆',
#   '潜水',
#   '人员',
#   '附近',
#   '海底',
#   '发现',
#   '保存',
#   '相当',
#   '完整',
#   '街道',
#   '石柱',
#   '石像',
#   '住宅',
#   '海底捞',
#   '十分',
#   '珍贵',
#   '黄金和',
#   '珠宝',
#   '饰物',
#   '太平洋',
#   '岛屿',
#   '都留有',
#   '巨大',
#   '石头',
#   '平台',
#   '石头',
#   '遗址',
#   '石头',
#   '雕像',
#   '学者',
#   '猜测',
#   '地区',
#   '曾经',
#   '存在',
#   '高度',
#   '文明',
#   '种族',
#   '高度',
#   '建筑',
#   '技巧',
#   '建成',
#   '城市',
#   '雕像',
#   '港口',
#   '迄今',
#   '知道',
#   '原因',
#   '集体',
#   '撤离',
#   '集体',
#   '灭绝',
#   '留下',
#   '壮观',
#   '建筑',
#   '遗迹',
#   '能够',
#   '冶炼',
#   '金属',
#   '使用',
#   '核能',
#   '科学家',
#   '考古学家',
#   '今天',
#   '非洲',
#   '加蓬共和国',
#   '发现',
#   '年前',
#   '链式',
#   '核反应堆',
#   '南非',
#   '发现',
#   '年前',
#   '金属球',
#   '很',
#   '显然',
#   '文明',
#   '古迹',
#   '不属于',
#   '人类',
#   '创造',
#   '实际上',
#   '文明',
#   '古迹',
#   '人类',
#   '技术',
#   '无法',
#   '建造',
#   '确凿',
#   '证据',
#   '学者',
#   '提出',
#   '文明',
#   '学说',
#   '人类',
#   '文明',
#   '之前',
#   '地球',
#   '曾经',
#   '存在',
#   '高度',
#   '文明',
#   '罗盘',
#   '失灵',
#   '无线电',
#   '中断',
#   '核潜艇',
#   '神秘',
#   '失踪',
#   '姆大陆',
#   '沉没',
#   '地方',
#   '自古以来',
#   '经常',
#   '发生',
#   '神秘',
#   '失踪',
#   '事件',
#   '船只',
#   '飞机',
#   '进入',
#   '水域',
#   '出现',
#   '罗盘',
#   '失灵',
#   '无线电',
#   '通讯',
#   '故障',
#   '中断',
#   '现象',
#   '已经',
#   '透露',
#   '消息',
#   '船只',
#   '照样',
#   '发生',
#   '事故',
#   '前苏联',
#   '先后',
#   '潜水艇',
#   '失踪',
#   '大部分',
#   '具有',
#   '先进',
#   '设备',
#   '核动力',
#   '潜艇',
#   '猜测',
#   '大洋',
#   '海底',
#   '可能',
#   '隐藏',
#   '文明',
#   '留下来',
#   '防卫',
#   '系统',
#   '导致',
#   '核潜艇',
#   '翻船',
#   '航海',
#   '建筑',
#   '发达',
#   '来往',
#   '乘坐',
#   '飞行船',
#   '专门',
#   '收集',
#   '古代',
#   '玛雅',
#   '传说',
#   '神话',
#   '特洛亚诺古',
#   '抄本',
#   '记载',
#   '姆大陆',
#   '消失',
#   '一万',
#   '千年',
#   '亚特兰蒂斯',
#   '大陆',
#   '沉没',
#   '姆大陆',
#   '土地',
#   '辽阔',
#   '东起',
#   '现今',
#   '夏威夷',
#   '群岛',
#   '西至',
#   '马里亚纳',
#   '群岛',
#   '南边',
#   '斐济',
#   '大溪地',
#   '群岛',
#   '复活节岛',
#   '大陆',
#   '东西',
#   '南北',
#   '总面积',
#   '一块',
#   '美丽',
#   '富饶',
#   '地方',
#   '英国人',
#   '詹姆士·丘吉沃德',
#   '遗失',
#   '大陆',
#   '一书',
#   '详细',
#   '描绘',
#   '地面',
#   '繁荣昌盛',
#   '帝国',
#   '姆大陆',
#   '帝国',
#   '共同',
#   '创造',
#   '灿烂',
#   '文化',
#   '航海',
#   '建筑业',
#   '相当',
#   '发达',
#   '大作',
#   '诸岛',
#   '传播',
#   '文明',
#   '帝国',
#   '科学技术',
#   '水平',
#   '很高',
#   '发明',
#   '行船',
#   '经常',
#   '来往',
#   '珍奇',
#   '物品',
#   '宝石',
#   '空中',
#   '鸟瞰',
#   '古地图',
#   '南极洲',
#   '爱因斯坦',
#   '科学家',
#   '坚信',
#   '如今',
#   '冰天雪地',
#   '毫无',
#   '生机',
#   '南极',
#   '可能',
#   '曾经',
#   '存在',
#   '文明',
#   '科学家',
#   '土耳其',
#   '伊斯坦布尔',
#   '托普卡比',
#   '发现',
#   '空中',
#   '鸟瞰',
#   '地图',
#   '上面',
#   '美洲',
#   '非洲',
#   '变形',
#   '轮廓线',
#   '阿波罗',
#   '飞船',
#   '拍摄',
#   '照片',
#   '完全',
#   '重合',
#   '令人',
#   '惊讶',
#   '地图',
#   '南极洲',
#   '冰层',
#   '覆盖',
#   '复杂',
#   '地貌',
#   '南极探险队',
#   '回声',
#   '探测仪',
#   '南极冰',
#   '地形',
#   '探测',
#   '毫无二致',
#   '证据',
#   '显示',
#   '南极洲',
#   '最早',
#   '地图',
#   '绘制',
#   '年前',
#   '当时',
#   '大陆',
#   '冰雪',
#   '覆盖',
#   '科学家',
#   '设想',
#   '多年前',
#   '南极',
#   '大陆',
#   '处于',
#   '温带',
#   '优越',
#   '自然环境',
#   '孕育',
#   '高度',
#   '发达',
#   '文明',
#   '掌握',
#   '先进',
#   '航海技术',
#   '天文',
#   '知识',
#   '率领',
#   '船队',
#   '穿梭',
#   '大洋',
#   '大陆',
#   '之间',
#   '文明',
#   '带到',
#   '世界',
#   '角落',
#   '蛮荒',
#   '落后',
#   '大陆',
#   '智慧',
#   '奇迹',
#   '成为',
#   '文化',
#   '交流',
#   '联系',
#   '桥梁',
#   '帝国',
#   '日趋',
#   '繁荣',
#   '危险',
#   '始终',
#   '存在',
#   '直至',
#   '突然',
#   '毁灭',
#   '原因',
#   '导致',
#   '人类',
#   '拥有',
#   '文明',
#   '最终',
#   '地球上',
#   '消失',
#   '灭绝',
#   '当时',
#   '生物',
#   '残留',
#   '极其',
#   '幸存',
#   '古迹',
#   '古城',
#   '遗址',
#   '核爆',
#   '痕迹',
#   '曾经',
#   '文明',
#   '核爆炸',
#   '印度',
#   '古城',
#   '遗址',
#   '哈拉巴',
#   '马享',
#   '佐·达摩',
#   '距今',
#   '至少',
#   '历史',
#   '马享',
#   '佐·达摩',
#   '出土',
#   '遗骨',
#   '比较',
#   '废墟',
#   '发现',
#   '成排',
#   '死去',
#   '遗体',
#   '双手',
#   '盖住',
#   '好像',
#   '保护',
#   '好像',
#   '看见',
#   '害怕',
#   '事情',
#   '肯定',
#   '突然',
#   '状态',
#   '死去',
#   '印度',
#   '考古学家',
#   '卡哈',
#   '出土',
#   '进行',
#   '详细',
#   '化学',
#   '分析',
#   '发现',
#   '高温',
#   '加热',
#   '痕迹',
#   '说明',
#   '马享',
#   '佐·达摩',
#   '毁灭',
#   '突然',
#   '出现',
#   '高温',
#   '马享',
#   '佐·达摩',
#   '发现',
#   '坍塌',
#   '建筑物',
#   '承受',
#   '高温',
#   '痕迹',
#   '发现',
#   '玻璃',
#   '建筑',
#   '立提',
#   '物质',
#   '物质',
#   '形成',
#   '瞬间',
#   '高温',
#   '熔化',
#   '物体',
#   '表面',
#   '迅速',
#   '冷却',
#   '造成',
#   '热核武器',
#   '爆炸',
#   '现场',
#   '发现',
#   '人为',
#   '物质',
#   '证据',
#   '说明',
#   '发生',
#   '爆炸',
#   '一夜之间',
#   '毁掉',
#   '一座',
#   '城池',
#   '印度',
#   '古巴比伦',
#   '撒哈拉',
#   '沙漠',
#   '蒙古',
#   '戈壁',
#   '发现',
#   '核战',
#   '废墟',
#   '废墟',
#   '玻璃',
#   '都与',
#   '今天',
#   '核试验',
#   '玻璃',
#   '一模一样',
#   '国外',
#   '物理学家',
#   '弗里德里克·索迪',
#   '认为',
#   '相信',
#   '人类',
#   '曾有',
#   '文明',
#   '人类',
#   '时已',
#   '熟悉',
#   '原子能',
#   '误用',
#   '遭到',
#   '毁灭',
#   '相关',
#   '链接',
#   '非洲',
#   '加蓬共和国',
#   '发现',
#   '年前',
#   '铀矿',
#   '奥克洛',
#   '铀矿',
#   '矿里',
#   '发现',
#   '不可思议',
#   '遗迹',
#   '古老',
#   '核反应堆',
#   '区域',
#   '大约',
#   '铀矿石',
#   '组成',
#   '运转',
#   '时间',
#   '长达',
#   '年之久',
#   '离',
#   '南美洲',
#   '太平洋',
#   '小岛',
#   '复活节岛',
#   '巨石',
#   '筑成',
#   '石殿',
#   '金字塔',
#   '吸引',
#   '余尊',
#   '面海',
#   '屹立',
#   '形状',
#   '奇特',
#   '半身',
#   '石雕',
#   '土著',
#   '口头',
#   '流传',
#   '传说',
#   '从前',
#   '一块',
#   '称为',
#   '希瓦',
#   '大陆',
#   '后来',
#   '突变',
#   '大部分',
#   '地区',
#   '沉沦',
#   '洋底',
#   '留下',
#   '复活节岛',
#   '撰文',
#   '亚锋'],
#  ['新华网',
#   '北京',
#   '专电',
#   '记者',
#   '晓芳',
#   '信息产业部',
#   '近日',
#   '公布',
#   '违规',
#   '移动信息',
#   '举报',
#   '电话',
#   '信息产业部',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '010-12300',
#   '北京市',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '010-68212300',
#   '地区',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '直辖市',
#   '省会',
#   '区号',
#   '用户',
#   '登录',
#   '信息',
#   '产业',
#   '网站',
#   'www',
#   'mii',
#   'gov',
#   'cn',
#   '进行',
#   '投诉',
#   '举报',
#   '了解',
#   '信息产业部',
#   '利用',
#   '左右',
#   '时间',
#   '全国',
#   '范围内',
#   '开展',
#   '治理',
#   '规范',
#   '信息',
#   '服务',
#   '企业',
#   '资费',
#   '收费',
#   '活动',
#   '明码',
#   '标价',
#   '信息',
#   '订购',
#   '计费',
#   '流程',
#   '收费',
#   '方式',
#   '资费',
#   '争议',
#   '处理',
#   '方面',
#   '相关',
#   '企业',
#   '进行',
#   '规范',
#   '加大',
#   '广播',
#   '电视',
#   '报纸',
#   '互联网',
#   '媒体',
#   '参与',
#   '互动',
#   '短信',
#   '规范',
#   '查处',
#   '力度',
#   '信息产业部',
#   '要求',
#   '相关',
#   '企业',
#   '近期',
#   '进行',
#   '自查自纠',
#   '信息产业部',
#   '组织',
#   '专门',
#   '力量',
#   '监督',
#   '检查',
#   '情况',
#   '社会',
#   '公布',
#   '恶意',
#   '侵犯',
#   '消费者',
#   '合法',
#   '权益',
#   '屡次',
#   '违规',
#   '信息',
#   '服务',
#   '企业',
#   '国家',
#   '充分',
#   '运用',
#   '法律',
#   '经济',
#   '技术',
#   '行政',
#   '手段',
#   '严厉',
#   '查处'],
#  ['天极网',
#   '消息',
#   '他山石',
#   '编译',
#   '外电',
#   '报道',
#   '全球',
#   '面板',
#   '制造商',
#   '友达',
#   '公司',
#   '奇美',
#   '电子',
#   '公司',
#   'LG',
#   '飞利浦',
#   '液晶',
#   '显示器',
#   '公司',
#   '今年',
#   '季度',
#   '面板',
#   '存货',
#   '过多',
#   '预期',
#   '今年',
#   '季度',
#   '全球',
#   '面板',
#   '行业',
#   '可能',
#   '发生',
#   '供过于求',
#   '现象',
#   '据',
#   '公司',
#   '公布',
#   '数据',
#   '显示',
#   '今年',
#   '季度',
#   '面板',
#   '存货',
#   '水平',
#   '同比',
#   '增长',
#   '18.4%',
#   '达到',
#   '新台币',
#   '资金周转',
#   '天数',
#   '增长',
#   '友达',
#   '公司',
#   '相比',
#   '奇美',
#   '电子',
#   '公司',
#   '面临',
#   '存货',
#   '过多',
#   '压力',
#   '更大',
#   '存货',
#   '价值',
#   '已经',
#   '达到',
#   '新台币',
#   '同比',
#   '增长',
#   '44.8%',
#   '资金周转',
#   '天数',
#   '一季度',
#   '增长',
#   '内部',
#   '存货',
#   '40%',
#   '完成',
#   '产品',
#   '35%',
#   '半成品',
#   '生产',
#   '生产',
#   '今年',
#   '季度',
#   'LG',
#   '飞利浦',
#   '液晶',
#   '显示器',
#   '公司',
#   '存货',
#   '水平',
#   '增长',
#   '三周',
#   '今年',
#   '四月',
#   '生产线',
#   '生产',
#   '月份',
#   '20%',
#   '30%',
#   '已经',
#   '达到',
#   '70%',
#   '80%'],
#  ['昨天',
#   '记者',
#   '了解到',
#   '我国',
#   '目前',
#   '余家',
#   '电子签名',
#   '认证',
#   '服务',
#   '机构',
#   '拥有',
#   '国家',
#   '电子',
#   '认证',
#   '服务',
#   '许可证',
#   '余家',
#   '竟未',
#   '认证',
#   '信产部',
#   '信息化',
#   '推进',
#   '司长',
#   '陈伟',
#   '透露',
#   '信产部',
#   '即日',
#   '月底',
#   '展开',
#   '相关',
#   '清查',
#   '工作',
#   '信产部',
#   '严查',
#   '机构',
#   '陈伟',
#   '透露',
#   '中华人民共和国',
#   '电子签名',
#   '实施',
#   '获得',
#   '国家',
#   '电子',
#   '认证',
#   '服务',
#   '许可证',
#   '认证',
#   '机构',
#   '已经',
#   '发出',
#   '电子',
#   '证书',
#   '电子签名',
#   '规定',
#   '拥有',
#   '许可证',
#   '电子认证',
#   '机构',
#   '提供',
#   '电子签名',
#   '认证',
#   '服务',
#   '清查',
#   '正规',
#   '机构',
#   '进行',
#   '自查自纠',
#   '派出',
#   '抽查',
#   '小组',
#   '进行',
#   '检查',
#   '月初',
#   '公布',
#   '清查',
#   '月底',
#   '再次',
#   '公告',
#   '行动',
#   '严查',
#   '没有',
#   '国家',
#   '认证',
#   '电子',
#   '认证',
#   '机构',
#   '电子签名',
#   '任重道远',
#   '电子商务',
#   '电子',
#   '政务',
#   '迅猛',
#   '发展',
#   '电子',
#   '签名',
#   '应用',
#   '范围',
#   '越来越',
#   '广泛',
#   '电子商务',
#   '企业',
#   '提高',
#   '电子',
#   '认证',
#   '质量',
#   '可信度',
#   '依靠',
#   '电子商务',
#   '企业',
#   '认证',
#   '管理',
#   '机构',
#   '共同',
#   'ax',
#   '实现',
#   '国务院',
#   '信息办',
#   '推广',
#   '副组长',
#   '张大明',
#   '透露',
#   '电子签名',
#   '重要',
#   '没有',
#   '足够',
#   '重视',
#   '建设',
#   '认证',
#   '机构',
#   '资金',
#   '投入',
#   '技术',
#   '更新',
#   '外资',
#   '银行',
#   '挑战',
#   '目前',
#   '国家',
#   '到底',
#   '需要',
#   '使用',
#   '认证',
#   '技术',
#   '明确',
#   '业内',
#   '行业',
#   '竞争',
#   '规范',
#   '记者',
#   '了解到',
#   '正规',
#   '电子认证',
#   '机构',
#   '发布',
#   '电子认证',
#   '诚信',
#   '服务',
#   '倡议书',
#   '倡议',
#   '成员',
#   '机构',
#   '北京',
#   '天威',
#   '诚信',
#   '数字',
#   '认证',
#   '中心',
#   '副总裁',
#   '李延昭',
#   '接受',
#   '记者',
#   '采访',
#   '表示',
#   '目前',
#   '电子签名',
#   '认证',
#   '企业',
#   '目前',
#   '规范',
#   '电子签名',
#   '出台',
#   '之前',
#   '存在',
#   '电子签名',
#   '认证',
#   '机构',
#   '大部分',
#   '银行',
#   '金融',
#   '行业',
#   '总体',
#   '市场',
#   '规范',
#   '行业',
#   '竞争',
#   '激烈',
#   '业内',
#   '普遍',
#   '担心',
#   '行业',
#   '起来',
#   '目前',
#   '普遍',
#   '业务',
#   '资费',
#   '企业',
#   '端也',
#   '机构',
#   '仍然',
#   '使用',
#   '免费',
#   '低价',
#   '恶意',
#   '竞争',
#   '方式',
#   '市场'],
#  ['端',
#   '点到点',
#   '端到',
#   'END-TO-END',
#   '点到点',
#   'POINT-TO-POINT',
#   '描述',
#   '网络',
#   '传输',
#   '实体',
#   'PEER',
#   'RNTITY',
#   '之间',
#   '关系',
#   '概念',
#   '端到',
#   '系统',
#   '信源',
#   '机上',
#   '实体',
#   '最终',
#   '信宿',
#   '对等',
#   '实体',
#   '用户',
#   '终端',
#   '直接',
#   '通信',
#   '之间',
#   '拥有',
#   '直通',
#   '线路',
#   '传输',
#   '过程',
#   '中断',
#   '节点',
#   '点到点',
#   '系统',
#   '对等',
#   '实体',
#   '通信',
#   '一段',
#   '直接',
#   '相连',
#   '计算机',
#   '通信',
#   '信道',
#   '组成',
#   '机器',
#   '直接',
#   '连接',
#   '点到点',
#   '连接',
#   '网卡',
#   '网卡',
#   '计算机',
#   '总线',
#   '上面',
#   '硬件',
#   '接口卡',
#   '终端',
#   '接入',
#   '以太网',
#   '以太网',
#   '网卡',
#   '接入',
#   'X.25',
#   '网络',
#   'X.25',
#   '中继器',
#   'REPEATER',
#   '中继器',
#   '网络',
#   '物理层',
#   '上面',
#   '连接',
#   '设备',
#   '适用',
#   '完全',
#   '相同',
#   '网络',
#   '互连',
#   '功能',
#   '数据',
#   '信号',
#   '重新',
#   '发送',
#   '转发',
#   '扩大',
#   '网络',
#   '传输',
#   '距离',
#   '网桥',
#   'BRIDGE',
#   '存储转发',
#   '设备',
#   '连接',
#   '同类型',
#   '网络拓扑',
#   '传输',
#   '介质',
#   '局域网',
#   'LAN',
#   '完成',
#   '数据',
#   '链路层',
#   '路由器',
#   'ROUTER',
#   '路由器',
#   '网络层',
#   '部分',
#   '互连',
#   '设备',
#   '功能',
#   '数据',
#   '流量',
#   '控制',
#   '差错',
#   '适时',
#   '控制',
#   '路由',
#   '选择',
#   '控制',
#   '进行',
#   '数据包',
#   '交换',
#   '网关',
#   'GATEWAY',
#   '用于',
#   '传输',
#   '传输层',
#   '高层',
#   '互连',
#   '连接器',
#   '互连',
#   '网络',
#   '类型',
#   '差别',
#   '之间',
#   '连接器'],
#  ['网友',
#   '浏览',
#   '网页',
#   '发现',
#   '重庆',
#   '代表',
#   '中国',
#   '特色',
#   '餐饮',
#   '火锅',
#   '韩国',
#   '企业',
#   '抢注',
#   '域名',
#   '网上',
#   '吆喝',
#   '重庆火锅',
#   '协会',
#   '表示',
#   '会同',
#   '中国',
#   '烹饪',
#   '协会',
#   '保护',
#   '中国',
#   '火锅',
#   '域名',
#   '重庆火锅',
#   '是否',
#   '侵权',
#   '进行',
#   '沟通',
#   '探讨',
#   '维权',
#   '可行性',
#   '媒体',
#   '部分',
#   '超女',
#   '中文',
#   'CN',
#   '中文',
#   '域名',
#   '离奇',
#   '服务',
#   '爬虫',
#   '事件',
#   '传出',
#   '索尔列恩兹',
#   '公司',
#   '电影',
#   '指环王',
#   '品牌',
#   '形象',
#   '拥有',
#   '国际',
#   '经济',
#   '贸易',
#   '仲裁',
#   '委员会',
#   '域名',
#   '争议',
#   '解决',
#   '中心',
#   '申请',
#   '仲裁',
#   '指环王',
#   'CN',
#   '归属',
#   '域名',
#   '争议',
#   '解决',
#   '办法',
#   '生效',
#   '一天',
#   '可口可乐',
#   '代表',
#   '埃克森',
#   '雀巢',
#   '羽西',
#   '托福',
#   '国际',
#   '品牌',
#   '扎堆',
#   '追讨',
#   'CN',
#   '中文',
#   '域名',
#   '年初',
#   '中文',
#   '域名',
#   '风波',
#   '不断',
#   '太多',
#   '企业',
#   '品牌',
#   '资产',
#   '管理',
#   '层面',
#   '远未',
#   '真正',
#   '准备好',
#   '适应',
#   '网络',
#   '经济',
#   '时代',
#   '到来',
#   '注册',
#   '保护',
#   '应用',
#   'CN',
#   '刻不容缓',
#   '年底',
#   '微软',
#   '宣布',
#   'IE7.0',
#   '全面',
#   '支持',
#   '中文',
#   '域名',
#   '尤其',
#   '中文',
#   '上网',
#   '时代',
#   '大前提',
#   '注册',
#   '保护',
#   '应用',
#   'CN',
#   '中文',
#   '域名',
#   '已经',
#   '大势所趋',
#   'GOOGLE',
#   '宣布',
#   '启用',
#   '中文',
#   '名称',
#   '谷歌',
#   '年底',
#   '抢注',
#   '古歌',
#   'CN',
#   '月前',
#   '抢注',
#   '谷歌',
#   'CN',
#   '当天',
#   '极易',
#   '输入',
#   '产生',
#   '失误',
#   '谷哥',
#   'CN',
#   '抢注',
#   '不能',
#   'GOOGLE',
#   '本土化',
#   '网络',
#   '品牌',
#   '把握',
#   '百密一疏',
#   '业内',
#   '专家',
#   '强调',
#   '中文',
#   '上网',
#   '时代',
#   '中文',
#   'CN',
#   '中文',
#   '域名',
#   '品牌',
#   '资产',
#   '注册',
#   '保护',
#   '应用',
#   '同样',
#   '拿出',
#   '传统',
#   '经济',
#   '领域',
#   '全面',
#   '细致',
#   '精神',
#   '企业',
#   '知名',
#   '品牌',
#   '专利',
#   '技术',
#   '特色',
#   '产品',
#   '进行',
#   '全面',
#   '中文',
#   'CN',
#   '中文',
#   '域名',
#   '注册',
#   '保护',
#   '亦要',
#   '可能',
#   '产生',
#   '误解',
#   '歧义',
#   '词汇',
#   '进行',
#   '注册',
#   '能够',
#   '企业',
#   '互联网',
#   '经济',
#   '时代',
#   '品牌',
#   '发展',
#   '编织',
#   '一道',
#   '全面',
#   '防护网',
#   '能够',
#   '企业',
#   '今后',
#   '网络',
#   '品牌',
#   '发展',
#   '创造',
#   '良好',
#   '网络',
#   '基础',
#   '环境'],
#  ['所谓',
#   'IP',
#   '主叫',
#   '业务',
#   '全名',
#   '应该',
#   'IP',
#   '主叫',
#   '识别',
#   '业务',
#   '用户',
#   '电话',
#   '号码',
#   '识别码',
#   '拨打',
#   'IP',
#   '电话',
#   'IP',
#   '电话卡',
#   '都要先',
#   '拨打',
#   '账号',
#   '密码',
#   '达成',
#   '数字',
#   '数字',
#   '其实',
#   'IP',
#   '电话卡',
#   '识别',
#   'IP',
#   '主叫',
#   '号码',
#   '利用',
#   '用户',
#   '固定',
#   '电话',
#   '号码',
#   '识别',
#   '方某',
#   '用户',
#   '家里',
#   '电话',
#   '电话',
#   '拨打',
#   '电话',
#   '电话局',
#   '知道',
#   '号码',
#   '曾经',
#   '拨打',
#   '收取',
#   '相应',
#   '费用',
#   '好处',
#   '使用',
#   '方便',
#   '过去',
#   '使用',
#   'IP',
#   '打电话',
#   '输入',
#   '账号',
#   '再加',
#   '密码',
#   '不好',
#   '中途',
#   '数字',
#   '需要',
#   '挂断',
#   '如今',
#   '不用',
#   '记住',
#   '密码',
#   '需要',
#   '记住',
#   '直接',
#   '拨打',
#   '购买',
#   '方便',
#   '购买',
#   '方便',
#   'IP',
#   '主叫',
#   '电话',
#   '付费',
#   '用户',
#   '拨打',
#   '没有',
#   '购买',
#   '过程',
#   '电话费',
#   '一并',
#   '省去',
#   '用户',
#   '麻烦',
#   '回顾',
#   'IP',
#   '市场',
#   '争夺',
#   '情况',
#   '发现',
#   'IP',
#   '市场',
#   '目前',
#   '电信业',
#   '争夺',
#   '最为',
#   '激烈',
#   '竞争',
#   '最为',
#   '充分',
#   '领域',
#   '目前',
#   'IP',
#   '主叫',
#   '电话',
#   '已经',
#   '方便',
#   '拨号',
#   '接入',
#   '良好',
#   '话音',
#   '质量',
#   '合理',
#   '资费',
#   '标准',
#   '吸引',
#   '家庭',
#   '用户',
#   '越来越',
#   '中小企业',
#   '选用',
#   'IP',
#   '主叫',
#   '电话',
#   '业务',
#   '处于',
#   '成本',
#   '考虑',
#   '看中',
#   'IP',
#   '主叫',
#   '电话',
#   '方便',
#   '拨打',
#   '付费',
#   '优点',
#   '方面',
#   '原因',
#   '综合',
#   '起来',
#   'IP',
#   '主叫',
#   '电话',
#   '无疑',
#   '成为',
#   '未来',
#   'IP',
#   '电话',
#   '发展',
#   '最终',
#   '方向'],
#  ['八公',
#   '小学',
#   '宣传',
#   '活动',
#   '答疑',
#   '枫阳',
#   '中学',
#   '布置',
#   '宣传',
#   '发放',
#   '宣传',
#   '材料',
#   '贵州',
#   '黄果树',
#   '瀑布',
#   '贵阳',
#   '誉为',
#   '春城',
#   '如今',
#   '林城',
#   '美名',
#   '森林',
#   '简称',
#   '贵阳市',
#   '位于',
#   '贵州省',
#   '中部',
#   '云贵高原',
#   '东斜',
#   '地带',
#   '市中心',
#   '平均',
#   '海拔',
#   '严寒',
#   '夏无',
#   '酷暑',
#   '行政区域',
#   '现有',
#   '林地',
#   '面积',
#   '森林',
#   '覆盖率',
#   '31.7%',
#   '市区',
#   '四周',
#   '群山',
#   '环抱',
#   '林木',
#   '长逾',
#   '环城',
#   '林带',
#   '贵阳市',
#   '提供',
#   '绿色',
#   '生态',
#   '屏障',
#   '投资',
#   '人民币',
#   '总长',
#   '面积',
#   '环城',
#   '林带',
#   '正在',
#   '建设',
#   '贵阳',
#   '可谓',
#   '林中之',
#   '樟树',
#   '竹子',
#   '贵阳',
#   '市树',
#   '世界',
#   '森林',
#   '以往',
#   '植树',
#   '表达',
#   '森林',
#   '重视',
#   '而今',
#   '植树',
#   '世界',
#   '森林',
#   '广泛',
#   '关注',
#   '森林',
#   '民生',
#   '更深',
#   '层次',
#   '本质',
#   '问题',
#   '国家',
#   '未来',
#   '青少年',
#   '更好',
#   '认识',
#   '身边',
#   '朋友',
#   '森林',
#   '贵州省',
#   '林科院',
#   '枫阳',
#   '中学',
#   '八公',
#   '小学',
#   '开展',
#   '世界',
#   '森林',
#   '宣传',
#   '活动',
#   '活动',
#   '既有',
#   '展示',
#   '讲解',
#   '森林',
#   '内容',
#   '有助于',
#   '森林',
#   '和谐',
#   '相处',
#   '贵州省',
#   '林科院',
#   '首批',
#   '全国',
#   '林业',
#   '基地',
#   '扎实',
#   '工作',
#   '森林',
#   '之间',
#   '架设',
#   '友谊',
#   '桥梁',
#   '相关',
#   '介绍',
#   '贵州省',
#   '地处',
#   '云贵',
#   '高原',
#   '地貌',
#   '属于',
#   '中国',
#   '西部',
#   '高原',
#   '山地',
#   '平均',
#   '海拔',
#   '面积',
#   '全国',
#   '1.8%',
#   '素有',
#   '一分田',
#   '92.5%',
#   '面积',
#   '山地',
#   '丘陵',
#   '植被',
#   '空间',
#   '分布',
#   '表现',
#   '明显',
#   '过渡性',
#   '植被',
#   '类型',
#   '地理',
#   '分布',
#   '相互',
#   '重叠',
#   '植被',
#   '类型',
#   '组合',
#   '变得',
#   '复杂',
#   '多样',
#   '贵州',
#   '位于',
#   '世界',
#   '喀斯特',
#   '三大',
#   '最大',
#   '东亚',
#   '中心',
#   '喀斯',
#   '面积',
#   '全省',
#   '国土',
#   '面积',
#   '61.9%',
#   '喀斯特',
#   '峰林',
#   '峰丛',
#   '峡谷',
#   '溶洞',
#   '洞穴',
#   '沉淀',
#   '形态',
#   '构成',
#   '绚丽',
#   '奇特',
#   '不可',
#   '再生',
#   '自然',
#   '遗产',
#   '属于',
#   '全人类',
#   '共同',
#   '财富',
#   '喀斯特地貌',
#   '多民族',
#   '聚居',
#   '贵州',
#   '具有',
#   '文化',
#   '特点',
#   '年末',
#   '全省',
#   '民族',
#   '成份',
#   '少数民族',
#   '人口',
#   '全省',
#   '总人口',
#   '37.9%',
#   '全省',
#   '动物',
#   '资源',
#   '余种',
#   '金丝猴',
#   '黑叶猴',
#   '华南虎',
#   '云豹',
#   '黑颈鹤',
#   '中华',
#   '秋沙鸭',
#   '金雕',
#   '白肩雕',
#   '白尾海',
#   '白头鹤',
#   '列为',
#   '国家',
#   '保护',
#   '动物',
#   '占全国',
#   '同类',
#   '动物',
#   '总数',
#   '13%',
#   '国家',
#   '保护',
#   '动物',
#   '穿山甲',
#   '黑熊',
#   '水獭',
#   '灵猫',
#   '小灵猫',
#   '林麝',
#   '白冠',
#   '长尾',
#   '红腹锦鸡',
#   '占全国',
#   '同类',
#   '动物',
#   '总数',
#   '25.7%',
#   '全省',
#   '珍稀',
#   '植物',
#   '列入',
#   '国家',
#   '珍稀',
#   '濒危',
#   '保护',
#   '植物',
#   '名录',
#   '银杉',
#   '珙桐',
#   '秃杉',
#   '桫椤',
#   '种属',
#   '国家',
#   '保护',
#   '植物',
#   '占全国',
#   '同类',
#   '植物',
#   '总数',
#   '50%',
#   '全省',
#   '野生植物',
#   '资源',
#   '余种',
#   '植物',
#   '资源',
#   '余种',
#   '占全国',
#   '中草药',
#   '品种',
#   '80%',
#   '全国',
#   '四大',
#   '中药材',
#   '产区',
#   '贵州',
#   '旅游',
#   '资源',
#   '丰富',
#   '闻名',
#   '世界',
#   '黄果树',
#   '瀑布',
#   '龙宫',
#   '织金',
#   '马岭河',
#   '峡谷',
#   '风景',
#   '名胜区',
#   '铜仁',
#   '梵净山',
#   '茂兰喀斯特',
#   '森林',
#   '赤水',
#   '桫椤',
#   '威宁',
#   '草海',
#   '自然保护区',
#   '犹如',
#   '璀灿',
#   '宝石',
#   '令人',
#   '目不暇接',
#   '流连忘返',
#   '自然',
#   '原因',
#   '水土',
#   '流失',
#   '问题',
#   '特别',
#   '石漠化',
#   '问题',
#   '倍受',
#   '关注',
#   '全国',
#   '土壤侵蚀',
#   '遥感',
#   '普查',
#   '全省',
#   '水土流失',
#   '面积',
#   '全省',
#   '面积',
#   '41.5%',
#   '全省',
#   '森林',
#   '面积',
#   '森林',
#   '覆盖率',
#   '24%',
#   '人均',
#   '森林',
#   '面积',
#   '森林',
#   '蓄积量',
#   '参考',
#   '资料',
#   '1',
#   '贵州省政府',
#   '2',
#   '贵阳市政府',
#   '3',
#   '国家林业局',
#   '中国林业',
#   '统计',
#   '年鉴',
#   '北京',
#   '中国林业出版社',
#   '图片',
#   '来源',
#   '1',
#   '邓伦',
#   '贵州省',
#   '林业',
#   '科学',
#   '研究院',
#   '2',
#   '中国林学会'],
#  ['摘要',
#   '中央国家机关',
#   '工会',
#   '联合会',
#   '授予',
#   '外交部领事司',
#   '农业部',
#   '兽医局',
#   '中科院',
#   '联想',
#   '集团',
#   '都灵',
#   '冬奥会',
#   '技术',
#   '保障',
#   '团队',
#   '国家',
#   '海洋局',
#   '雪龙',
#   '极地',
#   '考察',
#   '先进',
#   '集体',
#   '中央国家机关',
#   '五一劳动',
#   '奖状',
#   '中央国家机关',
#   '工会',
#   '联合会',
#   '联想',
#   '集团',
#   '召开',
#   '五一劳动',
#   '奖状',
#   '先进',
#   '集体',
#   '表彰',
#   '大会',
#   '表彰',
#   '时期',
#   '工作',
#   '岗位',
#   '做出',
#   '突出',
#   '贡献',
#   '社会上',
#   '引起',
#   '较大',
#   '反响',
#   '先进',
#   '集体',
#   '授予',
#   '外交部领事司',
#   '农业部',
#   '兽医局',
#   '中科院',
#   '联想',
#   '集团',
#   '都灵',
#   '冬奥会',
#   '技术',
#   '保障',
#   '团队',
#   '国家',
#   '海洋局',
#   '雪龙',
#   '极地',
#   '考察',
#   '先进',
#   '集体',
#   '中央国家机关',
#   '五一劳动',
#   '奖状',
#   '中央',
#   '国家机关',
#   '工委',
#   '副书记',
#   '中央国家机关',
#   '工会',
#   '联合会',
#   '主席',
#   '黄燕明',
#   '出席',
#   '大会',
#   '先进',
#   '集体',
#   '颁奖',
#   '中央',
#   '国家机关',
#   '部门',
#   '机关',
#   '工会',
#   '主席',
#   '受表彰',
#   '集体',
#   '代表',
#   '参加',
#   '表彰会',
#   '受',
#   '表彰',
#   '集体',
#   '外交部领事司',
#   '印度洋',
#   '海啸',
#   '所罗门群岛',
#   '撤侨',
#   '中国',
#   '公民',
#   '非洲',
#   '重大',
#   '事件',
#   '案件',
#   '及时',
#   '应对',
#   '妥善',
#   '处理',
#   '最大限度',
#   '保护',
#   '境外',
#   '中国',
#   '公民',
#   '法人',
#   '合法',
#   '权益',
#   '农业部',
#   '兽医局',
#   '面对',
#   '突发',
#   '致病性',
#   '禽流感',
#   '疫情',
#   '时间',
#   '组织',
#   '督察',
#   '专家组',
#   '赶赴',
#   '现场',
#   '坚决',
#   '疫情',
#   '消灭',
#   '疫点',
#   '成功',
#   '组织',
#   '研制出',
#   '疫苗',
#   '保护',
#   '人民',
#   '群众',
#   '生命',
#   '安全',
#   '中科院',
#   '联想',
#   '集团',
#   '都灵',
#   '冬奥会',
#   '技术',
#   '服务',
#   '保障',
#   '团队',
#   '恶劣',
#   '气候',
#   '条件',
#   '出色',
#   '完成',
#   '奥运会',
#   '比赛',
#   '技术',
#   '服务',
#   '保障',
#   '任务',
#   '国际上',
#   '提供',
#   '科技',
#   '服务',
#   '平台',
#   '得到',
#   '国际',
#   '奥委会',
#   '高度',
#   '赞誉',
#   '祖国',
#   '赢得',
#   '奥运',
#   '史上',
#   '具有',
#   '特殊',
#   '意义',
#   '金牌',
#   '雪龙',
#   '极地',
#   '考察',
#   '年来',
#   '先后',
#   '完成',
#   '南极',
#   '科学',
#   '考察',
#   '北极',
#   '科学',
#   '考察',
#   '任务',
#   '创下',
#   '中国',
#   '航海',
#   '史上多',
#   '纪录',
#   '探索',
#   '极地',
#   '科学',
#   '弘扬',
#   '民族',
#   '精神',
#   '维护',
#   '国家',
#   '权益',
#   '做出',
#   '突出',
#   '贡献',
#   '中央国家机关',
#   '工会',
#   '联合会',
#   '号召',
#   '中央',
#   '国家机关',
#   '职工',
#   '表彰',
#   '先进',
#   '集体',
#   '同志',
#   '榜样',
#   '认真',
#   '学习',
#   '以人为本',
#   '一心',
#   '为民',
#   '临危',
#   '受命',
#   '勇于',
#   '担当',
#   '迎难而上',
#   '锐意',
#   '创新',
#   '团结',
#   '协作',
#   '无私奉献',
#   '精益求精',
#   '争光',
#   '精神',
#   '品质',
#   '作风',
#   '主力军',
#   '和谐',
#   '小康',
#   '实现',
#   '规划',
#   '构建',
#   '社会主义',
#   '和谐',
#   '社会',
#   '做出',
#   '新的',
#   '贡献',
#   '表彰',
#   '会上',
#   '联想',
#   '集团',
#   '董事局',
#   '主席',
#   '杨元庆',
#   '颁发',
#   '全国',
#   '五一劳动奖章'],
#  ['缝纫机',
#   '电子管',
#   '收音机',
#   '飞鸽',
#   '自行车',
#   '电视机',
#   '；还有',
#   '英特尔',
#   'reg',
#   '欢跃',
#   '&#8482',
#   '技术',
#   '数字',
#   '家庭',
#   '产品',
#   '看似',
#   '毫无',
#   '关联',
#   '东西',
#   '出现',
#   '北京',
#   '艺术家',
#   '聚集地',
#   '工厂',
#   '出现',
#   '科技',
#   '艺术',
#   '完美',
#   '组合',
#   '标志着',
#   '英特尔',
#   '公司',
#   '导演',
#   '大山子',
#   '艺术节',
#   '精彩',
#   '展览',
#   '序幕',
#   '正式',
#   '拉开',
#   '看似',
#   '不同',
#   '同样',
#   '承载',
#   '心灵',
#   '美好',
#   '生活',
#   '追求',
#   '跨越',
#   '世纪',
#   '代表',
#   '年代',
#   '美好',
#   '生活',
#   '象征',
#   '家庭',
#   '用品',
#   '英特尔',
#   '中国',
#   '有限公司',
#   '举办',
#   '美好',
#   '生活',
#   '三大件',
#   '艺术展',
#   '成为',
#   '大山子',
#   '艺术节',
#   '特色',
#   '展览',
#   '三大件',
#   '不断',
#   '演变',
#   '已经',
#   '成为',
#   '中国',
#   '人民',
#   '生活',
#   '水平',
#   '不断',
#   '发展',
#   '标志',
#   '记录',
#   '追求',
#   '美好',
#   '生活',
#   '足迹',
#   '唤起',
#   '心灵',
#   '深处',
#   '家里',
#   '拥有',
#   '大件',
#   '激动',
#   '自豪',
#   '激发',
#   '未来',
#   '美好',
#   '生活',
#   '憧憬',
#   '从',
#   '上个世纪',
#   '七十年代',
#   '手表',
#   '缝纫机',
#   '自行车',
#   '八十年代',
#   '彩电',
#   '冰箱',
#   '洗衣机',
#   '九十年代',
#   '寻呼机',
#   '手机',
#   '电脑',
#   '一直',
#   '现在',
#   '房子',
#   '车子',
#   '数字',
#   '家庭',
#   '产品',
#   '三大件',
#   '一直',
#   '中国',
#   '人民',
#   '心里',
#   '情节',
#   '支撑',
#   '不断',
#   '追求',
#   '美好',
#   '生活',
#   '原动力',
#   '同三',
#   '大件',
#   '变迁',
#   '早期',
#   '奔腾',
#   'reg',
#   '迅驰',
#   '&#8482',
#   '移动',
#   '技术',
#   '一直',
#   '今天',
#   '英特尔',
#   'reg',
#   '欢跃',
#   '&#8482',
#   '技术',
#   '数字',
#   '家庭',
#   '产品',
#   '英特尔',
#   '每一次',
#   '努力',
#   '无不',
#   '伴随',
#   '迈向',
#   '美好',
#   '生活',
#   '脚步',
#   '科技',
#   '赋予',
#   '更加',
#   '精彩',
#   '生活',
#   '工作',
#   '娱乐',
#   '今天',
#   '英特尔',
#   '欢跃',
#   '技术',
#   '沙发',
#   '探索',
#   '娱乐',
#   '乐趣',
#   '轻松',
#   '游戏',
#   '数字',
#   '娱乐',
#   '王国',
#   '享受',
#   '最新',
#   '美好',
#   '生活',
#   '香醇',
#   '惬意'],
#  ['形象',
#   '战略',
#   '苏宁',
#   '重装',
#   '珠江路',
#   '体验',
#   '国际',
#   '高科技',
#   '新店',
#   '开张',
#   '重装',
#   '开业',
#   '成为',
#   '商家',
#   '固定',
#   '营销',
#   '手段',
#   '黄金周',
#   '消费',
#   '旺季',
#   '更是',
#   '商家',
#   '开业',
#   '首选',
#   '黄道吉日',
#   '形象',
#   '开业',
#   '酬宾',
#   '活动',
#   '取得',
#   '轰动',
#   '效应',
#   '成功',
#   '打开',
#   '市场',
#   '局面',
#   '改造',
#   '苏宁',
#   '珠江路',
#   '终于',
#   '掀起',
#   '盖头',
#   '常规',
#   '综合',
#   '家电',
#   '卖场',
#   '迥然不同',
#   '区别于',
#   '珠江路',
#   '普通',
#   '卖场',
#   '卖场',
#   '基础上',
#   '升级版',
#   '最大',
#   '特征',
#   '人性',
#   '设计',
#   '布局',
#   '完全',
#   '消费者',
#   '需求',
#   '出发',
#   '部分',
#   '变动',
#   '借鉴',
#   '传统',
#   '百货',
#   '连锁',
#   '卖场',
#   '优势',
#   '避免',
#   '大卖场',
#   '重复',
#   '浪费',
#   '卖场',
#   '采用',
#   '先进',
#   '信息技术',
#   '引进',
#   'ＲＰ',
#   '系统',
#   '感应',
#   '防盗',
#   '系统',
#   '消费者',
#   '充分',
#   '体验',
#   '现代',
#   '高科技',
#   '珠江路',
#   '卖场',
#   '斥资',
#   '设置',
#   'ｉｎｔｅｌ',
#   '体验',
#   '全国',
#   '体验',
#   '独此一家',
#   '网络',
#   '战略',
#   '国美',
#   '网上商城',
#   '狂飙',
#   '红眼',
#   '购物',
#   '热潮',
#   '五一',
#   '国内',
#   '电子',
#   '商务',
#   '网站',
#   '已经',
#   '摩拳擦掌',
#   '酝酿',
#   '新一轮',
#   '降价',
#   '狂潮',
#   '近来',
#   '国美',
#   '电器',
#   '全国',
#   '网上',
#   '商城',
#   '狂飙',
#   '红眼',
#   '购物',
#   '热潮',
#   '据悉',
#   '五一',
#   '前夜',
#   '国美',
#   '网上',
#   '商城',
#   '红眼',
#   '航班',
#   '再度',
#   '启航',
#   '打开',
#   '国美',
#   '电器',
#   '公司',
#   '官方',
#   '电子',
#   '商务',
#   '网站',
#   'ｗｗｗ',
#   'ｇｏｍｅ',
#   'ｏｍ',
#   'ｃｎ',
#   '全屏',
#   '广告',
#   '立即',
#   '呈现',
#   '记者',
#   '眼前',
#   '繁星',
#   '点点',
#   '黑色',
#   '夜幕',
#   '背景',
#   '购物',
#   '狂欢节',
#   '提前',
#   '揭幕',
#   '国美',
#   '电器',
#   '网站',
#   '负责人',
#   '介绍',
#   '国美',
#   '网上',
#   '商城',
#   '四月',
#   '网购',
#   '纷呈',
#   '主题',
#   '促销',
#   '活动',
#   '团购',
#   '砍价',
#   '招募',
#   '全国',
#   '网络',
#   '集采',
#   '家电',
#   '网络',
#   '套餐',
#   '手机',
#   '展销会',
#   '回馈',
#   '消费者',
#   '家电',
#   '拍卖',
#   '几乎',
#   '网络',
#   '营销',
#   '促销',
#   '项目',
#   '此起彼伏',
#   '配以',
#   '网络',
#   '媒体',
#   '搜索引擎',
#   '形式',
#   '互联网',
#   '广告',
#   '宣传',
#   '国美',
#   '网上商城',
#   '全国',
#   '销售额',
#   '增势',
#   '明显',
#   '达到',
#   '提前',
#   '透支',
#   '五一',
#   '家电',
#   '市场',
#   '份额',
#   '目的',
#   '营销',
#   '战略',
#   '永乐',
#   '推出',
#   '新人',
#   '家电',
#   '特选',
#   '套餐',
#   '本报讯',
#   '通讯员',
#   '北',
#   '似乎',
#   '吉利',
#   '年头',
#   '情侣',
#   '选择',
#   '完成',
#   '终身大事',
#   '部门',
#   '预计',
#   '今年',
#   '五一',
#   '黄金周',
#   '期间',
#   '婚庆',
#   '高峰期',
#   '家电',
#   '零售',
#   '瞄准',
#   '商机',
#   '新人',
#   '量身',
#   '新人',
#   '新家',
#   '家电',
#   '套餐',
#   '本',
#   '周末',
#   '永乐',
#   '生活',
#   '电器',
#   '隆重',
#   '推出',
#   '主题',
#   '五一',
#   '家电',
#   '品牌',
#   '全线',
#   '特卖会',
#   '底价',
#   '活动',
#   '甜蜜',
#   '奔走',
#   '家电',
#   '卖场',
#   '新婚',
#   '爱侣',
#   '打造',
#   '家电',
#   '采购',
#   '绝对',
#   '手册',
#   '活动',
#   '永乐',
#   '推出',
#   '等离子',
#   '液晶',
#   '冰洗',
#   '空调',
#   '小家电',
#   '厨卫',
#   '音响',
#   '数码',
#   '手机',
#   '品类',
#   '产品',
#   '南京',
#   '永乐',
#   '电器',
#   '卖场',
#   '开展',
#   '促销',
#   '活动',
#   '海尔',
#   '西门子',
#   '三星',
#   '松下',
#   '三星',
#   '格力',
#   '海信',
#   '伊莱克斯',
#   '大金',
#   '家电',
#   '厂商',
#   '新品',
#   '平价',
#   '销售',
#   '支持',
#   '活动',
#   '了解',
#   '全面',
#   '促销',
#   '最高',
#   '让利',
#   '幅度',
#   '部分',
#   '商品',
#   '套餐',
#   '最高',
#   '让利',
#   '让利',
#   '幅度',
#   '达到',
#   '永乐',
#   '电器',
#   '打造',
#   '实惠',
#   '诱人',
#   '活动',
#   '套餐',
#   '抢购',
#   '新品',
#   '特惠',
#   '惊喜',
#   '赠送',
#   '抽奖',
#   '参加',
#   '活动',
#   '新人',
#   '推荐',
#   '居室',
#   '必备',
#   '大小',
#   '家电',
#   '永乐',
#   '电器',
#   '相关',
#   '负责人',
#   '表示',
#   '新婚',
#   '装修',
#   '消费者',
#   '家电',
#   '销售额',
#   '永乐',
#   '总体',
#   '销售额',
#   '忙碌',
#   '新婚',
#   '家电',
#   '消费者',
#   '省心',
#   '省力',
#   '省钱',
#   '实在',
#   '三大',
#   '愿望',
#   '文化',
#   '战略',
#   '五星',
#   '举行',
#   '百年',
#   '家电',
#   '广告',
#   '黄金周',
#   '期间',
#   '南京',
#   '商家',
#   '掀起',
#   '一浪高过一浪',
#   '促销',
#   '特卖',
#   '今年',
#   '增加',
#   '较多',
#   '文化',
#   '元素',
#   '购物',
#   '消费',
#   '增添',
#   '休闲',
#   '调剂',
#   '佐料',
#   '从',
#   '五星',
#   '电器',
#   '全国',
#   '城市',
#   '卖场',
#   '黄金',
#   '位置',
#   '隆重',
#   '推出',
#   '五星',
#   '精心',
#   '准备',
#   '百年',
#   '家电',
#   '广告',
#   '集中',
#   '展示',
#   '世界',
#   '家电',
#   '广告',
#   '图片',
#   '完整',
#   '演绎',
#   '家电',
#   '产品',
#   '技术',
#   '发展',
#   '市民',
#   '艺术',
#   '盛宴',
#   '五星',
#   '特意',
#   '精心',
#   '准备',
#   '百年',
#   '家电',
#   '广告',
#   '主题',
#   '明信片',
#   '免费',
#   '馈赠',
#   '消费者',
#   '在',
#   '展出',
#   '广告',
#   '出自',
#   '欧洲',
#   '亚洲',
#   '设计师',
#   '风格各异',
#   '设计',
#   '精巧',
#   '构思',
#   '大胆',
#   '出彩',
#   '色彩',
#   '运用',
#   '值得',
#   '欣赏',
#   '价值',
#   '电器',
#   '发展史',
#   '不仅仅',
#   '一部',
#   '人类',
#   '科学技术',
#   '进步',
#   '一部',
#   '人类',
#   '文化',
#   '发展史',
#   '品牌',
#   '战略',
#   '大',
#   '一天',
#   '新增',
#   '品牌',
#   '酒香',
#   '巷子',
#   '一前',
#   '商场',
#   '营销',
#   '达到',
#   '极致',
#   '新颖',
#   '独特',
#   '花样翻新',
#   '不断',
#   '引进',
#   '品牌',
#   '商家',
#   '招徕',
#   '人气',
#   '手段',
#   '记者',
#   '大洋百货',
#   '了解到',
#   '五一',
#   '期间',
#   '一楼',
#   '美食城',
#   '新增',
#   '四大',
#   '食品',
#   '永年丰',
#   '牛肉面',
#   '麻辣烫',
#   '香竹',
#   '关东',
#   '章鱼',
#   '丸子',
#   '大洋',
#   '百货',
#   '台资',
#   '背景',
#   '新增',
#   '几大',
#   '美食',
#   '台湾',
#   '品牌',
#   '黄金周',
#   '大洋',
#   '服饰',
#   '品牌',
#   '力气',
#   '新增',
#   'ｅｒｏｍｏｄｅ',
#   '品牌',
#   '姐妹',
#   '品牌',
#   'ｏｎｌｙ',
#   '重新',
#   '改装',
#   '面积',
#   '增加',
#   '成为',
#   '华东',
#   '地区',
#   '最大',
#   '旗舰店',
#   '；大',
#   '继续',
#   '加大',
#   '职业',
#   '淑女装',
#   '品牌',
#   '力度',
#   'ｌａｎｄ',
#   '品牌',
#   '之后',
#   '引进',
#   'ｌａｎｄ',
#   '公司',
#   '旗下',
#   '小熊维尼',
#   '内衣',
#   'ｂｌｉｎ',
#   '了解',
#   '品牌',
#   '南京',
#   '独此一家',
#   '近期',
#   '华联',
#   '服饰',
#   '有限公司',
#   '品牌',
#   '脑筋',
#   '华联',
#   '女装',
#   '开辟',
#   'ＬＶ',
#   'ＩＬＬ',
#   '贝拉维拉',
#   '特惠',
#   '集中',
#   '贝位',
#   '维拉',
#   '四大',
#   '品牌',
#   'ＬＶ',
#   'ＩＬＬ',
#   '小贝',
#   'ＬＶ',
#   'ＩＬ',
#   'ＬＬ',
#   'ＴＩ',
#   '大贝',
#   'ＬＶ',
#   'ＩＬＬ',
#   'ＬＶ',
#   'ＩＬＬ',
#   'Ｔ',
#   '了解',
#   '贝拉维拉',
#   '法国',
#   '时尚',
#   '品牌',
#   '南京',
#   '金鹰',
#   '金陵',
#   '百货',
#   '专柜',
#   '市区',
#   '专卖店',
#   '特惠',
#   '形式',
#   '华联商厦',
#   '价格',
#   '战略',
#   '华诚',
#   '超市',
#   '百类',
#   '商品',
#   '降价',
#   '昨',
#   '记者',
#   '华诚',
#   '超市',
#   '获悉',
#   '五一',
#   '期间',
#   '华诚',
#   '南京',
#   '超市',
#   '社区',
#   '便利店',
#   '不同',
#   '程度',
#   '优惠',
#   '优惠',
#   '让利',
#   '幅度',
#   '据',
#   '了解',
#   '华诚',
#   '大卖场',
#   '几十',
#   '品类',
#   '百种',
#   '商品',
#   '降价',
#   '千种',
#   '商品',
#   '降价',
#   '指定',
#   '门店',
#   '消费者',
#   '机会',
#   '获赠',
#   '碧纯',
#   '饮料',
#   '指定',
#   '门店',
#   '购买',
#   '前排',
#   '大肠',
#   '荔枝',
#   '消费者',
#   '享受',
#   '方便',
#   '消费者',
#   '公司',
#   '五一',
#   '期间',
#   '消费',
#   '免费',
#   '提供',
#   '方便',
#   '塑料',
#   '具体',
#   '促销',
#   '价格',
#   '华诚',
#   '超市',
#   '店堂',
#   '海报',
#   '刊登',
#   '抱团',
#   '战略',
#   '百安居',
#   '携手',
#   '招行',
#   '首推',
#   '家装',
#   '零首付',
#   '建材',
#   '超市',
#   '老大',
#   '百安居',
#   '联手',
#   '国内',
#   '信用卡',
#   '老大',
#   '招商',
#   '银行',
#   '推出',
#   '最高',
#   '延期',
#   '分期付款',
#   '装潢',
#   '项目',
#   '百安居',
#   '成为',
#   '目前',
#   '国内',
#   '一家',
#   '提供',
#   '家装',
#   '零首付',
#   '建材',
#   '超市',
#   '据介绍',
#   '名为',
#   '家装',
#   '分期付款',
#   '业务',
#   '百安居',
#   '招商',
#   '银行',
#   '联合',
#   '推出',
#   '专门',
#   '服务',
#   '准备',
#   '进行',
#   '装修',
#   '消费者',
#   '消费者',
#   '持有',
#   '招商',
#   '银行',
#   '信用卡',
#   '百安居',
#   '装潢',
#   '中心',
#   '进行',
#   '房屋',
#   '装修',
#   '付款',
#   '享受',
#   '待遇',
#   '不用',
#   '马上',
#   '掏腰包',
#   '延期',
#   '买单',
#   '享受',
#   '最长',
#   '分期',
#   '还款',
#   '便利',
#   '购房',
#   '消费者',
#   '付款',
#   '最长',
#   '分期',
#   '还款',
#   '理想',
#   '财务',
#   '计划',
#   '极大',
#   '降低',
#   '一次性',
#   '支付',
#   '压力',
#   '增加',
#   '装修',
#   '预算',
#   '新房',
#   '装修',
#   '提升',
#   '层次',
#   '完成',
#   '装修',
#   '提前',
#   '享用',
#   '新房',
#   '记者'],
#  ['世界',
#   '许多人',
#   '超女',
#   '成名',
#   '可称',
#   '流俗',
#   '世界',
#   '反对',
#   '超女',
#   '附丽',
#   '传统',
#   '意识',
#   '话语',
#   '堪称',
#   '作伪',
#   '在',
#   '看来',
#   '反对',
#   '等量',
#   '刘忠德',
#   '先生',
#   '全国',
#   '政协',
#   '常委',
#   '教科文卫体',
#   '委员会',
#   '主任',
#   '外加',
#   '中国演出家协会',
#   '主席',
#   '头衔',
#   '反对',
#   '超女',
#   '建议',
#   '加强',
#   '管制',
#   '并不',
#   '排除',
#   '取缔',
#   '觉得',
#   '太高',
#   '超女',
#   '我',
#   '始终',
#   '超女',
#   '绝对',
#   '没有',
#   '喜欢',
#   '反证',
#   '绝不',
#   '可能',
#   '反对',
#   '超女',
#   '兴趣',
#   '吸引',
#   '眼球',
#   '吸引',
#   '吸引',
#   '创造',
#   '收视率',
#   '收视率',
#   '经济',
#   '表演',
#   '经国之',
#   '大义',
#   '无碍',
#   '文化',
#   '千秋',
#   '表演',
#   '自然',
#   '丑有好',
#   '选秀',
#   '难免',
#   '良莠不齐',
#   '社会',
#   '精神',
#   '没有',
#   '虚弱',
#   '病菌',
#   '经不起',
#   '超女',
#   '流俗',
#   '自然',
#   '宽恕',
#   '不拿',
#   '投票',
#   '再劝',
#   '身边',
#   '投票',
#   '超女',
#   '出现',
#   '时代',
#   '产物',
#   '应该',
#   '看到',
#   '现象',
#   '过去',
#   '传统',
#   '拘谨',
#   '话语',
#   '消解',
#   '过去',
#   '精英',
#   '话语',
#   '灌输',
#   '说教',
#   '转向',
#   '娱乐',
#   '精英',
#   '转向',
#   '平民',
#   '超女',
#   '市场经济',
#   '培育',
#   '为数众多',
#   '市民',
#   '阶层',
#   '产生',
#   '普遍',
#   '个体',
#   '自觉',
#   '个体',
#   '意识',
#   '之后',
#   '个人',
#   '表现',
#   '支撑',
#   '大众',
#   '娱乐',
#   '狂欢',
#   '释放',
#   '社会',
#   '娱乐',
#   '需要',
#   '迎合',
#   '个体',
#   '意识',
#   '凸现',
#   '娱乐',
#   '倾向',
#   '本质',
#   '大众',
#   '意识',
#   '旨趣',
#   '媒体',
#   '业界',
#   '人士',
#   '惊呼',
#   '受众',
#   '主导',
#   '时代',
#   '已经',
#   '来临',
#   '在',
#   '主导',
#   '之外',
#   '看见',
#   '一种',
#   '思维',
#   '模式',
#   '引导',
#   '中国',
#   '天鹅湖',
#   '新闻',
#   '发布会',
#   '刘忠德',
#   '先生',
#   '表示',
#   '应该',
#   '老百姓',
#   '接触',
#   '高雅',
#   '艺术',
#   '提高',
#   '审美',
# ...
#   '地图',
#   '服务',
#   '微软',
#   '已经',
#   '收购',
#   '一家',
#   '公司',
#   '公司',
#   '产品',
#   '利用',
#   '航拍',
#   '卫星',
#   '照片',
#   '创建',
#   '地图',
#   '微软',
#   '周四',
#   '公布',
#   '收购',
#   'Vexcel',
#   '消息',
#   '没有',
#   '公布',
#   '交易',
#   '相关',
#   '财务',
#   '资料',
#   '微软',
#   '期望',
#   'Vexcel',
#   '产品',
#   '技术',
#   '能够',
#   '强化',
#   'Windows',
#   'Live',
#   'Local',
#   '服务',
#   '用户',
#   '方便',
#   '查找',
#   '企业',
#   '显示',
#   '在线',
#   '地图',
#   'Windows',
#   'Live',
#   'Local',
#   '微软',
#   '竞争',
#   '激烈',
#   '搜索',
#   '在线',
#   '地图',
#   '市场',
#   '推出',
#   '产品',
#   '包括',
#   '微软',
#   '雅虎',
#   'Google',
#   'AOL',
#   'Ask',
#   'com',
#   '搜索',
#   '服务',
#   '提供',
#   '提供',
#   '整合',
#   '在线',
#   '地图',
#   '搜索',
#   '服务',
#   '服务',
#   '吸引',
#   '不断',
#   '增长',
#   '广告',
#   '收入',
#   '有着',
#   '强烈',
#   '兴趣',
#   '搜索',
#   '地图',
#   '服务',
#   '相当于',
#   '互联网',
#   '电话',
#   '号码',
#   '用户',
#   '查找',
#   '地区',
#   '企业',
#   '获得',
#   '行车',
#   '路线',
#   '能够',
#   '获得',
#   '客户',
#   '企业',
#   '评价',
#   '微软',
#   'Windows',
#   'Live',
#   'Local',
#   '有着',
#   '很高',
#   '期望',
#   '希望',
#   '能够',
#   '消费者',
#   '商业',
#   '用户',
#   '提供',
#   '所谓',
#   '体验'],
#  ['据',
#   '美国',
#   '太空',
#   '报道',
#   '今年',
#   '之间',
#   '73P/',
#   '瓦斯',
#   '曼-瓦赫曼',
#   '彗星',
#   '碎片',
#   '对此',
#   '美国',
#   '宇航局',
#   '科学家',
#   '反驳',
#   '碎片',
#   '不会',
#   '撞击',
#   '地球',
#   '不会',
#   '引起',
#   '海啸',
#   '生物',
#   '灭绝',
#   '灾难',
#   '美国',
#   '宇航局',
#   '科学家',
#   '之间',
#   '73P/',
#   '瓦斯',
#   '曼-瓦赫曼',
#   '彗星',
#   '接近',
#   '地球',
#   '轨道',
#   '距离',
#   '地球',
#   '最近',
#   '碎片',
#   '地球',
#   '月球',
#   '距离',
#   '多倍',
#   '根本',
#   '不会',
#   '危险',
#   '存在',
#   '科学家',
#   '提醒',
#   '利用',
#   '机会',
#   '彗星',
#   '进行',
#   '观察',
#   '科学家',
#   '预计',
#   '碎片',
#   '明亮',
#   '碎片',
#   '可能',
#   '直接',
#   '双筒',
#   '望远镜',
#   '肉眼',
#   '观察',
#   'n101'],
#  ['女尸',
#   '曾经',
#   '复活',
#   '齐齐哈尔',
#   '木乃伊',
#   '死因',
#   '之谜',
#   '女尸',
#   '曾经',
#   '复活',
#   '齐齐哈尔',
#   '木乃伊',
#   '死因',
#   '之谜',
#   '年前',
#   '齐齐哈尔',
#   '扎龙',
#   '湿地',
#   '保护',
#   '发现',
#   '神秘',
#   '木乃伊',
#   '木乃伊',
#   '保存',
#   '完整',
#   '来历',
#   '可疑',
#   '湿地',
#   '保存',
#   '木乃伊',
#   '死者',
#   '生前',
#   '究竟',
#   '经历',
#   '当时',
#   '确定',
#   '女性',
#   '身份',
#   '专家',
#   '没有',
#   '找到',
#   '更多',
#   '线索',
#   '专家',
#   '发现',
#   '蛛丝马迹',
#   '隐藏',
#   '木乃伊',
#   '身上',
#   '秘密',
#   '一一',
#   '解开',
#   '挖掘',
#   '木乃伊',
#   '保存',
#   '齐齐哈尔市',
#   '五教',
#   '道德',
#   '冬天',
#   '院子',
#   '充满',
#   '强烈',
#   '寒意',
#   '院落',
#   '杂草',
#   '看门',
#   '管理',
#   '人员',
#   '接待',
#   '记者',
#   '不禁',
#   '毛骨悚然',
#   '木乃伊',
#   '放在',
#   '院子',
#   '最大',
#   '房子',
#   '中间',
#   '管理员',
#   '木乃伊',
#   '扎龙',
#   '展览馆',
#   '后来',
#   '展览馆',
#   '经营不善',
#   '才放',
#   '五教',
#   '道德',
#   '存放',
#   '走进',
#   '房间',
#   '记者',
#   '看到',
#   '玻璃',
#   '水晶',
#   '棺材',
#   '里面',
#   '木乃伊',
#   '身高',
#   '身体',
#   '木炭',
#   '黑色',
#   '面部',
#   '表情',
#   '十分',
#   '狰狞',
#   '四肢',
#   '弯曲',
#   '大腿',
#   '之间',
#   '看到',
#   '黑色',
#   '粘连',
#   '一起',
#   '物质',
#   '管理员',
#   '介绍',
#   '得知',
#   '物质',
#   '木乃伊',
#   '生前',
#   '处理',
#   '胎盘',
#   '仔细',
#   '左手',
#   '左脚',
#   '明显',
#   '残缺',
#   '通常',
#   '看到',
#   '木乃伊',
#   '双手',
#   '合十',
#   '木乃伊',
#   '表面',
#   '似乎',
#   '剧烈',
#   '挣扎',
#   '不免',
#   '木乃伊',
#   '出现',
#   '年代',
#   '身份',
#   '经历',
#   '产生',
#   '猜测',
#   '记者',
#   '找到',
#   '齐齐哈尔市',
#   '文物',
#   '管理站',
#   '副站长',
#   '辛健',
#   '当时',
#   '发现',
#   '见证人',
#   '多年来',
#   '收集',
#   '细节',
#   '发现',
#   '木乃伊',
#   '生前',
#   '轮廓',
#   '是非',
#   '讲述',
#   '变得',
#   '清晰',
#   '起来',
#   '湿地',
#   '干尸',
#   '纯属',
#   '偶然',
#   '湿地',
#   '干尸',
#   '纯属',
#   '偶然',
#   '齐齐哈尔市',
#   '扎龙',
#   '湿地',
#   '保护',
#   '附近',
#   '扎龙',
#   '村民',
#   '修路',
#   '取土',
#   '意外',
#   '发现',
#   '一座',
#   '青砖',
#   '墓室',
#   '发现',
#   '棺材',
#   '棺材',
#   '尸体',
#   '已经',
#   '变成',
#   '木乃伊',
#   '棺材',
#   '尸体',
#   '剩下',
#   '比较',
#   '完整',
#   '头骨',
#   '扎龙',
#   '自然保护区',
#   '位于',
#   '黑龙江省',
#   '齐齐哈尔市',
#   '东南',
#   '芦苇沼泽',
#   '广袤',
#   '湖泊',
#   '星罗棋布',
#   '居住',
#   '鸟类',
#   '更是',
#   '丹顶鹤',
#   '重要',
#   '栖息地',
#   '地理',
#   '常识',
#   '扎龙',
#   '湿地',
#   '保护',
#   '空气',
#   '潮湿',
#   '容易',
#   '滋生',
#   '寄生虫',
#   '微生物',
#   '区域',
#   '棺木',
#   '尸体',
#   '应该',
#   '比较',
#   '容易',
#   '腐烂',
#   '棺木',
#   '保存',
#   '辛',
#   '介绍',
#   '发现',
#   '墓室',
#   '结构',
#   '讲究',
#   '男女',
#   '木棺',
#   '放在',
#   '西侧',
#   '东侧',
#   '中间',
#   '过道',
#   '男性',
#   '木棺',
#   '镶嵌',
#   '没有',
#   '青砖',
#   '坑里',
#   '女性',
#   '木棺',
#   '两端',
#   '中间',
#   '三道',
#   '青砖',
#   '通风',
#   '条件',
#   '很好',
#   '墓室',
#   '封闭性',
#   '很好',
#   '室内',
#   '未见',
#   '据',
#   '辛健',
#   '分析',
#   '垫起',
#   '比较',
#   '干燥',
#   '木乃伊',
#   '生前',
#   '挣扎',
#   '痕迹',
#   '可能',
#   '氧气',
#   '消耗',
#   '殆尽',
#   '留下',
#   '二氧化碳',
#   '体内',
#   '水分',
#   '消耗',
#   '腹内',
#   '器官',
#   '缓慢',
#   '干瘪',
#   '水分',
#   '迅速',
#   '消失',
#   '形成',
#   '现在',
#   '看到',
#   '木乃伊',
#   '木乃伊',
#   '真实',
#   '身份',
#   '存在',
#   '可能',
#   '保存',
#   '完整',
#   '木乃伊',
#   '生前',
#   '究竟',
#   '男',
#   '主人',
#   '官袍',
#   '一块',
#   '补子',
#   '补子',
#   '祥云',
#   '树木',
#   '花草',
#   '山岗',
#   '丘陵',
#   '金钱豹',
#   '动物',
#   '图案',
#   '相关',
#   '资料',
#   '记载',
#   '补服',
#   '武官',
#   '标志',
#   '出土',
#   '铜钱',
#   '饰物',
#   '清代',
#   '乾隆',
#   '年间',
#   '物品',
#   '辛健',
#   '推断',
#   '清代',
#   '墓葬',
#   '至少',
#   '历史',
#   '男性',
#   '干尸',
#   '一位',
#   '武官',
#   '从',
#   '墓室',
#   '结构',
#   '松动',
#   '青砖',
#   '个人',
#   '后来',
#   '合葬',
#   '一起',
#   '男性',
#   '容貌',
#   '观察',
#   '死亡',
#   '年龄',
#   '大约',
#   '之间',
#   '女性',
#   '年龄',
#   '大约',
#   '之间',
#   '推断',
#   '女性',
#   '主人',
#   '可能',
#   '男性',
#   '主人',
#   '大约',
#   '下葬',
#   '女性',
#   '木乃伊',
#   '应该',
#   '男性',
#   '主人',
#   '夫人',
#   '在',
#   '女性',
#   '棺材',
#   '发现',
#   '满文',
#   '黑龙江省',
#   '满语',
#   '研究所',
#   '研究员',
#   '黄锡会',
#   '专门',
#   '研究',
#   '满文',
#   '翻译',
#   '上面',
#   '记载',
#   '诰封',
#   '墨尔根觉罗',
#   '史料',
#   '记载',
#   '满族',
#   '姓氏',
#   '没有',
#   '墨尔根觉罗',
#   '专家',
#   '分析',
#   '确定',
#   '可能',
#   '文字',
#   '标注',
#   '祭地',
#   '赐姓',
#   '女真',
#   '一支',
#   '木乃伊',
#   '真实',
#   '姓名',
#   '无法',
#   '核实',
#   '研究',
#   '专家',
#   '叫做',
#   '孟氏',
#   '中毒',
#   '难产',
#   '中毒',
#   '难产',
#   '记载',
#   '文字',
#   '随葬品',
#   '孟氏',
#   '木乃伊',
#   '留下',
#   '费解',
#   '胎盘',
#   '胎盘',
#   '臀部',
#   '连着',
#   '胎盘',
#   '分明',
#   '看出',
#   '没有',
#   '处理',
#   '辛健',
#   '回忆说',
#   '女性',
#   '干尸',
#   '出土',
#   '主人',
#   '皮肤',
#   '发黄',
#   '头发',
#   '眉毛',
#   '清晰可见',
#   '主人',
#   '脸上',
#   '辨别',
#   '木乃伊',
#   '身上',
#   '出现',
#   '一层',
#   '黄白',
#   '相间',
#   '有点',
#   '生活',
#   '看到',
#   '芥菜',
#   '疙瘩',
#   '表面',
#   '可能',
#   '木乃伊',
#   '体内',
#   '药物',
#   '皮肤',
#   '显现',
#   '一种',
#   '出现',
#   '难道',
#   '药物',
#   '中毒',
#   '木乃伊',
#   '张大',
#   '口里',
#   '文物',
#   '专家',
#   '发现',
#   '牙齿',
#   '左右',
#   '女性',
#   '剩下',
#   '牙齿',
#   '并不',
#   '寻常',
#   '齐齐哈尔市',
#   '医学院',
#   '解剖学',
#   '专家',
#   '医师',
#   '看到',
#   '木乃伊',
#   '认为',
#   '女子',
#   '牙齿',
#   '可能',
#   '体弱多病',
#   '服用',
#   '滋补品',
#   '草药',
#   '制品',
#   '引起',
#   '药物中毒',
#   '中毒',
#   '导致',
#   '部分',
#   '牙齿松动',
#   '脱落',
#   '胎盘',
#   '医师',
#   '分析',
#   '可能',
#   '孟氏',
#   '骨盆',
#   '口角',
#   '比较',
#   '窄小',
#   '分娩',
#   '遇上',
#   '难产',
#   '小时',
#   '痛苦',
#   '拼搏',
#   '之后',
#   '孩子',
#   '终于',
#   '降生',
#   '体弱多病',
#   '再加',
#   '难产',
#   '孟氏',
#   '体力',
#   '支而',
#   '昏死',
#   '过去',
#   '当时',
#   '医疗',
#   '水平',
#   '有限',
#   '也许',
#   '孟氏',
#   '家人',
#   '昏厥',
#   '假死',
#   '认为',
#   '真正',
#   '死亡',
#   '准备',
#   '后事',
#   '造成',
#   '女子',
#   '永久性',
#   '真正',
#   '死亡',
#   '复活',
#   '女尸',
#   '曾经',
#   '复活',
#   '从',
#   '满文',
#   '证明',
#   '孟氏',
#   '满族人',
#   '满族人',
#   '丧葬',
#   '习俗',
#   '家人',
#   '喜欢',
#   '服装',
#   '头饰',
#   '手工',
#   '绣制',
#   '身上',
#   '落叶归根',
#   '故里',
#   '说法',
#   '墓地',
#   '选择',
#   '扎龙',
#   '村南',
#   '月牙形',
#   '土岗',
#   '孟氏',
#   '下葬',
#   '可能',
#   '过度',
#   '颠簸',
#   '过来',
#   '发现',
#   '躺在',
#   '棺材',
#   '用力',
#   '挣扎',
#   '无济于事',
#   '拼命',
#   '挣扎',
#   '活动',
#   '左腿',
#   '捆绑',
#   '丝带',
#   '左脚',
#   '鞋袜',
#   '脱落',
#   '脚趾',
#   '手指',
#   '击打',
#   '棺板',
#   '受伤',
#   '木乃伊',
#   '棺盖',
#   '打开',
#   '专家',
#   '发现',
#   '盖上有',
#   '明显',
#   '抓痕',
#   '左手',
#   '左脚',
#   '明显',
#   '残缺',
#   '辛健',
#   '后来',
#   '推断',
#   '皮外伤',
#   '引起',
#   '感染',
#   '导致',
#   '腐烂',
#   '造成',
#   '时间',
#   '应该',
#   '下葬',
#   '右脚',
#   '深黄色',
#   '素面',
#   '丝绢',
#   '用纸',
#   '鞋底',
#   '圆口',
#   '黑色',
#   '绣花鞋',
#   '左脚',
#   '裸露',
#   '外面',
#   '后在',
#   '棺木',
#   '底部',
#   '左侧',
#   '边角',
#   '找到',
#   '发现',
#   '丝带',
#   '松散',
#   '右腿',
#   '关节',
#   '位置',
#   '孟',
#   '肯定',
#   '答案',
#   '不解',
#   '棺木',
#   '出现',
#   '湿地',
#   '年前',
#   '扎龙',
#   '处于',
#   '政治',
#   '历史',
#   '地位',
#   '专家',
#   '认为',
#   '木乃伊',
#   '出土',
#   '研究',
#   '满族',
#   '部落',
#   '历史',
#   '文化',
#   '提供',
#   '有力',
#   '史料',
#   '目前',
#   '正作',
#   '细致',
#   '研究',
#   '希望',
#   '揭开',
#   '更多',
#   '谜团',
#   '来源',
#   '2'],
#  ['信息产业部',
#   '近日',
#   '公布',
#   '违规',
#   '移动信息',
#   '举报',
#   '电话',
#   '信息产业部',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '010-12300',
#   '北京市',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '010-68212300',
#   '地区',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '直辖市',
#   '省会',
#   '区号',
#   '用户',
#   '登录',
#   '信息',
#   '产业',
#   '网站',
#   'www',
#   'mii',
#   'gov',
#   'cn',
#   '进行',
#   '投诉',
#   '举报',
#   '了解',
#   '信息产业部',
#   '利用',
#   '左右',
#   '时间',
#   '全国',
#   '范围内',
#   '开展',
#   '治理',
#   '规范',
#   '信息',
#   '服务',
#   '企业',
#   '资费',
#   '收费',
#   '活动',
#   '明码',
#   '标价',
#   '信息',
#   '订购',
#   '计费',
#   '流程',
#   '收费',
#   '方式',
#   '资费',
#   '争议',
#   '处理',
#   '方面',
#   '相关',
#   '企业',
#   '进行',
#   '规范',
#   '加大',
#   '广播',
#   '电视',
#   '报纸',
#   '互联网',
#   '媒体',
#   '参与',
#   '互动',
#   '短信',
#   '规范',
#   '查处',
#   '力度'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '柯达',
#   '公司',
#   '公布',
#   '今年',
#   '季度',
#   '财报',
#   '公司',
#   '转移',
#   '数字',
#   '摄影',
#   '技术',
#   '季度',
#   '亏损',
#   '公司',
#   '季度',
#   '出现',
#   '亏损',
#   '柯达',
#   '公司',
#   '正在',
#   '考虑',
#   '出售',
#   '医疗',
#   '成像',
#   '部门',
#   '公司',
#   '股票',
#   '下跌',
#   '幅度',
#   '超过',
#   '4%',
#   '柯达',
#   '公司',
#   '表示',
#   '今年',
#   '季度',
#   '业务',
#   '重组',
#   '费用',
#   '亏损',
#   '相比之下',
#   '去年',
#   '同期',
#   '亏损',
#   '公司',
#   '销售',
#   '收入',
#   '增长',
#   '2%',
#   '达到',
#   '去年',
#   '季度',
#   '销售',
#   '收入',
#   '包括',
#   '先前',
#   '费用',
#   '柯达',
#   '公司',
#   '今年',
#   '季度',
#   '亏损',
#   '没有',
#   '达到',
#   '分析师',
#   '预期',
#   '市场',
#   '调研',
#   '机构',
#   'Thomson',
#   'Financia',
#   '公司',
#   '多数',
#   '分析',
#   '预期',
#   '柯达',
#   '公司',
#   '今年',
#   '季度',
#   '利润',
#   '胶卷',
#   '销售',
#   '迅速',
#   '下滑',
#   '打击',
#   '柯达',
#   '公司',
#   '收入',
#   '稳定',
#   '进入',
#   '数字',
#   '时代',
#   '柯达',
#   '公司',
#   '得到',
#   '安慰',
#   '今年',
#   '季度',
#   '公司',
#   '数字',
#   '部门',
#   '销售',
#   '非常',
#   '强劲',
#   '同比',
#   '增长',
#   '29%',
#   '达到',
#   '胶卷',
#   '传统',
#   '产品',
#   '化学',
#   '业务',
#   '同比',
#   '下滑',
#   '20%',
#   '去年',
#   '夏季',
#   '历史',
#   '柯达',
#   '公司',
#   '宣布',
#   '削减',
#   '员工',
#   '裁员',
#   '举措',
#   '一月',
#   '决定',
#   '最高',
#   '削减',
#   '员工',
#   '计划',
#   '柯达',
#   '公司',
#   '发言人',
#   'David',
#   'Lanzillo',
#   '表示',
#   '公司',
#   '正在',
#   '医疗',
#   '部门',
#   '进行',
#   '战略',
#   '选择',
#   '医疗',
#   '部门',
#   '包括',
#   '胶卷',
#   '医学',
#   '打印',
#   '医疗',
#   '成像',
#   '产品',
#   '服务',
#   '战略',
#   '选择',
#   '包括',
#   '经营',
#   '彻底',
#   '出售',
#   '选择',
#   '柯达',
#   '公司',
#   '医疗',
#   '部门',
#   '去年',
#   '收入',
#   '柯达',
#   '公司',
#   '首席',
#   '执行官',
#   '安东尼奥-佩雷斯',
#   'Antonio',
#   'Perez',
#   '声明',
#   '医疗',
#   '商务',
#   '数字',
#   '基础',
#   '业务',
#   '享受',
#   '强劲',
#   '增长',
#   '注意到',
#   '行业',
#   '进行',
#   '合并',
#   '有价值',
#   '资产',
#   '市场',
#   '前景',
#   '变化',
#   '目前',
#   '医疗',
#   '部门',
#   '战略',
#   '选择',
#   '进行',
#   '研究',
#   '今年',
#   '季度',
#   '柯达',
#   '公司',
#   '胶卷',
#   '照相',
#   '洗印',
#   '服务',
#   '收入',
#   '去年',
#   '同期',
#   '下滑',
#   '运作',
#   '利润',
#   '下滑',
#   '医疗',
#   '成像',
#   '销售',
#   '收入',
#   '下滑',
#   '7%',
#   '运作',
#   '利润',
#   '下滑',
#   '相比之下',
#   '图象',
#   '通信',
#   '业务',
#   '销售',
#   '收入',
#   '同比',
#   '增长',
#   '136%',
#   '达到',
#   '运作',
#   '利润',
#   '本',
#   '周四',
#   '柯达',
#   '公司',
#   '预期',
#   '今年',
#   '数字',
#   '部门',
#   '利润',
#   '增长',
#   '数字',
#   '部门',
#   '销售',
#   '收入',
#   '增长',
#   '16%',
#   '22%',
#   '在',
#   '纽约',
#   '股票',
#   '市场',
#   '柯达',
#   '公司',
#   '股票',
#   '下跌',
#   '4.2%',
#   '交易',
#   '柯达',
#   '公司',
#   '股票',
#   '之间',
#   '浮动'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '国外',
#   '媒体',
#   '报道',
#   '索尼',
#   'PlayStation3',
#   '游戏机',
#   '登场',
#   '蹒跚',
#   '殃及',
#   '全球',
#   '游戏',
#   '软件',
#   '开发商',
#   '电子',
#   '艺术',
#   '公司',
#   'EA',
#   '公司',
#   '宣布',
#   '今年',
#   '一季度',
#   '公司',
#   '去年',
#   '一季度',
#   'EA',
#   '盈利',
#   '盈利',
#   '索尼',
#   'PlayStation',
#   '定于',
#   '上市',
#   '任天堂公司',
#   '下一代',
#   '游戏机',
#   'Wii',
#   '预计',
#   '左右',
#   '上市',
#   '微软',
#   'Xbox',
#   '已经',
#   '去年',
#   '推出'],
#  ['摘要',
#   '微软',
#   '首席',
#   '执行官',
#   '鲍尔默',
#   '表示',
#   '重视',
#   '服务化',
#   '软件',
#   '微软',
#   '计划',
#   'MSN',
#   '部门',
#   '研发',
#   '预算',
#   '翻一番',
#   '天极网',
#   '消息',
#   '孙淑艳',
#   '编译',
#   '外电',
#   '报道',
#   '美国',
#   '时间',
#   '本周',
#   '微软',
#   '首席',
#   '执行官',
#   '鲍尔默',
#   '表示',
#   '重视',
#   '服务化',
#   '软件',
#   '微软',
#   '计划',
#   'MSN',
#   '部门',
#   '研发',
#   '预算',
#   '微软',
#   '公布',
#   '牺牲',
#   '利润',
#   '用于',
#   '投资',
#   '业务',
#   '领域',
#   '计划',
#   '投资者',
#   '大吃一惊',
#   '抱怨',
#   '微软',
#   'Google',
#   '雅虎',
#   '竞争',
#   '计划',
#   '缺乏',
#   '透明性',
#   '在',
#   '推广',
#   '微软',
#   '在线',
#   '广告',
#   '一次',
#   '会议',
#   '发言',
#   '鲍尔默',
#   '投资',
#   '微软',
#   '决心',
#   '成为',
#   'Web',
#   '领域',
#   '领头羊',
#   '信号',
#   '表示',
#   '公司',
#   '能够',
#   '真正',
#   '提供',
#   '消费者',
#   '广告主',
#   '要求',
#   '同步',
#   '基础设施',
#   '微软',
#   '计划',
#   'MSN',
#   '部门',
#   '研发',
#   '预算',
#   '提高',
#   '微软',
#   '计划',
#   '资本',
#   '投资',
#   '提高',
#   '鲍尔默',
#   '表示',
#   '研发',
#   '预算',
#   '达到',
#   '没有',
#   '表明',
#   '时间',
#   '框架',
#   '研发',
#   '团队',
#   '明白',
#   '优先',
#   '任务',
#   '服务化',
#   '软件'],
#  ['赛迪网',
#   '消息',
#   '高通',
#   '微软',
#   '联合',
#   '宣布',
#   '一项',
#   '合作',
#   '计划',
#   '合作',
#   '计划',
#   '微软',
#   'Windows',
#   'Mobile',
#   '操作系统',
#   '移植',
#   '高通',
#   'MSM',
#   '移动工作站',
#   '调制解调器',
#   '芯片组',
#   '据',
#   'webwire',
#   'com',
#   '网站',
#   '报道',
#   '高通',
#   '合作',
#   '设备',
#   '厂商',
#   '开发',
#   '便宜',
#   '功能',
#   '丰富',
#   '采用',
#   '微软',
#   'Windows',
#   'Mobile',
#   '操作系统',
#   '高通',
#   'MSM',
#   '芯片组',
#   '手机',
#   '缩短',
#   '厂商',
#   '产品',
#   '开发',
#   '时间',
#   '高通',
#   '高度',
#   '集成',
#   'MSM',
#   '芯片组',
#   '支持',
#   'Windows',
#   'Mobile',
#   '平台',
#   '能够',
#   '用户',
#   '运行',
#   '商业',
#   '娱乐',
#   '应用',
#   '程序',
#   '延长',
#   '电池',
#   '使用',
#   '寿命',
#   '高',
#   '负责',
#   'CDMA',
#   '技术',
#   '总裁',
#   'Sanjay',
#   'Jha',
#   '博士',
#   '高通',
#   'MSM',
#   '芯片组',
#   '支持',
#   '微软',
#   'Windows',
#   'Mobile',
#   '操作',
#   '系统',
#   '下一代',
#   '具有',
#   '诱人',
#   '外形',
#   '更轻',
#   '手机',
#   '带来',
#   '熟悉',
#   '软件',
#   '体验',
#   '客户',
#   '能够',
#   '更快',
#   '设计',
#   '成本',
#   '效率',
#   '创新',
#   '设备',
#   '发挥',
#   '融合',
#   '平台',
#   '双处理器',
#   '解决方案',
#   '优势',
#   '微软',
#   '移动',
#   '嵌入式',
#   '设备',
#   '部门',
#   '通信',
#   '行业',
#   '部门',
#   '高级',
#   '副总裁',
#   'Pieter',
#   'Knook',
#   '知道',
#   '移动',
#   '运营商',
#   '迫切',
#   '需要',
#   '使用',
#   '配置',
#   'Windows',
#   'Mobile',
#   '操作系统',
#   '设备',
#   '吸引',
#   '保留',
#   '用户',
#   '越来越',
#   '移动',
#   '用户',
#   '需要',
#   '移动',
#   '电子邮件',
#   'Office',
#   '办公',
#   '软件',
#   '功能',
#   '能够',
#   '使用',
#   '计算机',
#   '软件',
#   '熟悉',
#   '方便',
#   '高通',
#   '硬件',
#   '平台',
#   '微软',
#   '软件',
#   '能够',
#   '实现',
#   '目的',
#   '微软',
#   '高通',
#   '合作',
#   '能够',
#   '设备',
#   '厂商',
#   '移动',
#   '运营商',
#   '销售',
#   '能够',
#   '产生',
#   '更多',
#   '收入',
#   '广泛',
#   '移动',
#   '设备',
#   '微软',
#   '高通',
#   '进行',
#   '全面',
#   '整合',
#   '测试',
#   '高通',
#   '融合',
#   '平台',
#   '7XXX',
#   '系列',
#   'MSM',
#   '芯片组',
#   '支持',
#   '微软',
#   'Windows',
#   'Mobile',
#   '操作系统',
#   '高通',
#   '平台',
#   '采用',
#   '双内核',
#   '架构',
#   '配置',
#   '集成',
#   'ARM11',
#   '应用',
#   '处理器',
#   '用于',
#   '高级',
#   '性能',
#   'ARM9',
#   '调制解调器',
#   '处理器',
#   '高',
#   '计划',
#   '下半年',
#   '融合',
#   '平台',
#   'MSM',
#   '芯片组',
#   '支持',
#   '微软',
#   'Windows',
#   'Mobile',
#   '5.0',
#   '操作系统',
#   '微软',
#   '高通',
#   '融合',
#   '平台',
#   '解决方案',
#   '新的',
#   '板卡',
#   '支持',
#   '包和',
#   '接口',
#   '结合',
#   '微软',
#   '未来',
#   '版本',
#   'Windows',
#   'Mobile',
#   '平台',
#   '发布',
#   '采用',
#   '支持',
#   'Windows',
#   'Mobile',
#   '平台',
#   'MSM',
#   '解决方案',
#   '手机',
#   '预计',
#   '上市'],
#  ['据',
#   '国际',
#   '先驱',
#   '论坛报',
#   '报道',
#   '日本',
#   'NEC公司',
#   '收到',
#   '私下',
#   '举报',
#   '有一',
#   '假冒',
#   'NEC公司',
#   '假冒',
#   'NEC公司',
#   '中国',
#   '运营',
#   '似乎',
#   '日本',
#   '台湾',
#   '组织',
#   '进行',
#   '控制',
#   '调查',
#   '发现',
#   '假冒',
#   'NEC公司',
#   '开发',
#   '大约',
#   '假冒',
#   'NEC',
#   '产品',
#   '包括',
#   '家庭',
#   '娱乐',
#   '系统',
#   'MP3',
#   '播放器',
#   '电池',
#   '麦克风',
#   'DVD',
#   '播放器',
#   '模仿',
#   'NEC',
#   '产品',
#   '以外',
#   '公司',
#   '开发',
#   '产品',
#   'NEC',
#   '管辖权',
#   '之内',
#   '假冒',
#   'NEC公司',
#   '方面',
#   '象是',
#   '一家',
#   '合法',
#   '公司',
#   'NEC',
#   '品牌',
#   '名义',
#   '中国',
#   '企业',
#   '签署',
#   '制造',
#   '协议',
#   '发放',
#   '设计',
#   '授权',
#   'NEC',
#   '高级',
#   '副总裁',
#   'Fujio',
#   'Okada',
#   '表示',
#   '复杂',
#   '组织',
#   '位于',
#   '台湾',
#   '日本',
#   '组织',
#   '进行',
#   '关键性',
#   '协调',
#   '试图',
#   '完全',
#   '假冒',
#   'NEC',
#   'NEC',
#   '法律',
#   '原因',
#   '为由',
#   '拒绝',
#   '透露',
#   '罪犯',
#   '目前',
#   '难以',
#   '估计',
#   '违法',
#   '公司',
#   '出售',
#   '商品',
#   '价值',
#   '编译',
#   '搜狐',
#   'IT',
#   'Unifytruth'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '国外',
#   '媒体',
#   '报道',
#   '美国',
#   '零售',
#   '巨头',
#   '沃尔玛',
#   '日前',
#   '宣布',
#   '全美三',
#   '零售店',
#   '销售',
#   'DIY',
#   '电脑',
#   '消费者',
#   '自行',
#   '挑选',
#   '不同',
#   '品牌',
#   '回家',
#   '组装',
#   '心目中',
#   '理想',
#   '电脑',
#   '此前',
#   '沃尔玛',
#   '一直',
#   '销售',
#   '品牌',
#   '电脑',
#   '整机',
#   '附件',
#   '未来',
#   '消费者',
#   'DIY',
#   '柜台',
#   '购买',
#   '沃尔玛',
#   '提供',
#   '散件',
#   '包括',
#   '处理器',
#   '显示器',
#   '键盘',
#   '鼠标',
#   '一台',
#   '电脑',
#   '消费者',
#   '购物车',
#   '散件',
#   '拉走',
#   '回家',
#   '电脑',
#   '沃尔玛',
#   '去年',
#   '已经',
#   '尝试',
#   '电脑',
#   '散件',
#   '业务',
#   '连锁店',
#   '沃尔玛',
#   '发言人',
#   '斯图尔特',
#   '路透社',
#   '记者',
#   '表示',
#   '沃尔玛',
#   '全美',
#   '连锁店',
#   '销售',
#   '年底',
#   '销售',
#   '散件',
#   '连锁店',
#   '增加',
#   '路透社',
#   '分析',
#   '认为',
#   '实力',
#   '雄厚',
#   '沃尔玛',
#   '进入',
#   'DIY',
#   '电脑',
#   '领域',
#   '品牌',
#   '电脑',
#   '厂商',
#   '带来',
#   '巨大',
#   '压力',
#   '过去',
#   '沃尔玛',
#   '销售',
#   '玩具',
#   '蔬菜',
#   '专业',
#   '公司',
#   '被迫',
#   '倒闭',
#   '关门',
#   '沃尔玛',
#   '模式',
#   '戴尔',
#   '厂商',
#   '不同',
#   '戴尔',
#   '负责',
#   '攒机',
#   '市场',
#   '企业',
#   '个人',
#   '消费者',
#   '全球',
#   '零售',
#   '巨头',
#   '沃尔玛',
#   '狗食',
#   '钻石',
#   '领域',
#   '销售',
#   '冠军',
#   '电脑',
#   '领域',
#   '一直',
#   '未能',
#   '占据',
#   '重要',
#   '低位',
#   '去年',
#   '沃尔玛',
#   '联手',
#   '惠普',
#   '公司',
#   '推出',
#   '笔记本',
#   '电脑',
#   '美国',
#   '掀起',
#   '波澜',
#   '值得一提的是',
#   '沃尔玛',
#   '近来',
#   '增加',
#   '利润',
#   '高科技',
#   '产品',
#   '进货',
#   '平板',
#   '电视机',
#   '高级',
#   '时装',
#   '显然',
#   '沃尔玛',
#   '希望',
#   '消费者',
#   '购买',
#   '利润',
#   '用品',
#   '购买',
#   '奢侈品']]

# %%
from gensim.models import Word2Vec
model = Word2Vec(sentences, size=100, window=5, min_count=5, workers=4)
model.save('my.word2vec')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
model = Word2Vec.load('my.word2vec')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
model.wv['电脑']
# Out:
# array([ 0.18344449,  0.0152768 , -0.13604826, -0.01214636,  0.08696793,
#        -0.2043133 , -0.08343486, -0.20476754, -0.30961055, -0.05255929,
#         0.26758552, -0.09658953, -0.49444154,  0.5289667 ,  0.15155792,
#        -0.2046119 , -0.05785393,  0.36078644,  0.09493233, -0.06579098,
#        -0.42164695,  0.0755384 ,  0.32462794, -0.0837433 ,  0.03612296,
#         0.18483846,  0.26904422,  0.13077937, -0.26698858,  0.40861133,
#        -0.08559329,  0.27656752, -0.38725853, -0.24136145, -0.09527284,
#        -0.6075816 , -0.12395583, -0.41609052, -0.54861623, -0.21724907,
#         0.1370065 ,  0.5673256 ,  0.1917161 ,  0.1599618 , -0.6628393 ,
#         0.04466977, -0.15765296, -0.30242646, -0.25842968, -0.25783616,
#         0.03822951, -0.1252077 ,  0.4490651 , -0.01014764, -0.01515726,
#         0.32964355, -0.83499193,  0.6825774 , -0.10666229,  0.22176291,
#         0.17136481, -0.12737551,  0.07468461,  0.02523253,  0.06961744,
#         0.3637891 ,  0.02655508, -0.06998077, -0.10937472,  0.01826737,
#        -0.00865961, -0.01346295,  0.05804701,  0.09935508,  0.06213485,
#         0.5570962 ,  0.02368529, -0.40487936, -0.14605428,  0.11505303,
#         0.15328242, -0.2669586 ,  0.49889916, -0.2349491 , -0.69819975,
#        -0.21463864,  0.14394365,  0.33986086,  0.10325585,  0.07890583,
#        -0.71951145, -0.43635064, -0.14629032, -0.65537006, -0.64958555,
#        -0.20517096,  0.85550195, -0.42322785, -0.19036147,  0.22431822],
#       dtype=float32)

# %%
model.similarity(u'笔记本', u'电脑')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.9998558

# %% [markdown]
# #### 词向量增量训练
#
# ```
# model = gensim.models.Word2Vec.load(fname)
# model.train(sentences,total_examples=new_model.corpus_count, epochs=1)
# ```

# %% [markdown]
# #### 数据降维与可视化
#
# 降维就是用2维或3维表示多维数据（彼此具有相关性的多个特征数据）的技术，利用降维算法，可以显式地表现数据。（t-SNE）t分布随机邻域嵌入 是一种用于探索高维数据的非线性降维算法。它将多维数据映射到适合于人类观察的两个或多个维度。

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

wordVocab = [k for (k,v) in model.wv.vocab.items()]

random_word = wordVocab[50:100]
X_tsne = TSNE(n_components=2, learning_rate=100).fit_transform(model.wv[random_word])

plt.figure(figsize=(14, 8))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1])
for i in range(len(X_tsne)):
    x = X_tsne[i][0]
    y = X_tsne[i][1]
    plt.text(x, y, random_word[i], size=16)
plt.show()

# %% [markdown]
# ## 5.文档向量模型

# %% [markdown]
# ### 5.1 Doc2vec原理
#
# 前文总结了Word2vec训练词向量的细节，讲解了一个词是如何通过word2vec模型训练出唯一的向量来表示的。那接着可能就会想到，有没有什么办法能够将一个句子甚至一篇短文也用一个向量来表示呢？答案是肯定有的，构建一个句子向量有很多种方法，今天我们接着word2vec来介绍下Doc2vec，看下Doc2vec是怎么训练一个句子向量的。
#
# Doc2vec又叫Paragraph Vector是Tomas Mikolov基于word2vec模型提出的，其具有一些优点，比如不用固定句子长度，接受不同长度的句子做训练样本，Doc2vec是一个无监督学习算法，该算法用于预测一个向量来表示不同的文档，该模型的结构潜在的克服了词袋模型的缺点。

# %% [markdown]
# 和word2vec一样，Doc2vec也有两种训练方式，一种是PV-DM（Distributed Memory Model of paragraphvectors）类似于word2vec中的CBOW模型，如图一：
#
# ![](images/doc1.jpeg)
#
# 另一种是PV-DBOW（Distributed Bag of Words of paragraph vector)类似于word2vec中的skip-gram模型，如图二：
#
# ![](images/doc2.jpeg)
#
# 在Doc2vec中，每一句话用唯一的向量来表示，用矩阵D的某一列来代表。每一个词也用唯一的向量来表示，用矩阵W的某一列来表示。每次从一句话中滑动采样固定长度的词，取其中一个词作预测词，其他的作输入词。输入词对应的词向量word vector和本句话对应的句子向量Paragraph vector作为输入层的输入，将本句话的向量和本次采样的词向量相加求平均或者累加构成一个新的向量X，进而使用这个向量X预测此次窗口内的预测词。

# %%
sentences
# Out:
# [['本报讯',
#   '记者',
#   '王京',
#   '联想',
#   'THINKPAD',
#   '近期',
#   '几乎',
#   '系列',
#   '笔记本',
#   '电脑',
#   '降价促销',
#   '最高',
#   '降幅',
#   '达到',
#   '降幅',
#   '达到',
#   '42%',
#   '记者',
#   '联想',
#   '美国',
#   '官方',
#   '网站',
#   '发现',
#   '联想',
#   '相关',
#   '人士',
#   '表示',
#   '纪念',
#   '联想',
#   '成立',
#   '美国',
#   '市场',
#   '推出',
#   '促销',
#   '产品',
#   '包括',
#   'THINKPAD',
#   'T',
#   '系列',
#   '笔记本',
#   '促销',
#   '价格战',
#   'THINK',
#   '品牌',
#   '高端',
#   '商务',
#   '路线',
#   '方向',
#   '不会',
#   '改变'],
#  ['赛迪网',
#   '消息',
#   '思科',
#   '周二',
#   '发布',
#   '其财',
#   '第三季度',
#   '财报',
#   '财报',
#   '显示',
#   '股票',
#   '期权',
#   '开支',
#   '收购',
#   '相关',
#   '费用',
#   '影响',
#   '季度',
#   '营收',
#   '实现',
#   '增长',
#   '净利润',
#   '同比',
#   '下降',
#   '据',
#   'Maketwatch',
#   '网站',
#   '报道',
#   '思科',
#   '季度',
#   '实现',
#   '净利润',
#   '低于',
#   '去年',
#   '同期',
#   '本季度',
#   '收益',
#   '去年',
#   '同期',
#   '收益',
#   '思科',
#   '去年',
#   '同期',
#   '发行',
#   '股票',
#   '数量',
#   '于今',
#   'Thomson',
#   'First',
#   'Call',
#   '调查',
#   '分析师',
#   '预计',
#   '收益',
#   '本',
#   '季度',
#   '营收',
#   '同比',
#   '增长',
#   '高于',
#   '华尔街',
#   '分析师',
#   '预计',
#   '思科',
#   '新近',
#   '收购',
#   'Scientific-Atlanta',
#   '公司',
#   '季度',
#   '营收',
#   '增长',
#   '做出',
#   '贡献',
#   '思科',
#   '上个世纪',
#   '年代',
#   '进行',
#   '收购',
#   '实现',
#   '发展',
#   '目的',
#   '现在',
#   '希望',
#   '借助',
#   '价格',
#   '收购',
#   'Scientific-Atlanta',
#   '公司',
#   '扩大',
#   '互联网',
#   '设备',
#   '市场',
#   '份额',
#   '分析师',
#   '投资者',
#   '看好',
#   '思科',
#   'Scientific-Atlanta',
#   '收购',
#   '思科',
#   '股价',
#   '进入',
#   '今年',
#   '上涨',
#   '财报',
#   '发布',
#   '思科',
#   '股票',
#   '盘后',
#   '交易',
#   '上涨'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '国外',
#   '媒体',
#   '报道',
#   '一名',
#   '德国',
#   '数据库安全',
#   '工程师',
#   '日前',
#   '撰文',
#   '指出',
#   '目前',
#   '甲骨文',
#   '软件',
#   '产品',
#   '尚未',
#   '修补',
#   '漏洞',
#   '漏洞',
#   '发现',
#   '不等',
#   '德国',
#   '信息',
#   '安全',
#   '机构',
#   '红色',
#   '数据库安全',
#   '工程师',
#   '亚力山大',
#   '·科布鲁斯特',
#   '日前',
#   'Buqtraq',
#   '安全',
#   '邮件',
#   '列表',
#   '发表',
#   '文章',
#   '漏洞',
#   '集中',
#   '甲骨文',
#   '数据库',
#   '产品',
#   '漏洞',
#   '之前',
#   '发现',
#   '报告',
#   '甲骨文',
#   '最新',
#   '漏洞',
#   '之前',
#   '发现',
#   '科',
#   '布鲁斯特',
#   '谈及',
#   '漏洞',
#   '包括',
#   'SQL',
#   '语句',
#   '插入',
#   '漏洞',
#   '交叉',
#   '脚本',
#   '攻击',
#   '漏洞',
#   '明文',
#   '密码',
#   '泄露',
#   '漏洞',
#   '漏洞',
#   '甲骨文公司',
#   '未来',
#   '安全更新',
#   '中将',
#   '得到',
#   '修补',
#   '清楚',
#   '甲骨文',
#   '升级',
#   '软件',
#   '发布',
#   '修补',
#   '具体',
#   '漏洞',
#   '时间',
#   '去年',
#   '甲骨文',
#   '首席',
#   '安全',
#   '玛丽·安娜·戴维德森',
#   '席话',
#   '信息',
#   '安全界',
#   '引发',
#   '骚动',
#   '安娜',
#   '已经',
#   '发现',
#   '甲骨文',
#   '软件',
#   '漏洞',
#   '有四',
#   '公司',
#   '工程师',
#   '发现',
#   '科布鲁斯特',
#   '计算',
#   '甲骨文',
#   '软件',
#   '尚未',
#   '得到',
#   '修补',
#   '漏洞',
#   '应该',
#   '百六',
#   '左右',
#   '算术',
#   '玛丽·安娜·戴维德森',
#   '说法',
#   '四分',
#   '漏洞',
#   '甲骨文',
#   '发现',
#   '发现',
#   '剩下',
#   '甲骨文',
#   '尚未',
#   '修改',
#   '至少',
#   '百六',
#   '漏洞',
#   '科布鲁斯特',
#   '文章',
#   '写道',
#   '近来',
#   '甲骨文',
#   '软件',
#   '漏洞',
#   '新闻',
#   '涌现',
#   '网络',
#   '周前',
#   '甲骨文',
#   '发布',
#   '安全',
#   '更新包',
#   '号称',
#   '修补',
#   '三十',
#   '漏洞',
#   'NGS',
#   '软件公司',
#   '工程师',
#   '大卫·里奇菲尔德',
#   '甲骨文',
#   '发布',
#   '补丁',
#   '没有',
#   '存在',
#   '年多',
#   '漏洞',
#   '修补',
#   '科布鲁斯特',
#   '文章',
#   '得出',
#   '结论',
#   '修补',
#   '软件',
#   '漏洞',
#   '方面',
#   '甲骨文',
#   '慢条斯理'],
#  ['赛迪网',
#   '外电',
#   '消息',
#   '美国',
#   '媒体',
#   '巨头',
#   '时代华纳公司',
#   '星期',
#   '公布',
#   '截止',
#   '月份',
#   '季度',
#   '财务',
#   '报告',
#   '有线电视',
#   '部门',
#   '强劲',
#   '增长',
#   '出售',
#   '图书',
#   '部门',
#   '资产',
#   '获得',
#   '收益',
#   '推动',
#   '时代华纳',
#   '季度',
#   '利润',
#   '增长',
#   '将近',
#   '60%',
#   '据',
#   '美联社',
#   '报道',
#   '时代华纳',
#   '季度',
#   '利润',
#   '收益',
#   '去年',
#   '同期',
#   '时代华纳',
#   '利润',
#   '收益',
#   '销售',
#   '收入',
#   '增长',
#   '1%',
#   '去年',
#   '同期',
#   '增长',
#   '扣除非',
#   '正常',
#   '收益',
#   '时间',
#   '一次性',
#   '收益',
#   '出售',
#   '图书',
#   '部门',
#   '收益',
#   '时代华纳',
#   '利润',
#   '增长',
#   '32%',
#   '去年',
#   '同期',
#   '增长',
#   '标准',
#   '计算',
#   '时代华纳',
#   '收益',
#   '去年',
#   '同期',
#   '收益',
#   '提高',
#   '收益',
#   '远远',
#   '超过',
#   '华尔街',
#   '分析师',
#   '预测',
#   '金融',
#   '机构',
#   'Thomson',
#   'Financial',
#   '调查',
#   '华尔街',
#   '分析师',
#   '预测',
#   '收益',
#   '时代华纳',
#   '旗下',
#   '子公司',
#   '收入',
#   '最多',
#   '有线电视',
#   '部门',
#   '部门',
#   '销售',
#   '收入',
#   '增长',
#   '15%',
#   '利润',
#   '增长',
#   '25%',
#   '今年',
#   '季度',
#   '时代华纳',
#   '有线电视',
#   '公司',
#   '增加',
#   '基本',
#   '有线电视',
#   '用户',
#   '公司',
#   '数字',
#   '视频',
#   '互联网',
#   '数字',
#   '视频',
#   '录像',
#   '数字电话',
#   '服务',
#   '收费',
#   '较高',
#   '服务',
#   '增加',
#   '用户',
#   '时代华纳',
#   '首席',
#   '执行官',
#   '迪克·帕森斯',
#   'Dick',
#   'Parsons',
#   '分析师',
#   '召开',
#   '电话会议',
#   '证实',
#   '时代华纳',
#   '媒体',
#   '大王',
#   '约翰·马龙',
#   '控股',
#   '位于',
#   '丹佛',
#   '自由',
#   '媒体',
#   '公司',
#   '谈判',
#   '正在',
#   '取得',
#   '进展',
#   '谈判',
#   '内容',
#   '收购',
#   '自由',
#   '媒体',
#   '公司',
#   '旗下',
#   'Court',
#   'TV',
#   '电视',
#   '公司',
#   '50%',
#   '股权',
#   '事宜',
#   '谈判',
#   '成功',
#   '时代华纳',
#   '拥有',
#   '有线电视',
#   '频道',
#   '股权',
#   '美国在线',
#   '继续',
#   '失去',
#   '用户',
#   '美国在线',
#   '重新',
#   '成为',
#   '广告',
#   '收入',
#   '推动',
#   '互联网',
#   '公司',
#   '美国在线',
#   '季度',
#   '用户',
#   '减少',
#   '目前',
#   '用户',
#   '总数',
#   '用户',
#   '收入',
#   '下降',
#   '超过',
#   '广告',
#   '收入',
#   '增长',
#   '美国在线',
#   '季度',
#   '经营',
#   '利润',
#   '减少',
#   '14%',
#   '时代公司',
#   '季度',
#   '利润',
#   '减少',
#   '12%',
#   '原因',
#   '海外',
#   '杂志',
#   '销售',
#   '疲软',
#   '支出',
#   '公司',
#   '重组',
#   '费用',
#   '今年',
#   '月份',
#   '宣布',
#   '出售',
#   '时代华纳',
#   '图书',
#   '集团',
#   '时代华纳',
#   '获得',
#   '收益',
#   '帕森斯',
#   '电话会议',
#   '投资者',
#   '公司',
#   '按计划',
#   '之前',
#   '完成',
#   'Comcast',
#   '一起',
#   '收购',
#   'Adelphia',
#   '通信',
#   '公司',
#   '有线电视',
#   '资产',
#   '交易'],
#  ['五',
#   '期间',
#   '苏宁',
#   '国美',
#   '大中',
#   '永乐',
#   '卖场',
#   '再次',
#   '掀起',
#   '平板',
#   '热卖',
#   '高潮',
#   '最高',
#   '降幅',
#   '50%',
#   '国美',
#   '液晶',
#   '电视',
#   '售价',
#   '每英寸',
#   '售卖',
#   '国美',
#   '平板',
#   '价格',
#   '整体',
#   '下调',
#   '30%',
#   '左右',
#   '最高',
#   '降幅',
#   '超过',
#   '50%',
#   '目前',
#   '市场',
#   '最为',
#   '走俏',
#   '液晶',
#   '等离子',
#   '电视',
#   '液晶',
#   '电视',
#   '成为',
#   '国美',
#   '重点',
#   '推出',
#   '机型',
#   '一款',
#   '液晶',
#   '电视',
#   '跌破',
#   '意味着',
#   '五一',
#   '期间',
#   '国美',
#   '液晶',
#   '电视',
#   '售价',
#   '每英寸',
#   '售卖',
#   '而',
#   '苏宁',
#   '合资',
#   '液晶',
#   '合资',
#   '等离子',
#   '液晶',
#   '跌破',
#   '苏宁',
#   '彩电',
#   '五一',
#   '期间',
#   '特价',
#   '投放',
#   '市场',
#   '新开',
#   '店面',
#   '低于',
#   '特价',
#   '电器',
#   '彩电',
#   '事业部',
#   '负责人',
#   '表示',
#   '大中',
#   '永乐',
#   '联手',
#   '集中',
#   '打压',
#   '等离子',
#   '平板',
#   '电视',
#   '五一',
#   '期间',
#   '预计',
#   '左右',
#   '低价',
#   '敞开',
#   '供应',
#   '大中',
#   '中央电视塔',
#   '集中',
#   '展示',
#   '液晶',
#   '新品',
#   '液晶',
#   '主流',
#   '价位',
#   '集中',
#   '左右',
#   '普及',
#   '价格',
#   '夏普',
#   '三星',
#   'LG',
#   '索尼',
#   '新品',
#   '亮相',
#   '记者',
#   '杨振'],
#  ['明年',
#   '有望',
#   '传回',
#   '中国',
#   '月球',
#   '三维图',
#   '本报讯',
#   '解放',
#   '日报',
#   '报道',
#   '日前',
#   '一支',
#   '上海',
#   '上海',
#   '光机',
#   '组成',
#   '科研',
#   '团队',
#   '正在',
#   '即将',
#   '上天',
#   '嫦娥',
#   '探月',
#   '卫星',
#   '激光',
#   '激光',
#   '我国',
#   '独立',
#   '自主',
#   '研发',
#   '太空',
#   '激光',
#   '高度计',
#   '明年',
#   '有望',
#   '月亮',
#   '传回',
#   '中国',
#   '月球',
#   '图片',
#   '中国人',
#   '未来',
#   '登月',
#   '计划',
#   '寻找',
#   '合适',
#   '落脚点',
#   '据介绍',
#   '国产化',
#   '激光',
#   '高度计',
#   '堪称',
#   '太空',
#   '劳模',
#   '嫦娥',
#   '运转',
#   '高度',
#   '轨道',
#   '长期',
#   '开机',
#   '工作',
#   '白天黑夜',
#   '每隔',
#   '发射',
#   '激光',
#   '激光',
#   '月球',
#   '表面',
#   '留下',
#   '直径',
#   '足印',
#   '千分',
#   '反射',
#   '回来',
#   '卫星',
#   '实时',
#   '处理',
#   '传回',
#   '测得',
#   '大量',
#   '数据',
#   '卫星',
#   '搭载',
#   '激光',
#   '高度计',
#   '绒线',
#   '一圈',
#   '地转',
#   '留下',
#   '激光',
#   '足印',
#   '最终',
#   '月球',
#   '地表',
#   '状况',
#   '扫描',
#   '下来'],
#  ['天极网',
#   '消息',
#   '孙淑艳',
#   '编译',
#   '外电',
#   '报道',
#   '美国纽约',
#   '时间',
#   '本周',
#   '华尔街',
#   '日报',
#   '报道',
#   '盗版',
#   'DVD',
#   '互联网',
#   '下载',
#   '电影',
#   '产业',
#   '造成',
#   '损失',
#   '原来',
#   '预期',
#   '报道',
#   '研究',
#   '显示',
#   '电影',
#   '产业',
#   '损失',
#   '原来',
#   '预期',
#   '75%',
#   '报告',
#   '援引',
#   '匿名',
#   '人士',
#   '指出',
#   '损失',
#   '不仅仅',
#   '票房',
#   'DVD',
#   '销售',
#   '报告',
#   '指出',
#   '美国',
#   '损失',
#   '高达',
#   '报告',
#   '推翻',
#   '常识',
#   '墨西哥',
#   '超过',
#   '中国',
#   '俄罗斯',
#   '成为',
#   '世界',
#   '最大',
#   '美国',
#   '电影',
#   '盗版',
#   '市场',
#   '美国',
#   '电影',
#   '产业',
#   '造成',
#   '损失'],
#  ['消息',
#   '研究',
#   '人员',
#   '星期',
#   '微软',
#   'IE',
#   '浏览器',
#   '发现',
#   '新的',
#   '安全',
#   '漏洞',
#   '之后',
#   '研究',
#   '人员',
#   '现在',
#   'IE',
#   '浏览器',
#   '发现',
#   '安全',
#   '漏洞',
#   '据',
#   'CNET',
#   'News',
#   'com',
#   '网站',
#   '报道',
#   '新的',
#   '安全',
#   '漏洞',
#   '能够',
#   '黑客',
#   '实施',
#   '执行',
#   '代码',
#   '攻击',
#   '微软',
#   '已经',
#   '证实',
#   '安全',
#   '漏洞',
#   '存在',
#   '安全',
#   '漏洞',
#   '安全',
#   '公司',
#   'Secunia',
#   '研究',
#   '人员',
#   'Andreas',
#   'Sandblad',
#   '发现',
#   '上个星期',
#   '安全',
#   '研究',
#   '人员',
#   'Michal',
#   'Zalewski',
#   '发现',
#   '成功',
#   '利用',
#   '安全漏洞',
#   '原来',
#   'Sandblad',
#   '发现',
#   '安全漏洞',
#   'Zalewski',
#   '上个星期',
#   '发现',
#   '安全漏洞',
#   '关联',
#   '微软',
#   '发言人',
#   '证实',
#   '安全漏洞',
#   '不同',
#   '安全',
#   '公司',
#   'Secunia',
#   '星期',
#   '网站',
#   '发表',
#   '文章',
#   '分析',
#   'Secunia',
#   '发现',
#   '安全',
#   '漏洞',
#   '一种',
#   '安全',
#   '漏洞',
#   'Zalewski',
#   '早些',
#   '发现',
#   '安全',
#   '漏洞',
#   '安全',
#   '公司',
#   '证实',
#   '安全',
#   '漏洞',
#   '影响',
#   '完全',
#   '使用',
#   '补丁',
#   'IE',
#   'Windows',
#   'XP',
#   'SP2',
#   'Secunia',
#   '警告',
#   '计算机',
#   '用户',
#   '引诱',
#   '之下',
#   '访问',
#   '恶意',
#   '网站',
#   '安全',
#   '漏洞',
#   '破坏',
#   '用户',
#   '计算机',
#   '内存',
#   '安全',
#   '公司',
#   '补充',
#   '微软',
#   '正在',
#   '制作',
#   '修复',
#   '安全',
#   '漏洞',
#   '补丁',
#   '天虹'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '周二',
#   '美国',
#   '电话',
#   '公司',
#   'Verizon',
#   '通讯',
#   '发布',
#   '报称',
#   '合并',
#   '影响',
#   '季度',
#   '利润',
#   '出现',
#   '下降',
#   '业务',
#   '强劲',
#   '收入',
#   '上升',
#   '沃达丰',
#   '合资',
#   '拥有',
#   'Verizon',
#   'Verizon',
#   '通讯',
#   '公司',
#   '季度',
#   '净利润',
#   '去年',
#   '同期',
#   '下降',
#   '去年',
#   '数字',
#   '包括',
#   'MCI',
#   '利润',
#   '除去',
#   '经常性',
#   '项目',
#   '利润',
#   '高出',
#   'Reuters',
#   'Estimates',
#   '调查',
#   '分析师',
#   '平均',
#   '估计',
#   '收入',
#   '提高',
#   '包括',
#   'MCI',
#   '数字',
#   '季度',
#   '利润',
#   '下降',
#   '3.3%',
#   '收入',
#   '上升',
#   '3.1%',
#   'Verizon',
#   '通讯',
#   'Verizon',
#   '新增',
#   '客户',
#   '高于',
#   '路透社',
#   '分析师',
#   '估计',
#   '上周',
#   '美国',
#   '电话',
#   '公司',
#   'AT&ampT',
#   '发布',
#   '季度',
#   '报告',
#   '利润',
#   '超过',
#   '华尔街',
#   '预期'],
#  ['天极网',
#   '消息',
#   '记者',
#   '顾萌',
#   'PC',
#   '市场',
#   '增长',
#   '减缓',
#   '全球',
#   '四大',
#   '电脑',
#   '厂商',
#   '宏碁',
#   '看好',
#   '平板',
#   '电视',
#   '市场',
#   '发展',
#   '未来',
#   '之内',
#   '进入',
#   '利润',
#   '较高',
#   '市场',
#   '宏碁',
#   '总经理',
#   '兰奇',
#   '上周',
#   '台湾',
#   '表示',
#   '全球',
#   '平板',
#   '电视',
#   '市场',
#   '持续增长',
#   '有助于',
#   '宏碁',
#   '维持',
#   '获利',
#   '能力',
#   '宏碁',
#   '计划',
#   '未来',
#   '完成',
#   '全球',
#   '液晶',
#   '电视',
#   '市场',
#   '布局',
#   '兰奇',
#   '表示',
#   '营收',
#   '角度',
#   '液晶',
#   '电视',
#   '有可能',
#   '成为',
#   '宏碁',
#   '三大',
#   '支柱',
#   '兰奇',
#   '承认',
#   '近期',
#   '抛售',
#   '明基',
#   '关系',
#   '企业',
#   '股票',
#   '资金',
#   '用于',
#   '提升',
#   '个人',
#   '电脑',
#   '电视',
#   '业务',
#   '全球',
#   '市场',
#   '市场',
#   '份额',
#   '宏碁',
#   '手中',
#   '大约',
#   '明基',
#   '关系',
#   '企业',
#   '股票',
#   '股票',
#   '年内',
#   '出售',
#   '分析师',
#   '认为',
#   '今年',
#   '宏碁',
#   '股价',
#   '下滑',
#   '高达',
#   '25%',
#   '未来',
#   '可能',
#   '下滑',
#   '5%',
#   '充分',
#   '反映',
#   '投资者',
#   'PC',
#   '市场',
#   '价格',
#   '持续',
#   '走低',
#   '担心',
#   '预计',
#   '未来',
#   '笔记本',
#   '电脑',
#   '售价',
#   '维持',
#   '电脑',
#   '维持',
#   '500~600',
#   '宏碁',
#   '希望',
#   '进入',
#   '平板',
#   '电视',
#   '市场',
#   '巩固',
#   '营收',
#   '目前',
#   '宏碁',
#   '欧洲和',
#   '北美',
#   '运作',
#   '液晶',
#   '电视',
#   '业务'],
#  ['天极网',
#   '消息',
#   '羽人',
#   '编译',
#   '外电',
#   '报道',
#   '市场',
#   '研究',
#   '机构',
#   'In-Stat',
#   '日前',
#   '表示',
#   '全球',
#   '使用',
#   '硬盘',
#   '闪存',
#   '存储',
#   '文件',
#   '音乐',
#   '播放器',
#   '出货',
#   '预计',
#   '翻番',
#   '市场',
#   '研究',
#   '机构',
#   '推动',
#   '全球',
#   '音乐',
#   '播放器',
#   '市场',
#   '发展',
#   '动力',
#   '包括',
#   '音乐',
#   '播放器',
#   '产品',
#   '价格',
#   '不断',
#   '下降',
#   '合理',
#   '定制',
#   '可行性',
#   '下载',
#   '付费',
#   '预计',
#   '全球',
#   '音乐',
#   '播放器',
#   '出货',
#   '去年',
#   '增加',
#   'In-Stat',
#   '苹果',
#   '公司',
#   '音乐',
#   '播放器',
#   '领域',
#   '居于',
#   '统治',
#   '地位',
#   '竞争',
#   '对手',
#   '面临',
#   '挑战',
#   '包括',
#   '紧俏',
#   '闪存',
#   '供应',
#   '设备',
#   '软件',
#   '融合',
#   '苹果',
#   'iPod',
#   '产品线',
#   '相关',
#   '因素',
#   '项对',
#   '消费者',
#   '调查',
#   '显示',
#   '49%',
#   '音乐',
#   '播放',
#   '用户',
#   '使用',
#   '产品',
#   '苹果',
#   'iPod'],
#  ['思科',
#   '总裁',
#   '首席',
#   '执行官',
#   '钱伯斯',
#   '周二',
#   '拉斯维加斯',
#   '开幕',
#   'Interop',
#   '大会',
#   '表示',
#   '网络',
#   '企业',
#   '成本',
#   '改变',
#   '促进',
#   '通信',
#   '技术',
#   '发展',
#   '引擎',
#   '包括',
#   '数据',
#   '视频',
#   '语音',
#   '移动',
#   '钱伯斯',
#   '表示',
#   '网络',
#   '改变',
#   '社会',
#   '改善',
#   '劳动生产率',
#   '增长',
#   '速度',
#   '协作',
#   '通信',
#   '方式',
#   '更多',
#   '操作',
#   '系统',
#   '进入',
#   '网络',
#   '网络',
#   '成为',
#   '平台',
#   '表示',
#   '网络',
#   '成为',
#   '平台',
#   '意味',
#   '能够',
#   '更快',
#   '速度',
#   '传输',
#   '带来',
#   '增长',
#   '机会',
#   'IT',
#   '职能',
#   '管理成本',
#   '变为',
#   '增长',
#   '动力',
#   '钱伯斯',
#   '表示',
#   '以前',
#   '一种',
#   '内容',
#   '一种',
#   '设备',
#   '联系',
#   '起来',
#   '现在',
#   '设备',
#   '显示屏',
#   '分享',
#   '相同',
#   '体验',
#   '带来',
#   '劳动生产率',
#   '大幅',
#   '提高',
#   '表示',
#   '通信',
#   '协作',
#   '过程',
#   '并不',
#   '轻松',
#   '思科',
#   '苦于',
#   '不同',
#   '部门',
#   '协作',
#   '协作',
#   '关系',
#   '成为',
#   '基础设施',
#   '思科',
#   '劳动生产率',
#   '得到',
#   '很大',
#   '提高',
#   '编译',
#   '搜狐',
#   'IT',
#   'Unifytruth'],
#  ['本报讯',
#   '记者',
#   '王京',
#   '记者',
#   '英特尔',
#   '公司',
#   '证实',
#   '英特尔',
#   '统一',
#   '台式机',
#   '笔记本',
#   'CPU',
#   '品牌',
#   '现有',
#   'Pentium',
#   '4',
#   '奔腾',
#   'Core',
#   'Duo',
#   '酷睿',
#   'Core',
#   'Duo',
#   '酷睿',
#   '双核',
#   '取代',
#   '品牌',
#   '预计',
#   '今年',
#   '季度',
#   '产品',
#   '使用',
#   '已经',
#   '影响',
#   '一代',
#   '电脑',
#   '奔腾',
#   '品牌',
#   '逐渐',
#   '退出',
#   '历史',
#   '舞台',
#   '英特尔',
#   '相关',
#   '人士',
#   '告诉',
#   '记者',
#   '英特尔',
#   '双核',
#   '处理器',
#   '研发',
#   '代号',
#   '分别为',
#   'Conroe',
#   '台式机处理器',
#   'Merom',
#   '笔记本',
#   '电脑',
#   '处理',
#   '采用',
#   '英特尔',
#   '新一代',
#   'Core',
#   '架构',
#   '结束',
#   '以往',
#   '英特尔',
#   '台式机',
#   '笔记本',
#   '电脑',
#   '处理器',
#   '架构',
#   '不一',
#   '导致',
#   '产品',
#   '品牌',
#   '混乱',
#   '局面',
#   '英特尔',
#   '借此机会',
#   '台式机',
#   '笔记本',
#   '电脑',
#   '处理器',
#   '品牌',
#   '统一',
#   'Core',
#   '2',
#   'Duo',
#   '具体',
#   '英文',
#   '数字',
#   '型号',
#   '标明',
#   '台式机',
#   '笔记本',
#   '电脑',
#   '处理器',
#   '区别',
#   '性能',
#   '功耗',
#   '人士',
#   '表示',
#   '英特尔',
#   '新的',
#   '统一',
#   '品牌',
#   '投入',
#   '极大',
#   '人力',
#   '物力',
#   '研发',
#   '能力',
#   '目的',
#   '提高',
#   '处理器',
#   '性能',
#   '今后',
#   'Pentium',
#   '奔腾',
#   '标志',
#   '逐渐',
#   '电脑',
#   '消失',
#   '记者',
#   '透露',
#   '考虑到',
#   '用户',
#   '不同',
#   '需求',
#   '今后',
#   '一段',
#   '时间',
#   '英特尔',
#   '市场',
#   '提供',
#   '奔腾',
#   '系列',
#   '产品'],
#  ['相',
#   '传统',
#   '购买',
#   '方式',
#   '节省',
#   '七成',
#   '费用',
#   '适合',
#   '购买',
#   '意外险',
#   '图',
#   '易保',
#   '网上',
#   '保险',
#   '候车',
#   '站台',
#   '灯箱',
#   '广告',
#   '目前',
#   '网上',
#   '投保',
#   '一项',
#   '新生事物',
#   '投保人',
#   '金额',
#   '较大',
#   '险种',
#   '进行',
#   '网上',
#   '投保',
#   '有所',
#   '顾虑',
#   '意外险',
#   '险种',
#   '保费',
#   '较低',
#   '投保人',
#   '最为',
#   '放心',
#   '陈锋',
#   '黄金周',
#   '老百姓',
#   '出行',
#   '旅游',
#   '时节',
#   '旅行',
#   '险和',
#   '意外险',
#   '销售',
#   '旺季',
#   '今年',
#   '保险公司',
#   '不约而同',
#   '打出',
#   '网络',
#   '保险公司',
#   '网络',
#   '据',
#   '了解',
#   '已经',
#   '保险',
#   '公司',
#   '推广',
#   '在线',
#   '投保',
#   '云网',
#   '专门',
#   '电子',
#   '商务',
#   '网站',
#   '网上',
#   '保险',
#   '有所',
#   '涉足',
#   '五一',
#   '保险公司',
#   '齐推',
#   '网络',
#   '保险',
#   '情况',
#   '前所未有',
#   '中国',
#   '平安',
#   '五一',
#   '推广',
#   '一款',
#   '网上',
#   '购买',
#   '旅游',
#   '意外险',
#   '推出',
#   '旅游',
#   '出行',
#   '保障',
#   '为主',
#   'e-',
#   '神州',
#   '逍遥',
#   'e-',
#   '四海',
#   '逍遥',
#   'e-',
#   '自驾',
#   '逍遥',
#   'e-',
#   '出行',
#   '无忧',
#   '系列',
#   '电子商务',
#   '渠道',
#   '专用',
#   '产品',
#   '太平洋',
#   '产险',
#   '近期',
#   '推行',
#   '网上',
#   '查询',
#   '保单',
#   '服务',
#   '民生',
#   '人寿',
#   '开通',
#   '电子',
#   '商务',
#   '网站',
#   '网站',
#   '在线',
#   '支付',
#   '保险费用',
#   '变更',
#   '保单',
#   '信息',
#   '查询',
#   '代理人',
#   '信息',
#   '民生',
#   '人寿',
#   '总裁',
#   '助理',
#   '李越',
#   '告诉',
#   '记者',
#   '电子',
#   '商务',
#   '网站',
#   '开通',
#   '消费者',
#   '进行',
#   '网上',
#   '支付',
#   '购买',
#   '保单',
#   '平台',
#   '提供',
#   '全天',
#   '小时',
#   '服务',
#   '投保',
#   '处理',
#   '效率',
#   '大幅',
#   '提高',
#   '完成',
#   '投保',
#   '实时',
#   '生成',
#   '保单',
#   '次日',
#   '零点',
#   '生效',
#   '意外险',
#   '适合',
#   '网络',
#   '投保',
#   '业内人士',
#   '表示',
#   '意外险',
#   '适合',
#   '在线',
#   '投保',
#   '险种',
#   '网上',
#   '投保',
#   '一项',
#   '新事物',
#   '投保人',
#   '金额',
#   '较大',
#   '险种',
#   '进行',
#   '网上',
#   '投保',
#   '有所',
#   '顾虑',
#   '意外险',
#   '险种',
#   '保费',
#   '较低',
#   '投保人',
#   '最为',
#   '放心',
#   '意外险',
#   '投保',
#   '不用',
#   '险种',
#   '需要',
#   '进行',
#   '体检',
#   '条款',
#   '相对',
#   '简单',
#   '相对于',
#   '传统',
#   '保单',
#   '在线',
#   '投保',
#   '程序',
#   '更为',
#   '简便',
#   '通常',
#   '情况下',
#   '投保人',
#   '填写',
#   '投保人',
#   '被保险人',
#   '姓名',
#   '身份证',
#   '联系',
#   '方式',
#   '信息',
#   '即可',
#   '快速',
#   '投保',
#   '投保人',
#   '自主',
#   '选择',
#   '保障',
#   '额度',
#   '保险',
#   '期限',
#   '保单',
#   '生效',
#   '时间',
#   '更容易',
#   '出游',
#   '人员',
#   '欢迎',
#   '网络',
#   '投保人',
#   '出售',
#   '保单',
#   '提供',
#   '服务',
#   '跳过',
#   '传统',
#   '中介',
#   '代理人',
#   '环节',
#   '不用',
#   '代理',
#   '人员',
#   '机构',
#   '支付',
#   '手续费',
#   '传统',
#   '营销',
#   '方式',
#   '节省',
#   '大约',
#   '七成',
#   '费用',
#   '保险公司',
#   '经营',
#   '成本',
#   '较大',
#   '幅度',
#   '降低',
#   '投保人',
#   '进行',
#   '让利',
#   '网上',
#   '投保',
#   '价格',
#   '相对',
#   '便宜',
#   '记者',
#   '张嵩浩'],
#  ['熟知',
#   'MSN',
#   '之外',
#   '微软',
#   '酝酿',
#   '今年',
#   '下半年',
#   '在线',
#   '服务',
#   '方面',
#   '推广',
#   '品牌',
#   'WindowsLive',
#   '借此',
#   '传统',
#   '商业',
#   '模式',
#   '软件',
#   '许可',
#   '获益',
#   '方式转',
#   '广告',
#   '日前',
#   '微软',
#   '次在',
#   '披露',
#   'Live',
#   '战略',
#   'MSN',
#   '大中华区',
#   '总监',
#   '罗川',
#   '上海',
#   '东方',
#   '早报',
#   '记者',
#   '透露',
#   '今年',
#   '下半年',
#   '微软',
#   'WindowsLive',
#   '软件',
#   '服务',
#   '全球',
#   '进行',
#   '推广',
#   '罗川',
#   '表示',
#   '具体',
#   '时间',
#   '尚未',
#   '最终',
#   '确定',
#   '相信',
#   '不知不觉',
#   '改变',
#   '网络',
#   '使用',
#   '习惯',
#   'WindowsLive',
#   '推出',
#   '并不',
#   '意味着',
#   'MSN',
#   '消失',
#   '罗川',
#   '透露',
#   'MSN',
#   '提供',
#   '一种',
#   '编排',
#   '信息',
#   'WindowsLive',
#   '提供',
#   '用户',
#   '选择',
#   '信息',
#   'Win-dowsLive',
#   '给予',
#   '用户',
#   '更多',
#   '可选择性',
#   '自由',
#   '设计',
#   '互联网',
#   '应用',
#   '平台',
#   '用户',
#   '兴趣',
#   '建立',
#   '稳定',
#   '群体',
#   '据悉',
#   '去年',
#   '微软',
#   '董事会',
#   '主席',
#   '比尔·盖茨',
#   '已经',
#   '拉开',
#   'Live',
#   '软件',
#   '序幕',
#   '微软',
#   '高级',
#   '副总裁',
#   '大卫·科利',
#   '备忘录',
#   'WindowsLive',
#   '战略',
#   '希望',
#   '互联网',
#   '争夺战',
#   '获胜',
#   '能够',
#   '刺激',
#   '微软',
#   '劳师动众',
#   '网络',
#   '广告',
#   '市场',
#   '突飞猛进',
#   '增长',
#   '过去',
#   '微软',
#   '活动',
#   '不断',
#   '围绕',
#   '视窗',
#   '从今',
#   '往后',
#   '围绕',
#   '广告',
#   '广告',
#   '微软公司',
#   '内部',
#   '传播',
#   '广泛',
#   '一段',
#   '影像',
#   '微软',
#   '副总裁',
#   '激动',
#   '言辞',
#   '已经',
#   '微软',
#   '广告',
#   '野心',
#   '昭告',
#   '天下',
#   '罗川',
#   '说法',
#   'WindowsLive',
#   '微软',
#   '商业',
#   '模式',
#   '广告',
#   '收费',
#   '领域',
#   '转型',
#   '重要',
#   '利器',
#   '固定',
#   '有着',
#   '相同',
#   '兴趣',
#   '快速',
#   '发展',
#   '用户',
#   '广告商',
#   '信息',
#   '恰当',
#   '提供',
#   '用户',
#   '完成',
#   '广告',
#   '配送',
#   '广告',
#   '发布',
#   '有效',
#   '过程',
#   '罗川',
#   '表示',
#   '罗',
#   '表示',
#   'Google',
#   '广告',
#   '方面',
#   '已经',
#   '非常',
#   '出色',
#   '微软',
#   '希望',
#   'WindowsLive',
#   '能够',
#   '赶上',
#   '发展',
#   '步伐',
#   'WindowsLive',
#   '微软',
#   '软件',
#   '相同',
#   '地方',
#   '商业',
#   '模式',
#   '微软',
#   '江山',
#   '软件',
#   '许可',
#   '获准',
#   '方式',
#   '转变',
#   '广告',
#   '收费',
#   '获得',
#   '商业',
#   '价值',
#   'Google',
#   '点击',
#   '付费',
#   '模式',
#   '出现',
#   'WindowsLive',
#   '罗川',
#   '罗川',
#   '表示',
#   '微软',
#   '全球',
#   '软件',
#   '市场',
#   '已经',
#   '占据',
#   '相当',
#   '可观',
#   '市场',
#   '份额',
#   '广告',
#   '市场',
#   '比例',
#   '仍然',
#   '微小',
#   '并称',
#   '希望',
#   '未来',
#   '能够',
#   '网络',
#   '广告',
#   '市场',
#   '份额',
#   '提升',
#   '10%',
#   '左右',
#   '据悉',
#   '目前',
#   '微软',
#   '收入',
#   '软件',
#   '业务',
#   '全球',
#   '网络',
#   '广告',
#   '市场',
#   '规模',
#   '微软',
#   '占据'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '时间',
#   '周一',
#   '美国半导体工业协会',
#   '公布',
#   '全球',
#   '半导体',
#   '贸易',
#   '统计',
#   '机构',
#   '最新',
#   '统计',
#   '数据',
#   '显示',
#   '今年',
#   '季度',
#   '全球',
#   '半导体',
#   '销售',
#   '收入',
#   '达到',
#   '去年',
#   '季度',
#   '销售',
#   '收入',
#   '增长',
#   '7.3%',
#   '季度',
#   '销售',
#   '收入',
#   '去年',
#   '第四季度',
#   '半导体',
#   '收入',
#   '下降',
#   '1.3%',
#   '美国半导体工业协会',
#   '表示',
#   '去年',
#   '第四季度',
#   '半导体',
#   '销售',
#   '假日',
#   '销售',
#   '旺季',
#   '推动',
#   '今年',
#   '季度',
#   '收入',
#   '下降',
#   '反映',
#   '一种',
#   '正常',
#   '季节性',
#   '疲软',
#   '销售',
#   '模式',
#   '今年',
#   '季度',
#   '平均',
#   '销售',
#   '收入',
#   '去年',
#   '季度',
#   '平均',
#   '销售',
#   '收入'],
#  ['摘要',
#   '服务',
#   'Napster',
#   '现有',
#   '预定',
#   '服务',
#   '增加',
#   '用户',
#   '选定',
#   '音乐',
#   '下载',
#   '链接',
#   '发送',
#   '朋友',
#   '用户',
#   '选购',
#   '歌曲',
#   '免费',
#   '网站',
#   '收听',
#   '天极网',
#   '消息',
#   '老沈',
#   '编译',
#   '外电',
#   '报道',
#   '一度',
#   '背叛',
#   '音乐',
#   '下载',
#   '服务',
#   '网站',
#   'Napster',
#   '再次',
#   '服务',
#   '回到',
#   '根基',
#   'Napster',
#   '音乐',
#   '提供',
#   '免费',
#   '欣赏',
#   '多万',
#   '首歌曲',
#   '机会',
#   'Napster',
#   'com',
#   '周一',
#   '推出',
#   '服务',
#   '依靠',
#   '广告',
#   '支持',
#   '唱片',
#   '公司',
#   '谈判',
#   '做出',
#   '决定',
#   'Napster',
#   '歌手',
#   '曲目',
#   '播放',
#   '次数',
#   '基础上',
#   '唱片',
#   '公司',
#   '分享',
#   '广告',
#   '收入',
#   '服务',
#   'Napster',
#   '现有',
#   '预定',
#   '服务',
#   '增加',
#   '用户',
#   '选定',
#   '音乐',
#   '下载',
#   '链接',
#   '发送',
#   '朋友',
#   '用户',
#   '选购',
#   '歌曲',
#   '免费',
#   '网站',
#   '收听',
#   '公司',
#   'CEO',
#   'Gorog',
#   'Napster',
#   'com',
#   '建成',
#   '开放',
#   '平台',
#   'CEO',
#   '媒体',
#   '期望',
#   '免费',
#   '服务',
#   '增加',
#   '用户',
#   '网站',
#   '访问量',
#   'Napster',
#   '网站',
#   '一直',
#   '销售',
#   '下载',
#   '音乐',
#   '目前',
#   '访问',
#   '用户',
#   '更高',
#   '用户',
#   '流量',
#   '公司',
#   '带来',
#   '更多',
#   '广告',
#   '收入',
#   'Napster',
#   '公司',
#   '名列',
#   '美国',
#   '音乐',
#   '下载',
#   '服务',
#   '市场',
#   '远远',
#   '落后',
#   '苹果',
#   '电脑',
#   'iTunes',
#   '70%',
#   '市场',
#   '份额'],
#  ['盛大网络',
#   '周一',
#   '表示',
#   '首席',
#   '财务',
#   '高级',
#   '副总裁',
#   '李曙君',
#   '辞职',
#   '追求',
#   '事业',
#   '生效',
#   '继续',
#   '担任',
#   '公司',
#   '董事',
#   '从',
#   '担任',
#   '公司',
#   '财务',
#   '总监',
#   '张勇',
#   '接替',
#   '李曙君',
#   '张勇',
#   '1991-1995',
#   '毕业',
#   '上海',
#   '财经大学',
#   '取得',
#   '金融学',
#   '学士',
#   '学位',
#   '张勇',
#   '期间',
#   '就职',
#   '安达信',
#   '会计师',
#   '事务所',
#   '担任',
#   '上海',
#   '办事处',
#   '经理',
#   '担任',
#   '普华永道',
#   '会计师',
#   '事务所',
#   '上海',
#   '办事处',
#   '高级',
#   '经理',
#   '李曙君',
#   '担任',
#   '公司',
#   '副总裁',
#   '担任',
#   '公司',
#   '首席',
#   '财务',
#   '之前',
#   '投资',
#   '海外',
#   '业务',
#   '总监',
#   '加入',
#   '之前',
#   '李曙君',
#   '曾在',
#   '期间',
#   '基金',
#   '管理',
#   '公司',
#   '筹建',
#   '期间',
#   '担任',
#   '中国',
#   '南方证券有限公司',
#   '国际业务部',
#   '高级',
#   '经理',
#   '编译',
#   '搜狐',
#   'IT',
#   'Unifytruth'],
#  ['街道',
#   '住宅',
#   '保存',
#   '相当',
#   '完整',
#   '姆大陆',
#   '消失',
#   '文明',
#   '毁于一旦',
#   '消失',
#   '亚特兰蒂斯',
#   '大陆',
#   '令人神往',
#   '吸引',
#   '科学家',
#   '探险家',
#   '追寻',
#   '踪迹',
#   '今天',
#   '探险家',
#   '科学家',
#   '目光',
#   '转向',
#   '失去',
#   '大陆',
#   '传说中',
#   '姆大陆',
#   '越来越',
#   '证据',
#   '显示',
#   '姆大陆',
#   '可能',
#   '连接',
#   '文明',
#   '脐带',
#   '街道',
#   '住宅',
#   '保存',
#   '完整',
#   '城市',
#   '港口',
#   '规模',
#   '庞大',
#   '潜水',
#   '考古学',
#   '发现',
#   '姆大陆',
#   '见解',
#   '提供',
#   '必要',
#   '密克罗尼西亚',
#   '群岛',
#   '波纳佩',
#   '附近',
#   '海底',
#   '一片',
#   '沉没',
#   '古陆',
#   '潜水',
#   '人员',
#   '附近',
#   '海底',
#   '发现',
#   '保存',
#   '相当',
#   '完整',
#   '街道',
#   '石柱',
#   '石像',
#   '住宅',
#   '海底捞',
#   '十分',
#   '珍贵',
#   '黄金和',
#   '珠宝',
#   '饰物',
#   '太平洋',
#   '岛屿',
#   '都留有',
#   '巨大',
#   '石头',
#   '平台',
#   '石头',
#   '遗址',
#   '石头',
#   '雕像',
#   '学者',
#   '猜测',
#   '地区',
#   '曾经',
#   '存在',
#   '高度',
#   '文明',
#   '种族',
#   '高度',
#   '建筑',
#   '技巧',
#   '建成',
#   '城市',
#   '雕像',
#   '港口',
#   '迄今',
#   '知道',
#   '原因',
#   '集体',
#   '撤离',
#   '集体',
#   '灭绝',
#   '留下',
#   '壮观',
#   '建筑',
#   '遗迹',
#   '能够',
#   '冶炼',
#   '金属',
#   '使用',
#   '核能',
#   '科学家',
#   '考古学家',
#   '今天',
#   '非洲',
#   '加蓬共和国',
#   '发现',
#   '年前',
#   '链式',
#   '核反应堆',
#   '南非',
#   '发现',
#   '年前',
#   '金属球',
#   '很',
#   '显然',
#   '文明',
#   '古迹',
#   '不属于',
#   '人类',
#   '创造',
#   '实际上',
#   '文明',
#   '古迹',
#   '人类',
#   '技术',
#   '无法',
#   '建造',
#   '确凿',
#   '证据',
#   '学者',
#   '提出',
#   '文明',
#   '学说',
#   '人类',
#   '文明',
#   '之前',
#   '地球',
#   '曾经',
#   '存在',
#   '高度',
#   '文明',
#   '罗盘',
#   '失灵',
#   '无线电',
#   '中断',
#   '核潜艇',
#   '神秘',
#   '失踪',
#   '姆大陆',
#   '沉没',
#   '地方',
#   '自古以来',
#   '经常',
#   '发生',
#   '神秘',
#   '失踪',
#   '事件',
#   '船只',
#   '飞机',
#   '进入',
#   '水域',
#   '出现',
#   '罗盘',
#   '失灵',
#   '无线电',
#   '通讯',
#   '故障',
#   '中断',
#   '现象',
#   '已经',
#   '透露',
#   '消息',
#   '船只',
#   '照样',
#   '发生',
#   '事故',
#   '前苏联',
#   '先后',
#   '潜水艇',
#   '失踪',
#   '大部分',
#   '具有',
#   '先进',
#   '设备',
#   '核动力',
#   '潜艇',
#   '猜测',
#   '大洋',
#   '海底',
#   '可能',
#   '隐藏',
#   '文明',
#   '留下来',
#   '防卫',
#   '系统',
#   '导致',
#   '核潜艇',
#   '翻船',
#   '航海',
#   '建筑',
#   '发达',
#   '来往',
#   '乘坐',
#   '飞行船',
#   '专门',
#   '收集',
#   '古代',
#   '玛雅',
#   '传说',
#   '神话',
#   '特洛亚诺古',
#   '抄本',
#   '记载',
#   '姆大陆',
#   '消失',
#   '一万',
#   '千年',
#   '亚特兰蒂斯',
#   '大陆',
#   '沉没',
#   '姆大陆',
#   '土地',
#   '辽阔',
#   '东起',
#   '现今',
#   '夏威夷',
#   '群岛',
#   '西至',
#   '马里亚纳',
#   '群岛',
#   '南边',
#   '斐济',
#   '大溪地',
#   '群岛',
#   '复活节岛',
#   '大陆',
#   '东西',
#   '南北',
#   '总面积',
#   '一块',
#   '美丽',
#   '富饶',
#   '地方',
#   '英国人',
#   '詹姆士·丘吉沃德',
#   '遗失',
#   '大陆',
#   '一书',
#   '详细',
#   '描绘',
#   '地面',
#   '繁荣昌盛',
#   '帝国',
#   '姆大陆',
#   '帝国',
#   '共同',
#   '创造',
#   '灿烂',
#   '文化',
#   '航海',
#   '建筑业',
#   '相当',
#   '发达',
#   '大作',
#   '诸岛',
#   '传播',
#   '文明',
#   '帝国',
#   '科学技术',
#   '水平',
#   '很高',
#   '发明',
#   '行船',
#   '经常',
#   '来往',
#   '珍奇',
#   '物品',
#   '宝石',
#   '空中',
#   '鸟瞰',
#   '古地图',
#   '南极洲',
#   '爱因斯坦',
#   '科学家',
#   '坚信',
#   '如今',
#   '冰天雪地',
#   '毫无',
#   '生机',
#   '南极',
#   '可能',
#   '曾经',
#   '存在',
#   '文明',
#   '科学家',
#   '土耳其',
#   '伊斯坦布尔',
#   '托普卡比',
#   '发现',
#   '空中',
#   '鸟瞰',
#   '地图',
#   '上面',
#   '美洲',
#   '非洲',
#   '变形',
#   '轮廓线',
#   '阿波罗',
#   '飞船',
#   '拍摄',
#   '照片',
#   '完全',
#   '重合',
#   '令人',
#   '惊讶',
#   '地图',
#   '南极洲',
#   '冰层',
#   '覆盖',
#   '复杂',
#   '地貌',
#   '南极探险队',
#   '回声',
#   '探测仪',
#   '南极冰',
#   '地形',
#   '探测',
#   '毫无二致',
#   '证据',
#   '显示',
#   '南极洲',
#   '最早',
#   '地图',
#   '绘制',
#   '年前',
#   '当时',
#   '大陆',
#   '冰雪',
#   '覆盖',
#   '科学家',
#   '设想',
#   '多年前',
#   '南极',
#   '大陆',
#   '处于',
#   '温带',
#   '优越',
#   '自然环境',
#   '孕育',
#   '高度',
#   '发达',
#   '文明',
#   '掌握',
#   '先进',
#   '航海技术',
#   '天文',
#   '知识',
#   '率领',
#   '船队',
#   '穿梭',
#   '大洋',
#   '大陆',
#   '之间',
#   '文明',
#   '带到',
#   '世界',
#   '角落',
#   '蛮荒',
#   '落后',
#   '大陆',
#   '智慧',
#   '奇迹',
#   '成为',
#   '文化',
#   '交流',
#   '联系',
#   '桥梁',
#   '帝国',
#   '日趋',
#   '繁荣',
#   '危险',
#   '始终',
#   '存在',
#   '直至',
#   '突然',
#   '毁灭',
#   '原因',
#   '导致',
#   '人类',
#   '拥有',
#   '文明',
#   '最终',
#   '地球上',
#   '消失',
#   '灭绝',
#   '当时',
#   '生物',
#   '残留',
#   '极其',
#   '幸存',
#   '古迹',
#   '古城',
#   '遗址',
#   '核爆',
#   '痕迹',
#   '曾经',
#   '文明',
#   '核爆炸',
#   '印度',
#   '古城',
#   '遗址',
#   '哈拉巴',
#   '马享',
#   '佐·达摩',
#   '距今',
#   '至少',
#   '历史',
#   '马享',
#   '佐·达摩',
#   '出土',
#   '遗骨',
#   '比较',
#   '废墟',
#   '发现',
#   '成排',
#   '死去',
#   '遗体',
#   '双手',
#   '盖住',
#   '好像',
#   '保护',
#   '好像',
#   '看见',
#   '害怕',
#   '事情',
#   '肯定',
#   '突然',
#   '状态',
#   '死去',
#   '印度',
#   '考古学家',
#   '卡哈',
#   '出土',
#   '进行',
#   '详细',
#   '化学',
#   '分析',
#   '发现',
#   '高温',
#   '加热',
#   '痕迹',
#   '说明',
#   '马享',
#   '佐·达摩',
#   '毁灭',
#   '突然',
#   '出现',
#   '高温',
#   '马享',
#   '佐·达摩',
#   '发现',
#   '坍塌',
#   '建筑物',
#   '承受',
#   '高温',
#   '痕迹',
#   '发现',
#   '玻璃',
#   '建筑',
#   '立提',
#   '物质',
#   '物质',
#   '形成',
#   '瞬间',
#   '高温',
#   '熔化',
#   '物体',
#   '表面',
#   '迅速',
#   '冷却',
#   '造成',
#   '热核武器',
#   '爆炸',
#   '现场',
#   '发现',
#   '人为',
#   '物质',
#   '证据',
#   '说明',
#   '发生',
#   '爆炸',
#   '一夜之间',
#   '毁掉',
#   '一座',
#   '城池',
#   '印度',
#   '古巴比伦',
#   '撒哈拉',
#   '沙漠',
#   '蒙古',
#   '戈壁',
#   '发现',
#   '核战',
#   '废墟',
#   '废墟',
#   '玻璃',
#   '都与',
#   '今天',
#   '核试验',
#   '玻璃',
#   '一模一样',
#   '国外',
#   '物理学家',
#   '弗里德里克·索迪',
#   '认为',
#   '相信',
#   '人类',
#   '曾有',
#   '文明',
#   '人类',
#   '时已',
#   '熟悉',
#   '原子能',
#   '误用',
#   '遭到',
#   '毁灭',
#   '相关',
#   '链接',
#   '非洲',
#   '加蓬共和国',
#   '发现',
#   '年前',
#   '铀矿',
#   '奥克洛',
#   '铀矿',
#   '矿里',
#   '发现',
#   '不可思议',
#   '遗迹',
#   '古老',
#   '核反应堆',
#   '区域',
#   '大约',
#   '铀矿石',
#   '组成',
#   '运转',
#   '时间',
#   '长达',
#   '年之久',
#   '离',
#   '南美洲',
#   '太平洋',
#   '小岛',
#   '复活节岛',
#   '巨石',
#   '筑成',
#   '石殿',
#   '金字塔',
#   '吸引',
#   '余尊',
#   '面海',
#   '屹立',
#   '形状',
#   '奇特',
#   '半身',
#   '石雕',
#   '土著',
#   '口头',
#   '流传',
#   '传说',
#   '从前',
#   '一块',
#   '称为',
#   '希瓦',
#   '大陆',
#   '后来',
#   '突变',
#   '大部分',
#   '地区',
#   '沉沦',
#   '洋底',
#   '留下',
#   '复活节岛',
#   '撰文',
#   '亚锋'],
#  ['新华网',
#   '北京',
#   '专电',
#   '记者',
#   '晓芳',
#   '信息产业部',
#   '近日',
#   '公布',
#   '违规',
#   '移动信息',
#   '举报',
#   '电话',
#   '信息产业部',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '010-12300',
#   '北京市',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '010-68212300',
#   '地区',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '直辖市',
#   '省会',
#   '区号',
#   '用户',
#   '登录',
#   '信息',
#   '产业',
#   '网站',
#   'www',
#   'mii',
#   'gov',
#   'cn',
#   '进行',
#   '投诉',
#   '举报',
#   '了解',
#   '信息产业部',
#   '利用',
#   '左右',
#   '时间',
#   '全国',
#   '范围内',
#   '开展',
#   '治理',
#   '规范',
#   '信息',
#   '服务',
#   '企业',
#   '资费',
#   '收费',
#   '活动',
#   '明码',
#   '标价',
#   '信息',
#   '订购',
#   '计费',
#   '流程',
#   '收费',
#   '方式',
#   '资费',
#   '争议',
#   '处理',
#   '方面',
#   '相关',
#   '企业',
#   '进行',
#   '规范',
#   '加大',
#   '广播',
#   '电视',
#   '报纸',
#   '互联网',
#   '媒体',
#   '参与',
#   '互动',
#   '短信',
#   '规范',
#   '查处',
#   '力度',
#   '信息产业部',
#   '要求',
#   '相关',
#   '企业',
#   '近期',
#   '进行',
#   '自查自纠',
#   '信息产业部',
#   '组织',
#   '专门',
#   '力量',
#   '监督',
#   '检查',
#   '情况',
#   '社会',
#   '公布',
#   '恶意',
#   '侵犯',
#   '消费者',
#   '合法',
#   '权益',
#   '屡次',
#   '违规',
#   '信息',
#   '服务',
#   '企业',
#   '国家',
#   '充分',
#   '运用',
#   '法律',
#   '经济',
#   '技术',
#   '行政',
#   '手段',
#   '严厉',
#   '查处'],
#  ['天极网',
#   '消息',
#   '他山石',
#   '编译',
#   '外电',
#   '报道',
#   '全球',
#   '面板',
#   '制造商',
#   '友达',
#   '公司',
#   '奇美',
#   '电子',
#   '公司',
#   'LG',
#   '飞利浦',
#   '液晶',
#   '显示器',
#   '公司',
#   '今年',
#   '季度',
#   '面板',
#   '存货',
#   '过多',
#   '预期',
#   '今年',
#   '季度',
#   '全球',
#   '面板',
#   '行业',
#   '可能',
#   '发生',
#   '供过于求',
#   '现象',
#   '据',
#   '公司',
#   '公布',
#   '数据',
#   '显示',
#   '今年',
#   '季度',
#   '面板',
#   '存货',
#   '水平',
#   '同比',
#   '增长',
#   '18.4%',
#   '达到',
#   '新台币',
#   '资金周转',
#   '天数',
#   '增长',
#   '友达',
#   '公司',
#   '相比',
#   '奇美',
#   '电子',
#   '公司',
#   '面临',
#   '存货',
#   '过多',
#   '压力',
#   '更大',
#   '存货',
#   '价值',
#   '已经',
#   '达到',
#   '新台币',
#   '同比',
#   '增长',
#   '44.8%',
#   '资金周转',
#   '天数',
#   '一季度',
#   '增长',
#   '内部',
#   '存货',
#   '40%',
#   '完成',
#   '产品',
#   '35%',
#   '半成品',
#   '生产',
#   '生产',
#   '今年',
#   '季度',
#   'LG',
#   '飞利浦',
#   '液晶',
#   '显示器',
#   '公司',
#   '存货',
#   '水平',
#   '增长',
#   '三周',
#   '今年',
#   '四月',
#   '生产线',
#   '生产',
#   '月份',
#   '20%',
#   '30%',
#   '已经',
#   '达到',
#   '70%',
#   '80%'],
#  ['昨天',
#   '记者',
#   '了解到',
#   '我国',
#   '目前',
#   '余家',
#   '电子签名',
#   '认证',
#   '服务',
#   '机构',
#   '拥有',
#   '国家',
#   '电子',
#   '认证',
#   '服务',
#   '许可证',
#   '余家',
#   '竟未',
#   '认证',
#   '信产部',
#   '信息化',
#   '推进',
#   '司长',
#   '陈伟',
#   '透露',
#   '信产部',
#   '即日',
#   '月底',
#   '展开',
#   '相关',
#   '清查',
#   '工作',
#   '信产部',
#   '严查',
#   '机构',
#   '陈伟',
#   '透露',
#   '中华人民共和国',
#   '电子签名',
#   '实施',
#   '获得',
#   '国家',
#   '电子',
#   '认证',
#   '服务',
#   '许可证',
#   '认证',
#   '机构',
#   '已经',
#   '发出',
#   '电子',
#   '证书',
#   '电子签名',
#   '规定',
#   '拥有',
#   '许可证',
#   '电子认证',
#   '机构',
#   '提供',
#   '电子签名',
#   '认证',
#   '服务',
#   '清查',
#   '正规',
#   '机构',
#   '进行',
#   '自查自纠',
#   '派出',
#   '抽查',
#   '小组',
#   '进行',
#   '检查',
#   '月初',
#   '公布',
#   '清查',
#   '月底',
#   '再次',
#   '公告',
#   '行动',
#   '严查',
#   '没有',
#   '国家',
#   '认证',
#   '电子',
#   '认证',
#   '机构',
#   '电子签名',
#   '任重道远',
#   '电子商务',
#   '电子',
#   '政务',
#   '迅猛',
#   '发展',
#   '电子',
#   '签名',
#   '应用',
#   '范围',
#   '越来越',
#   '广泛',
#   '电子商务',
#   '企业',
#   '提高',
#   '电子',
#   '认证',
#   '质量',
#   '可信度',
#   '依靠',
#   '电子商务',
#   '企业',
#   '认证',
#   '管理',
#   '机构',
#   '共同',
#   'ax',
#   '实现',
#   '国务院',
#   '信息办',
#   '推广',
#   '副组长',
#   '张大明',
#   '透露',
#   '电子签名',
#   '重要',
#   '没有',
#   '足够',
#   '重视',
#   '建设',
#   '认证',
#   '机构',
#   '资金',
#   '投入',
#   '技术',
#   '更新',
#   '外资',
#   '银行',
#   '挑战',
#   '目前',
#   '国家',
#   '到底',
#   '需要',
#   '使用',
#   '认证',
#   '技术',
#   '明确',
#   '业内',
#   '行业',
#   '竞争',
#   '规范',
#   '记者',
#   '了解到',
#   '正规',
#   '电子认证',
#   '机构',
#   '发布',
#   '电子认证',
#   '诚信',
#   '服务',
#   '倡议书',
#   '倡议',
#   '成员',
#   '机构',
#   '北京',
#   '天威',
#   '诚信',
#   '数字',
#   '认证',
#   '中心',
#   '副总裁',
#   '李延昭',
#   '接受',
#   '记者',
#   '采访',
#   '表示',
#   '目前',
#   '电子签名',
#   '认证',
#   '企业',
#   '目前',
#   '规范',
#   '电子签名',
#   '出台',
#   '之前',
#   '存在',
#   '电子签名',
#   '认证',
#   '机构',
#   '大部分',
#   '银行',
#   '金融',
#   '行业',
#   '总体',
#   '市场',
#   '规范',
#   '行业',
#   '竞争',
#   '激烈',
#   '业内',
#   '普遍',
#   '担心',
#   '行业',
#   '起来',
#   '目前',
#   '普遍',
#   '业务',
#   '资费',
#   '企业',
#   '端也',
#   '机构',
#   '仍然',
#   '使用',
#   '免费',
#   '低价',
#   '恶意',
#   '竞争',
#   '方式',
#   '市场'],
#  ['端',
#   '点到点',
#   '端到',
#   'END-TO-END',
#   '点到点',
#   'POINT-TO-POINT',
#   '描述',
#   '网络',
#   '传输',
#   '实体',
#   'PEER',
#   'RNTITY',
#   '之间',
#   '关系',
#   '概念',
#   '端到',
#   '系统',
#   '信源',
#   '机上',
#   '实体',
#   '最终',
#   '信宿',
#   '对等',
#   '实体',
#   '用户',
#   '终端',
#   '直接',
#   '通信',
#   '之间',
#   '拥有',
#   '直通',
#   '线路',
#   '传输',
#   '过程',
#   '中断',
#   '节点',
#   '点到点',
#   '系统',
#   '对等',
#   '实体',
#   '通信',
#   '一段',
#   '直接',
#   '相连',
#   '计算机',
#   '通信',
#   '信道',
#   '组成',
#   '机器',
#   '直接',
#   '连接',
#   '点到点',
#   '连接',
#   '网卡',
#   '网卡',
#   '计算机',
#   '总线',
#   '上面',
#   '硬件',
#   '接口卡',
#   '终端',
#   '接入',
#   '以太网',
#   '以太网',
#   '网卡',
#   '接入',
#   'X.25',
#   '网络',
#   'X.25',
#   '中继器',
#   'REPEATER',
#   '中继器',
#   '网络',
#   '物理层',
#   '上面',
#   '连接',
#   '设备',
#   '适用',
#   '完全',
#   '相同',
#   '网络',
#   '互连',
#   '功能',
#   '数据',
#   '信号',
#   '重新',
#   '发送',
#   '转发',
#   '扩大',
#   '网络',
#   '传输',
#   '距离',
#   '网桥',
#   'BRIDGE',
#   '存储转发',
#   '设备',
#   '连接',
#   '同类型',
#   '网络拓扑',
#   '传输',
#   '介质',
#   '局域网',
#   'LAN',
#   '完成',
#   '数据',
#   '链路层',
#   '路由器',
#   'ROUTER',
#   '路由器',
#   '网络层',
#   '部分',
#   '互连',
#   '设备',
#   '功能',
#   '数据',
#   '流量',
#   '控制',
#   '差错',
#   '适时',
#   '控制',
#   '路由',
#   '选择',
#   '控制',
#   '进行',
#   '数据包',
#   '交换',
#   '网关',
#   'GATEWAY',
#   '用于',
#   '传输',
#   '传输层',
#   '高层',
#   '互连',
#   '连接器',
#   '互连',
#   '网络',
#   '类型',
#   '差别',
#   '之间',
#   '连接器'],
#  ['网友',
#   '浏览',
#   '网页',
#   '发现',
#   '重庆',
#   '代表',
#   '中国',
#   '特色',
#   '餐饮',
#   '火锅',
#   '韩国',
#   '企业',
#   '抢注',
#   '域名',
#   '网上',
#   '吆喝',
#   '重庆火锅',
#   '协会',
#   '表示',
#   '会同',
#   '中国',
#   '烹饪',
#   '协会',
#   '保护',
#   '中国',
#   '火锅',
#   '域名',
#   '重庆火锅',
#   '是否',
#   '侵权',
#   '进行',
#   '沟通',
#   '探讨',
#   '维权',
#   '可行性',
#   '媒体',
#   '部分',
#   '超女',
#   '中文',
#   'CN',
#   '中文',
#   '域名',
#   '离奇',
#   '服务',
#   '爬虫',
#   '事件',
#   '传出',
#   '索尔列恩兹',
#   '公司',
#   '电影',
#   '指环王',
#   '品牌',
#   '形象',
#   '拥有',
#   '国际',
#   '经济',
#   '贸易',
#   '仲裁',
#   '委员会',
#   '域名',
#   '争议',
#   '解决',
#   '中心',
#   '申请',
#   '仲裁',
#   '指环王',
#   'CN',
#   '归属',
#   '域名',
#   '争议',
#   '解决',
#   '办法',
#   '生效',
#   '一天',
#   '可口可乐',
#   '代表',
#   '埃克森',
#   '雀巢',
#   '羽西',
#   '托福',
#   '国际',
#   '品牌',
#   '扎堆',
#   '追讨',
#   'CN',
#   '中文',
#   '域名',
#   '年初',
#   '中文',
#   '域名',
#   '风波',
#   '不断',
#   '太多',
#   '企业',
#   '品牌',
#   '资产',
#   '管理',
#   '层面',
#   '远未',
#   '真正',
#   '准备好',
#   '适应',
#   '网络',
#   '经济',
#   '时代',
#   '到来',
#   '注册',
#   '保护',
#   '应用',
#   'CN',
#   '刻不容缓',
#   '年底',
#   '微软',
#   '宣布',
#   'IE7.0',
#   '全面',
#   '支持',
#   '中文',
#   '域名',
#   '尤其',
#   '中文',
#   '上网',
#   '时代',
#   '大前提',
#   '注册',
#   '保护',
#   '应用',
#   'CN',
#   '中文',
#   '域名',
#   '已经',
#   '大势所趋',
#   'GOOGLE',
#   '宣布',
#   '启用',
#   '中文',
#   '名称',
#   '谷歌',
#   '年底',
#   '抢注',
#   '古歌',
#   'CN',
#   '月前',
#   '抢注',
#   '谷歌',
#   'CN',
#   '当天',
#   '极易',
#   '输入',
#   '产生',
#   '失误',
#   '谷哥',
#   'CN',
#   '抢注',
#   '不能',
#   'GOOGLE',
#   '本土化',
#   '网络',
#   '品牌',
#   '把握',
#   '百密一疏',
#   '业内',
#   '专家',
#   '强调',
#   '中文',
#   '上网',
#   '时代',
#   '中文',
#   'CN',
#   '中文',
#   '域名',
#   '品牌',
#   '资产',
#   '注册',
#   '保护',
#   '应用',
#   '同样',
#   '拿出',
#   '传统',
#   '经济',
#   '领域',
#   '全面',
#   '细致',
#   '精神',
#   '企业',
#   '知名',
#   '品牌',
#   '专利',
#   '技术',
#   '特色',
#   '产品',
#   '进行',
#   '全面',
#   '中文',
#   'CN',
#   '中文',
#   '域名',
#   '注册',
#   '保护',
#   '亦要',
#   '可能',
#   '产生',
#   '误解',
#   '歧义',
#   '词汇',
#   '进行',
#   '注册',
#   '能够',
#   '企业',
#   '互联网',
#   '经济',
#   '时代',
#   '品牌',
#   '发展',
#   '编织',
#   '一道',
#   '全面',
#   '防护网',
#   '能够',
#   '企业',
#   '今后',
#   '网络',
#   '品牌',
#   '发展',
#   '创造',
#   '良好',
#   '网络',
#   '基础',
#   '环境'],
#  ['所谓',
#   'IP',
#   '主叫',
#   '业务',
#   '全名',
#   '应该',
#   'IP',
#   '主叫',
#   '识别',
#   '业务',
#   '用户',
#   '电话',
#   '号码',
#   '识别码',
#   '拨打',
#   'IP',
#   '电话',
#   'IP',
#   '电话卡',
#   '都要先',
#   '拨打',
#   '账号',
#   '密码',
#   '达成',
#   '数字',
#   '数字',
#   '其实',
#   'IP',
#   '电话卡',
#   '识别',
#   'IP',
#   '主叫',
#   '号码',
#   '利用',
#   '用户',
#   '固定',
#   '电话',
#   '号码',
#   '识别',
#   '方某',
#   '用户',
#   '家里',
#   '电话',
#   '电话',
#   '拨打',
#   '电话',
#   '电话局',
#   '知道',
#   '号码',
#   '曾经',
#   '拨打',
#   '收取',
#   '相应',
#   '费用',
#   '好处',
#   '使用',
#   '方便',
#   '过去',
#   '使用',
#   'IP',
#   '打电话',
#   '输入',
#   '账号',
#   '再加',
#   '密码',
#   '不好',
#   '中途',
#   '数字',
#   '需要',
#   '挂断',
#   '如今',
#   '不用',
#   '记住',
#   '密码',
#   '需要',
#   '记住',
#   '直接',
#   '拨打',
#   '购买',
#   '方便',
#   '购买',
#   '方便',
#   'IP',
#   '主叫',
#   '电话',
#   '付费',
#   '用户',
#   '拨打',
#   '没有',
#   '购买',
#   '过程',
#   '电话费',
#   '一并',
#   '省去',
#   '用户',
#   '麻烦',
#   '回顾',
#   'IP',
#   '市场',
#   '争夺',
#   '情况',
#   '发现',
#   'IP',
#   '市场',
#   '目前',
#   '电信业',
#   '争夺',
#   '最为',
#   '激烈',
#   '竞争',
#   '最为',
#   '充分',
#   '领域',
#   '目前',
#   'IP',
#   '主叫',
#   '电话',
#   '已经',
#   '方便',
#   '拨号',
#   '接入',
#   '良好',
#   '话音',
#   '质量',
#   '合理',
#   '资费',
#   '标准',
#   '吸引',
#   '家庭',
#   '用户',
#   '越来越',
#   '中小企业',
#   '选用',
#   'IP',
#   '主叫',
#   '电话',
#   '业务',
#   '处于',
#   '成本',
#   '考虑',
#   '看中',
#   'IP',
#   '主叫',
#   '电话',
#   '方便',
#   '拨打',
#   '付费',
#   '优点',
#   '方面',
#   '原因',
#   '综合',
#   '起来',
#   'IP',
#   '主叫',
#   '电话',
#   '无疑',
#   '成为',
#   '未来',
#   'IP',
#   '电话',
#   '发展',
#   '最终',
#   '方向'],
#  ['八公',
#   '小学',
#   '宣传',
#   '活动',
#   '答疑',
#   '枫阳',
#   '中学',
#   '布置',
#   '宣传',
#   '发放',
#   '宣传',
#   '材料',
#   '贵州',
#   '黄果树',
#   '瀑布',
#   '贵阳',
#   '誉为',
#   '春城',
#   '如今',
#   '林城',
#   '美名',
#   '森林',
#   '简称',
#   '贵阳市',
#   '位于',
#   '贵州省',
#   '中部',
#   '云贵高原',
#   '东斜',
#   '地带',
#   '市中心',
#   '平均',
#   '海拔',
#   '严寒',
#   '夏无',
#   '酷暑',
#   '行政区域',
#   '现有',
#   '林地',
#   '面积',
#   '森林',
#   '覆盖率',
#   '31.7%',
#   '市区',
#   '四周',
#   '群山',
#   '环抱',
#   '林木',
#   '长逾',
#   '环城',
#   '林带',
#   '贵阳市',
#   '提供',
#   '绿色',
#   '生态',
#   '屏障',
#   '投资',
#   '人民币',
#   '总长',
#   '面积',
#   '环城',
#   '林带',
#   '正在',
#   '建设',
#   '贵阳',
#   '可谓',
#   '林中之',
#   '樟树',
#   '竹子',
#   '贵阳',
#   '市树',
#   '世界',
#   '森林',
#   '以往',
#   '植树',
#   '表达',
#   '森林',
#   '重视',
#   '而今',
#   '植树',
#   '世界',
#   '森林',
#   '广泛',
#   '关注',
#   '森林',
#   '民生',
#   '更深',
#   '层次',
#   '本质',
#   '问题',
#   '国家',
#   '未来',
#   '青少年',
#   '更好',
#   '认识',
#   '身边',
#   '朋友',
#   '森林',
#   '贵州省',
#   '林科院',
#   '枫阳',
#   '中学',
#   '八公',
#   '小学',
#   '开展',
#   '世界',
#   '森林',
#   '宣传',
#   '活动',
#   '活动',
#   '既有',
#   '展示',
#   '讲解',
#   '森林',
#   '内容',
#   '有助于',
#   '森林',
#   '和谐',
#   '相处',
#   '贵州省',
#   '林科院',
#   '首批',
#   '全国',
#   '林业',
#   '基地',
#   '扎实',
#   '工作',
#   '森林',
#   '之间',
#   '架设',
#   '友谊',
#   '桥梁',
#   '相关',
#   '介绍',
#   '贵州省',
#   '地处',
#   '云贵',
#   '高原',
#   '地貌',
#   '属于',
#   '中国',
#   '西部',
#   '高原',
#   '山地',
#   '平均',
#   '海拔',
#   '面积',
#   '全国',
#   '1.8%',
#   '素有',
#   '一分田',
#   '92.5%',
#   '面积',
#   '山地',
#   '丘陵',
#   '植被',
#   '空间',
#   '分布',
#   '表现',
#   '明显',
#   '过渡性',
#   '植被',
#   '类型',
#   '地理',
#   '分布',
#   '相互',
#   '重叠',
#   '植被',
#   '类型',
#   '组合',
#   '变得',
#   '复杂',
#   '多样',
#   '贵州',
#   '位于',
#   '世界',
#   '喀斯特',
#   '三大',
#   '最大',
#   '东亚',
#   '中心',
#   '喀斯',
#   '面积',
#   '全省',
#   '国土',
#   '面积',
#   '61.9%',
#   '喀斯特',
#   '峰林',
#   '峰丛',
#   '峡谷',
#   '溶洞',
#   '洞穴',
#   '沉淀',
#   '形态',
#   '构成',
#   '绚丽',
#   '奇特',
#   '不可',
#   '再生',
#   '自然',
#   '遗产',
#   '属于',
#   '全人类',
#   '共同',
#   '财富',
#   '喀斯特地貌',
#   '多民族',
#   '聚居',
#   '贵州',
#   '具有',
#   '文化',
#   '特点',
#   '年末',
#   '全省',
#   '民族',
#   '成份',
#   '少数民族',
#   '人口',
#   '全省',
#   '总人口',
#   '37.9%',
#   '全省',
#   '动物',
#   '资源',
#   '余种',
#   '金丝猴',
#   '黑叶猴',
#   '华南虎',
#   '云豹',
#   '黑颈鹤',
#   '中华',
#   '秋沙鸭',
#   '金雕',
#   '白肩雕',
#   '白尾海',
#   '白头鹤',
#   '列为',
#   '国家',
#   '保护',
#   '动物',
#   '占全国',
#   '同类',
#   '动物',
#   '总数',
#   '13%',
#   '国家',
#   '保护',
#   '动物',
#   '穿山甲',
#   '黑熊',
#   '水獭',
#   '灵猫',
#   '小灵猫',
#   '林麝',
#   '白冠',
#   '长尾',
#   '红腹锦鸡',
#   '占全国',
#   '同类',
#   '动物',
#   '总数',
#   '25.7%',
#   '全省',
#   '珍稀',
#   '植物',
#   '列入',
#   '国家',
#   '珍稀',
#   '濒危',
#   '保护',
#   '植物',
#   '名录',
#   '银杉',
#   '珙桐',
#   '秃杉',
#   '桫椤',
#   '种属',
#   '国家',
#   '保护',
#   '植物',
#   '占全国',
#   '同类',
#   '植物',
#   '总数',
#   '50%',
#   '全省',
#   '野生植物',
#   '资源',
#   '余种',
#   '植物',
#   '资源',
#   '余种',
#   '占全国',
#   '中草药',
#   '品种',
#   '80%',
#   '全国',
#   '四大',
#   '中药材',
#   '产区',
#   '贵州',
#   '旅游',
#   '资源',
#   '丰富',
#   '闻名',
#   '世界',
#   '黄果树',
#   '瀑布',
#   '龙宫',
#   '织金',
#   '马岭河',
#   '峡谷',
#   '风景',
#   '名胜区',
#   '铜仁',
#   '梵净山',
#   '茂兰喀斯特',
#   '森林',
#   '赤水',
#   '桫椤',
#   '威宁',
#   '草海',
#   '自然保护区',
#   '犹如',
#   '璀灿',
#   '宝石',
#   '令人',
#   '目不暇接',
#   '流连忘返',
#   '自然',
#   '原因',
#   '水土',
#   '流失',
#   '问题',
#   '特别',
#   '石漠化',
#   '问题',
#   '倍受',
#   '关注',
#   '全国',
#   '土壤侵蚀',
#   '遥感',
#   '普查',
#   '全省',
#   '水土流失',
#   '面积',
#   '全省',
#   '面积',
#   '41.5%',
#   '全省',
#   '森林',
#   '面积',
#   '森林',
#   '覆盖率',
#   '24%',
#   '人均',
#   '森林',
#   '面积',
#   '森林',
#   '蓄积量',
#   '参考',
#   '资料',
#   '1',
#   '贵州省政府',
#   '2',
#   '贵阳市政府',
#   '3',
#   '国家林业局',
#   '中国林业',
#   '统计',
#   '年鉴',
#   '北京',
#   '中国林业出版社',
#   '图片',
#   '来源',
#   '1',
#   '邓伦',
#   '贵州省',
#   '林业',
#   '科学',
#   '研究院',
#   '2',
#   '中国林学会'],
#  ['摘要',
#   '中央国家机关',
#   '工会',
#   '联合会',
#   '授予',
#   '外交部领事司',
#   '农业部',
#   '兽医局',
#   '中科院',
#   '联想',
#   '集团',
#   '都灵',
#   '冬奥会',
#   '技术',
#   '保障',
#   '团队',
#   '国家',
#   '海洋局',
#   '雪龙',
#   '极地',
#   '考察',
#   '先进',
#   '集体',
#   '中央国家机关',
#   '五一劳动',
#   '奖状',
#   '中央国家机关',
#   '工会',
#   '联合会',
#   '联想',
#   '集团',
#   '召开',
#   '五一劳动',
#   '奖状',
#   '先进',
#   '集体',
#   '表彰',
#   '大会',
#   '表彰',
#   '时期',
#   '工作',
#   '岗位',
#   '做出',
#   '突出',
#   '贡献',
#   '社会上',
#   '引起',
#   '较大',
#   '反响',
#   '先进',
#   '集体',
#   '授予',
#   '外交部领事司',
#   '农业部',
#   '兽医局',
#   '中科院',
#   '联想',
#   '集团',
#   '都灵',
#   '冬奥会',
#   '技术',
#   '保障',
#   '团队',
#   '国家',
#   '海洋局',
#   '雪龙',
#   '极地',
#   '考察',
#   '先进',
#   '集体',
#   '中央国家机关',
#   '五一劳动',
#   '奖状',
#   '中央',
#   '国家机关',
#   '工委',
#   '副书记',
#   '中央国家机关',
#   '工会',
#   '联合会',
#   '主席',
#   '黄燕明',
#   '出席',
#   '大会',
#   '先进',
#   '集体',
#   '颁奖',
#   '中央',
#   '国家机关',
#   '部门',
#   '机关',
#   '工会',
#   '主席',
#   '受表彰',
#   '集体',
#   '代表',
#   '参加',
#   '表彰会',
#   '受',
#   '表彰',
#   '集体',
#   '外交部领事司',
#   '印度洋',
#   '海啸',
#   '所罗门群岛',
#   '撤侨',
#   '中国',
#   '公民',
#   '非洲',
#   '重大',
#   '事件',
#   '案件',
#   '及时',
#   '应对',
#   '妥善',
#   '处理',
#   '最大限度',
#   '保护',
#   '境外',
#   '中国',
#   '公民',
#   '法人',
#   '合法',
#   '权益',
#   '农业部',
#   '兽医局',
#   '面对',
#   '突发',
#   '致病性',
#   '禽流感',
#   '疫情',
#   '时间',
#   '组织',
#   '督察',
#   '专家组',
#   '赶赴',
#   '现场',
#   '坚决',
#   '疫情',
#   '消灭',
#   '疫点',
#   '成功',
#   '组织',
#   '研制出',
#   '疫苗',
#   '保护',
#   '人民',
#   '群众',
#   '生命',
#   '安全',
#   '中科院',
#   '联想',
#   '集团',
#   '都灵',
#   '冬奥会',
#   '技术',
#   '服务',
#   '保障',
#   '团队',
#   '恶劣',
#   '气候',
#   '条件',
#   '出色',
#   '完成',
#   '奥运会',
#   '比赛',
#   '技术',
#   '服务',
#   '保障',
#   '任务',
#   '国际上',
#   '提供',
#   '科技',
#   '服务',
#   '平台',
#   '得到',
#   '国际',
#   '奥委会',
#   '高度',
#   '赞誉',
#   '祖国',
#   '赢得',
#   '奥运',
#   '史上',
#   '具有',
#   '特殊',
#   '意义',
#   '金牌',
#   '雪龙',
#   '极地',
#   '考察',
#   '年来',
#   '先后',
#   '完成',
#   '南极',
#   '科学',
#   '考察',
#   '北极',
#   '科学',
#   '考察',
#   '任务',
#   '创下',
#   '中国',
#   '航海',
#   '史上多',
#   '纪录',
#   '探索',
#   '极地',
#   '科学',
#   '弘扬',
#   '民族',
#   '精神',
#   '维护',
#   '国家',
#   '权益',
#   '做出',
#   '突出',
#   '贡献',
#   '中央国家机关',
#   '工会',
#   '联合会',
#   '号召',
#   '中央',
#   '国家机关',
#   '职工',
#   '表彰',
#   '先进',
#   '集体',
#   '同志',
#   '榜样',
#   '认真',
#   '学习',
#   '以人为本',
#   '一心',
#   '为民',
#   '临危',
#   '受命',
#   '勇于',
#   '担当',
#   '迎难而上',
#   '锐意',
#   '创新',
#   '团结',
#   '协作',
#   '无私奉献',
#   '精益求精',
#   '争光',
#   '精神',
#   '品质',
#   '作风',
#   '主力军',
#   '和谐',
#   '小康',
#   '实现',
#   '规划',
#   '构建',
#   '社会主义',
#   '和谐',
#   '社会',
#   '做出',
#   '新的',
#   '贡献',
#   '表彰',
#   '会上',
#   '联想',
#   '集团',
#   '董事局',
#   '主席',
#   '杨元庆',
#   '颁发',
#   '全国',
#   '五一劳动奖章'],
#  ['缝纫机',
#   '电子管',
#   '收音机',
#   '飞鸽',
#   '自行车',
#   '电视机',
#   '；还有',
#   '英特尔',
#   'reg',
#   '欢跃',
#   '&#8482',
#   '技术',
#   '数字',
#   '家庭',
#   '产品',
#   '看似',
#   '毫无',
#   '关联',
#   '东西',
#   '出现',
#   '北京',
#   '艺术家',
#   '聚集地',
#   '工厂',
#   '出现',
#   '科技',
#   '艺术',
#   '完美',
#   '组合',
#   '标志着',
#   '英特尔',
#   '公司',
#   '导演',
#   '大山子',
#   '艺术节',
#   '精彩',
#   '展览',
#   '序幕',
#   '正式',
#   '拉开',
#   '看似',
#   '不同',
#   '同样',
#   '承载',
#   '心灵',
#   '美好',
#   '生活',
#   '追求',
#   '跨越',
#   '世纪',
#   '代表',
#   '年代',
#   '美好',
#   '生活',
#   '象征',
#   '家庭',
#   '用品',
#   '英特尔',
#   '中国',
#   '有限公司',
#   '举办',
#   '美好',
#   '生活',
#   '三大件',
#   '艺术展',
#   '成为',
#   '大山子',
#   '艺术节',
#   '特色',
#   '展览',
#   '三大件',
#   '不断',
#   '演变',
#   '已经',
#   '成为',
#   '中国',
#   '人民',
#   '生活',
#   '水平',
#   '不断',
#   '发展',
#   '标志',
#   '记录',
#   '追求',
#   '美好',
#   '生活',
#   '足迹',
#   '唤起',
#   '心灵',
#   '深处',
#   '家里',
#   '拥有',
#   '大件',
#   '激动',
#   '自豪',
#   '激发',
#   '未来',
#   '美好',
#   '生活',
#   '憧憬',
#   '从',
#   '上个世纪',
#   '七十年代',
#   '手表',
#   '缝纫机',
#   '自行车',
#   '八十年代',
#   '彩电',
#   '冰箱',
#   '洗衣机',
#   '九十年代',
#   '寻呼机',
#   '手机',
#   '电脑',
#   '一直',
#   '现在',
#   '房子',
#   '车子',
#   '数字',
#   '家庭',
#   '产品',
#   '三大件',
#   '一直',
#   '中国',
#   '人民',
#   '心里',
#   '情节',
#   '支撑',
#   '不断',
#   '追求',
#   '美好',
#   '生活',
#   '原动力',
#   '同三',
#   '大件',
#   '变迁',
#   '早期',
#   '奔腾',
#   'reg',
#   '迅驰',
#   '&#8482',
#   '移动',
#   '技术',
#   '一直',
#   '今天',
#   '英特尔',
#   'reg',
#   '欢跃',
#   '&#8482',
#   '技术',
#   '数字',
#   '家庭',
#   '产品',
#   '英特尔',
#   '每一次',
#   '努力',
#   '无不',
#   '伴随',
#   '迈向',
#   '美好',
#   '生活',
#   '脚步',
#   '科技',
#   '赋予',
#   '更加',
#   '精彩',
#   '生活',
#   '工作',
#   '娱乐',
#   '今天',
#   '英特尔',
#   '欢跃',
#   '技术',
#   '沙发',
#   '探索',
#   '娱乐',
#   '乐趣',
#   '轻松',
#   '游戏',
#   '数字',
#   '娱乐',
#   '王国',
#   '享受',
#   '最新',
#   '美好',
#   '生活',
#   '香醇',
#   '惬意'],
#  ['形象',
#   '战略',
#   '苏宁',
#   '重装',
#   '珠江路',
#   '体验',
#   '国际',
#   '高科技',
#   '新店',
#   '开张',
#   '重装',
#   '开业',
#   '成为',
#   '商家',
#   '固定',
#   '营销',
#   '手段',
#   '黄金周',
#   '消费',
#   '旺季',
#   '更是',
#   '商家',
#   '开业',
#   '首选',
#   '黄道吉日',
#   '形象',
#   '开业',
#   '酬宾',
#   '活动',
#   '取得',
#   '轰动',
#   '效应',
#   '成功',
#   '打开',
#   '市场',
#   '局面',
#   '改造',
#   '苏宁',
#   '珠江路',
#   '终于',
#   '掀起',
#   '盖头',
#   '常规',
#   '综合',
#   '家电',
#   '卖场',
#   '迥然不同',
#   '区别于',
#   '珠江路',
#   '普通',
#   '卖场',
#   '卖场',
#   '基础上',
#   '升级版',
#   '最大',
#   '特征',
#   '人性',
#   '设计',
#   '布局',
#   '完全',
#   '消费者',
#   '需求',
#   '出发',
#   '部分',
#   '变动',
#   '借鉴',
#   '传统',
#   '百货',
#   '连锁',
#   '卖场',
#   '优势',
#   '避免',
#   '大卖场',
#   '重复',
#   '浪费',
#   '卖场',
#   '采用',
#   '先进',
#   '信息技术',
#   '引进',
#   'ＲＰ',
#   '系统',
#   '感应',
#   '防盗',
#   '系统',
#   '消费者',
#   '充分',
#   '体验',
#   '现代',
#   '高科技',
#   '珠江路',
#   '卖场',
#   '斥资',
#   '设置',
#   'ｉｎｔｅｌ',
#   '体验',
#   '全国',
#   '体验',
#   '独此一家',
#   '网络',
#   '战略',
#   '国美',
#   '网上商城',
#   '狂飙',
#   '红眼',
#   '购物',
#   '热潮',
#   '五一',
#   '国内',
#   '电子',
#   '商务',
#   '网站',
#   '已经',
#   '摩拳擦掌',
#   '酝酿',
#   '新一轮',
#   '降价',
#   '狂潮',
#   '近来',
#   '国美',
#   '电器',
#   '全国',
#   '网上',
#   '商城',
#   '狂飙',
#   '红眼',
#   '购物',
#   '热潮',
#   '据悉',
#   '五一',
#   '前夜',
#   '国美',
#   '网上',
#   '商城',
#   '红眼',
#   '航班',
#   '再度',
#   '启航',
#   '打开',
#   '国美',
#   '电器',
#   '公司',
#   '官方',
#   '电子',
#   '商务',
#   '网站',
#   'ｗｗｗ',
#   'ｇｏｍｅ',
#   'ｏｍ',
#   'ｃｎ',
#   '全屏',
#   '广告',
#   '立即',
#   '呈现',
#   '记者',
#   '眼前',
#   '繁星',
#   '点点',
#   '黑色',
#   '夜幕',
#   '背景',
#   '购物',
#   '狂欢节',
#   '提前',
#   '揭幕',
#   '国美',
#   '电器',
#   '网站',
#   '负责人',
#   '介绍',
#   '国美',
#   '网上',
#   '商城',
#   '四月',
#   '网购',
#   '纷呈',
#   '主题',
#   '促销',
#   '活动',
#   '团购',
#   '砍价',
#   '招募',
#   '全国',
#   '网络',
#   '集采',
#   '家电',
#   '网络',
#   '套餐',
#   '手机',
#   '展销会',
#   '回馈',
#   '消费者',
#   '家电',
#   '拍卖',
#   '几乎',
#   '网络',
#   '营销',
#   '促销',
#   '项目',
#   '此起彼伏',
#   '配以',
#   '网络',
#   '媒体',
#   '搜索引擎',
#   '形式',
#   '互联网',
#   '广告',
#   '宣传',
#   '国美',
#   '网上商城',
#   '全国',
#   '销售额',
#   '增势',
#   '明显',
#   '达到',
#   '提前',
#   '透支',
#   '五一',
#   '家电',
#   '市场',
#   '份额',
#   '目的',
#   '营销',
#   '战略',
#   '永乐',
#   '推出',
#   '新人',
#   '家电',
#   '特选',
#   '套餐',
#   '本报讯',
#   '通讯员',
#   '北',
#   '似乎',
#   '吉利',
#   '年头',
#   '情侣',
#   '选择',
#   '完成',
#   '终身大事',
#   '部门',
#   '预计',
#   '今年',
#   '五一',
#   '黄金周',
#   '期间',
#   '婚庆',
#   '高峰期',
#   '家电',
#   '零售',
#   '瞄准',
#   '商机',
#   '新人',
#   '量身',
#   '新人',
#   '新家',
#   '家电',
#   '套餐',
#   '本',
#   '周末',
#   '永乐',
#   '生活',
#   '电器',
#   '隆重',
#   '推出',
#   '主题',
#   '五一',
#   '家电',
#   '品牌',
#   '全线',
#   '特卖会',
#   '底价',
#   '活动',
#   '甜蜜',
#   '奔走',
#   '家电',
#   '卖场',
#   '新婚',
#   '爱侣',
#   '打造',
#   '家电',
#   '采购',
#   '绝对',
#   '手册',
#   '活动',
#   '永乐',
#   '推出',
#   '等离子',
#   '液晶',
#   '冰洗',
#   '空调',
#   '小家电',
#   '厨卫',
#   '音响',
#   '数码',
#   '手机',
#   '品类',
#   '产品',
#   '南京',
#   '永乐',
#   '电器',
#   '卖场',
#   '开展',
#   '促销',
#   '活动',
#   '海尔',
#   '西门子',
#   '三星',
#   '松下',
#   '三星',
#   '格力',
#   '海信',
#   '伊莱克斯',
#   '大金',
#   '家电',
#   '厂商',
#   '新品',
#   '平价',
#   '销售',
#   '支持',
#   '活动',
#   '了解',
#   '全面',
#   '促销',
#   '最高',
#   '让利',
#   '幅度',
#   '部分',
#   '商品',
#   '套餐',
#   '最高',
#   '让利',
#   '让利',
#   '幅度',
#   '达到',
#   '永乐',
#   '电器',
#   '打造',
#   '实惠',
#   '诱人',
#   '活动',
#   '套餐',
#   '抢购',
#   '新品',
#   '特惠',
#   '惊喜',
#   '赠送',
#   '抽奖',
#   '参加',
#   '活动',
#   '新人',
#   '推荐',
#   '居室',
#   '必备',
#   '大小',
#   '家电',
#   '永乐',
#   '电器',
#   '相关',
#   '负责人',
#   '表示',
#   '新婚',
#   '装修',
#   '消费者',
#   '家电',
#   '销售额',
#   '永乐',
#   '总体',
#   '销售额',
#   '忙碌',
#   '新婚',
#   '家电',
#   '消费者',
#   '省心',
#   '省力',
#   '省钱',
#   '实在',
#   '三大',
#   '愿望',
#   '文化',
#   '战略',
#   '五星',
#   '举行',
#   '百年',
#   '家电',
#   '广告',
#   '黄金周',
#   '期间',
#   '南京',
#   '商家',
#   '掀起',
#   '一浪高过一浪',
#   '促销',
#   '特卖',
#   '今年',
#   '增加',
#   '较多',
#   '文化',
#   '元素',
#   '购物',
#   '消费',
#   '增添',
#   '休闲',
#   '调剂',
#   '佐料',
#   '从',
#   '五星',
#   '电器',
#   '全国',
#   '城市',
#   '卖场',
#   '黄金',
#   '位置',
#   '隆重',
#   '推出',
#   '五星',
#   '精心',
#   '准备',
#   '百年',
#   '家电',
#   '广告',
#   '集中',
#   '展示',
#   '世界',
#   '家电',
#   '广告',
#   '图片',
#   '完整',
#   '演绎',
#   '家电',
#   '产品',
#   '技术',
#   '发展',
#   '市民',
#   '艺术',
#   '盛宴',
#   '五星',
#   '特意',
#   '精心',
#   '准备',
#   '百年',
#   '家电',
#   '广告',
#   '主题',
#   '明信片',
#   '免费',
#   '馈赠',
#   '消费者',
#   '在',
#   '展出',
#   '广告',
#   '出自',
#   '欧洲',
#   '亚洲',
#   '设计师',
#   '风格各异',
#   '设计',
#   '精巧',
#   '构思',
#   '大胆',
#   '出彩',
#   '色彩',
#   '运用',
#   '值得',
#   '欣赏',
#   '价值',
#   '电器',
#   '发展史',
#   '不仅仅',
#   '一部',
#   '人类',
#   '科学技术',
#   '进步',
#   '一部',
#   '人类',
#   '文化',
#   '发展史',
#   '品牌',
#   '战略',
#   '大',
#   '一天',
#   '新增',
#   '品牌',
#   '酒香',
#   '巷子',
#   '一前',
#   '商场',
#   '营销',
#   '达到',
#   '极致',
#   '新颖',
#   '独特',
#   '花样翻新',
#   '不断',
#   '引进',
#   '品牌',
#   '商家',
#   '招徕',
#   '人气',
#   '手段',
#   '记者',
#   '大洋百货',
#   '了解到',
#   '五一',
#   '期间',
#   '一楼',
#   '美食城',
#   '新增',
#   '四大',
#   '食品',
#   '永年丰',
#   '牛肉面',
#   '麻辣烫',
#   '香竹',
#   '关东',
#   '章鱼',
#   '丸子',
#   '大洋',
#   '百货',
#   '台资',
#   '背景',
#   '新增',
#   '几大',
#   '美食',
#   '台湾',
#   '品牌',
#   '黄金周',
#   '大洋',
#   '服饰',
#   '品牌',
#   '力气',
#   '新增',
#   'ｅｒｏｍｏｄｅ',
#   '品牌',
#   '姐妹',
#   '品牌',
#   'ｏｎｌｙ',
#   '重新',
#   '改装',
#   '面积',
#   '增加',
#   '成为',
#   '华东',
#   '地区',
#   '最大',
#   '旗舰店',
#   '；大',
#   '继续',
#   '加大',
#   '职业',
#   '淑女装',
#   '品牌',
#   '力度',
#   'ｌａｎｄ',
#   '品牌',
#   '之后',
#   '引进',
#   'ｌａｎｄ',
#   '公司',
#   '旗下',
#   '小熊维尼',
#   '内衣',
#   'ｂｌｉｎ',
#   '了解',
#   '品牌',
#   '南京',
#   '独此一家',
#   '近期',
#   '华联',
#   '服饰',
#   '有限公司',
#   '品牌',
#   '脑筋',
#   '华联',
#   '女装',
#   '开辟',
#   'ＬＶ',
#   'ＩＬＬ',
#   '贝拉维拉',
#   '特惠',
#   '集中',
#   '贝位',
#   '维拉',
#   '四大',
#   '品牌',
#   'ＬＶ',
#   'ＩＬＬ',
#   '小贝',
#   'ＬＶ',
#   'ＩＬ',
#   'ＬＬ',
#   'ＴＩ',
#   '大贝',
#   'ＬＶ',
#   'ＩＬＬ',
#   'ＬＶ',
#   'ＩＬＬ',
#   'Ｔ',
#   '了解',
#   '贝拉维拉',
#   '法国',
#   '时尚',
#   '品牌',
#   '南京',
#   '金鹰',
#   '金陵',
#   '百货',
#   '专柜',
#   '市区',
#   '专卖店',
#   '特惠',
#   '形式',
#   '华联商厦',
#   '价格',
#   '战略',
#   '华诚',
#   '超市',
#   '百类',
#   '商品',
#   '降价',
#   '昨',
#   '记者',
#   '华诚',
#   '超市',
#   '获悉',
#   '五一',
#   '期间',
#   '华诚',
#   '南京',
#   '超市',
#   '社区',
#   '便利店',
#   '不同',
#   '程度',
#   '优惠',
#   '优惠',
#   '让利',
#   '幅度',
#   '据',
#   '了解',
#   '华诚',
#   '大卖场',
#   '几十',
#   '品类',
#   '百种',
#   '商品',
#   '降价',
#   '千种',
#   '商品',
#   '降价',
#   '指定',
#   '门店',
#   '消费者',
#   '机会',
#   '获赠',
#   '碧纯',
#   '饮料',
#   '指定',
#   '门店',
#   '购买',
#   '前排',
#   '大肠',
#   '荔枝',
#   '消费者',
#   '享受',
#   '方便',
#   '消费者',
#   '公司',
#   '五一',
#   '期间',
#   '消费',
#   '免费',
#   '提供',
#   '方便',
#   '塑料',
#   '具体',
#   '促销',
#   '价格',
#   '华诚',
#   '超市',
#   '店堂',
#   '海报',
#   '刊登',
#   '抱团',
#   '战略',
#   '百安居',
#   '携手',
#   '招行',
#   '首推',
#   '家装',
#   '零首付',
#   '建材',
#   '超市',
#   '老大',
#   '百安居',
#   '联手',
#   '国内',
#   '信用卡',
#   '老大',
#   '招商',
#   '银行',
#   '推出',
#   '最高',
#   '延期',
#   '分期付款',
#   '装潢',
#   '项目',
#   '百安居',
#   '成为',
#   '目前',
#   '国内',
#   '一家',
#   '提供',
#   '家装',
#   '零首付',
#   '建材',
#   '超市',
#   '据介绍',
#   '名为',
#   '家装',
#   '分期付款',
#   '业务',
#   '百安居',
#   '招商',
#   '银行',
#   '联合',
#   '推出',
#   '专门',
#   '服务',
#   '准备',
#   '进行',
#   '装修',
#   '消费者',
#   '消费者',
#   '持有',
#   '招商',
#   '银行',
#   '信用卡',
#   '百安居',
#   '装潢',
#   '中心',
#   '进行',
#   '房屋',
#   '装修',
#   '付款',
#   '享受',
#   '待遇',
#   '不用',
#   '马上',
#   '掏腰包',
#   '延期',
#   '买单',
#   '享受',
#   '最长',
#   '分期',
#   '还款',
#   '便利',
#   '购房',
#   '消费者',
#   '付款',
#   '最长',
#   '分期',
#   '还款',
#   '理想',
#   '财务',
#   '计划',
#   '极大',
#   '降低',
#   '一次性',
#   '支付',
#   '压力',
#   '增加',
#   '装修',
#   '预算',
#   '新房',
#   '装修',
#   '提升',
#   '层次',
#   '完成',
#   '装修',
#   '提前',
#   '享用',
#   '新房',
#   '记者'],
#  ['世界',
#   '许多人',
#   '超女',
#   '成名',
#   '可称',
#   '流俗',
#   '世界',
#   '反对',
#   '超女',
#   '附丽',
#   '传统',
#   '意识',
#   '话语',
#   '堪称',
#   '作伪',
#   '在',
#   '看来',
#   '反对',
#   '等量',
#   '刘忠德',
#   '先生',
#   '全国',
#   '政协',
#   '常委',
#   '教科文卫体',
#   '委员会',
#   '主任',
#   '外加',
#   '中国演出家协会',
#   '主席',
#   '头衔',
#   '反对',
#   '超女',
#   '建议',
#   '加强',
#   '管制',
#   '并不',
#   '排除',
#   '取缔',
#   '觉得',
#   '太高',
#   '超女',
#   '我',
#   '始终',
#   '超女',
#   '绝对',
#   '没有',
#   '喜欢',
#   '反证',
#   '绝不',
#   '可能',
#   '反对',
#   '超女',
#   '兴趣',
#   '吸引',
#   '眼球',
#   '吸引',
#   '吸引',
#   '创造',
#   '收视率',
#   '收视率',
#   '经济',
#   '表演',
#   '经国之',
#   '大义',
#   '无碍',
#   '文化',
#   '千秋',
#   '表演',
#   '自然',
#   '丑有好',
#   '选秀',
#   '难免',
#   '良莠不齐',
#   '社会',
#   '精神',
#   '没有',
#   '虚弱',
#   '病菌',
#   '经不起',
#   '超女',
#   '流俗',
#   '自然',
#   '宽恕',
#   '不拿',
#   '投票',
#   '再劝',
#   '身边',
#   '投票',
#   '超女',
#   '出现',
#   '时代',
#   '产物',
#   '应该',
#   '看到',
#   '现象',
#   '过去',
#   '传统',
#   '拘谨',
#   '话语',
#   '消解',
#   '过去',
#   '精英',
#   '话语',
#   '灌输',
#   '说教',
#   '转向',
#   '娱乐',
#   '精英',
#   '转向',
#   '平民',
#   '超女',
#   '市场经济',
#   '培育',
#   '为数众多',
#   '市民',
#   '阶层',
#   '产生',
#   '普遍',
#   '个体',
#   '自觉',
#   '个体',
#   '意识',
#   '之后',
#   '个人',
#   '表现',
#   '支撑',
#   '大众',
#   '娱乐',
#   '狂欢',
#   '释放',
#   '社会',
#   '娱乐',
#   '需要',
#   '迎合',
#   '个体',
#   '意识',
#   '凸现',
#   '娱乐',
#   '倾向',
#   '本质',
#   '大众',
#   '意识',
#   '旨趣',
#   '媒体',
#   '业界',
#   '人士',
#   '惊呼',
#   '受众',
#   '主导',
#   '时代',
#   '已经',
#   '来临',
#   '在',
#   '主导',
#   '之外',
#   '看见',
#   '一种',
#   '思维',
#   '模式',
#   '引导',
#   '中国',
#   '天鹅湖',
#   '新闻',
#   '发布会',
#   '刘忠德',
#   '先生',
#   '表示',
#   '应该',
#   '老百姓',
#   '接触',
#   '高雅',
#   '艺术',
#   '提高',
#   '审美',
# ...
#   '地图',
#   '服务',
#   '微软',
#   '已经',
#   '收购',
#   '一家',
#   '公司',
#   '公司',
#   '产品',
#   '利用',
#   '航拍',
#   '卫星',
#   '照片',
#   '创建',
#   '地图',
#   '微软',
#   '周四',
#   '公布',
#   '收购',
#   'Vexcel',
#   '消息',
#   '没有',
#   '公布',
#   '交易',
#   '相关',
#   '财务',
#   '资料',
#   '微软',
#   '期望',
#   'Vexcel',
#   '产品',
#   '技术',
#   '能够',
#   '强化',
#   'Windows',
#   'Live',
#   'Local',
#   '服务',
#   '用户',
#   '方便',
#   '查找',
#   '企业',
#   '显示',
#   '在线',
#   '地图',
#   'Windows',
#   'Live',
#   'Local',
#   '微软',
#   '竞争',
#   '激烈',
#   '搜索',
#   '在线',
#   '地图',
#   '市场',
#   '推出',
#   '产品',
#   '包括',
#   '微软',
#   '雅虎',
#   'Google',
#   'AOL',
#   'Ask',
#   'com',
#   '搜索',
#   '服务',
#   '提供',
#   '提供',
#   '整合',
#   '在线',
#   '地图',
#   '搜索',
#   '服务',
#   '服务',
#   '吸引',
#   '不断',
#   '增长',
#   '广告',
#   '收入',
#   '有着',
#   '强烈',
#   '兴趣',
#   '搜索',
#   '地图',
#   '服务',
#   '相当于',
#   '互联网',
#   '电话',
#   '号码',
#   '用户',
#   '查找',
#   '地区',
#   '企业',
#   '获得',
#   '行车',
#   '路线',
#   '能够',
#   '获得',
#   '客户',
#   '企业',
#   '评价',
#   '微软',
#   'Windows',
#   'Live',
#   'Local',
#   '有着',
#   '很高',
#   '期望',
#   '希望',
#   '能够',
#   '消费者',
#   '商业',
#   '用户',
#   '提供',
#   '所谓',
#   '体验'],
#  ['据',
#   '美国',
#   '太空',
#   '报道',
#   '今年',
#   '之间',
#   '73P/',
#   '瓦斯',
#   '曼-瓦赫曼',
#   '彗星',
#   '碎片',
#   '对此',
#   '美国',
#   '宇航局',
#   '科学家',
#   '反驳',
#   '碎片',
#   '不会',
#   '撞击',
#   '地球',
#   '不会',
#   '引起',
#   '海啸',
#   '生物',
#   '灭绝',
#   '灾难',
#   '美国',
#   '宇航局',
#   '科学家',
#   '之间',
#   '73P/',
#   '瓦斯',
#   '曼-瓦赫曼',
#   '彗星',
#   '接近',
#   '地球',
#   '轨道',
#   '距离',
#   '地球',
#   '最近',
#   '碎片',
#   '地球',
#   '月球',
#   '距离',
#   '多倍',
#   '根本',
#   '不会',
#   '危险',
#   '存在',
#   '科学家',
#   '提醒',
#   '利用',
#   '机会',
#   '彗星',
#   '进行',
#   '观察',
#   '科学家',
#   '预计',
#   '碎片',
#   '明亮',
#   '碎片',
#   '可能',
#   '直接',
#   '双筒',
#   '望远镜',
#   '肉眼',
#   '观察',
#   'n101'],
#  ['女尸',
#   '曾经',
#   '复活',
#   '齐齐哈尔',
#   '木乃伊',
#   '死因',
#   '之谜',
#   '女尸',
#   '曾经',
#   '复活',
#   '齐齐哈尔',
#   '木乃伊',
#   '死因',
#   '之谜',
#   '年前',
#   '齐齐哈尔',
#   '扎龙',
#   '湿地',
#   '保护',
#   '发现',
#   '神秘',
#   '木乃伊',
#   '木乃伊',
#   '保存',
#   '完整',
#   '来历',
#   '可疑',
#   '湿地',
#   '保存',
#   '木乃伊',
#   '死者',
#   '生前',
#   '究竟',
#   '经历',
#   '当时',
#   '确定',
#   '女性',
#   '身份',
#   '专家',
#   '没有',
#   '找到',
#   '更多',
#   '线索',
#   '专家',
#   '发现',
#   '蛛丝马迹',
#   '隐藏',
#   '木乃伊',
#   '身上',
#   '秘密',
#   '一一',
#   '解开',
#   '挖掘',
#   '木乃伊',
#   '保存',
#   '齐齐哈尔市',
#   '五教',
#   '道德',
#   '冬天',
#   '院子',
#   '充满',
#   '强烈',
#   '寒意',
#   '院落',
#   '杂草',
#   '看门',
#   '管理',
#   '人员',
#   '接待',
#   '记者',
#   '不禁',
#   '毛骨悚然',
#   '木乃伊',
#   '放在',
#   '院子',
#   '最大',
#   '房子',
#   '中间',
#   '管理员',
#   '木乃伊',
#   '扎龙',
#   '展览馆',
#   '后来',
#   '展览馆',
#   '经营不善',
#   '才放',
#   '五教',
#   '道德',
#   '存放',
#   '走进',
#   '房间',
#   '记者',
#   '看到',
#   '玻璃',
#   '水晶',
#   '棺材',
#   '里面',
#   '木乃伊',
#   '身高',
#   '身体',
#   '木炭',
#   '黑色',
#   '面部',
#   '表情',
#   '十分',
#   '狰狞',
#   '四肢',
#   '弯曲',
#   '大腿',
#   '之间',
#   '看到',
#   '黑色',
#   '粘连',
#   '一起',
#   '物质',
#   '管理员',
#   '介绍',
#   '得知',
#   '物质',
#   '木乃伊',
#   '生前',
#   '处理',
#   '胎盘',
#   '仔细',
#   '左手',
#   '左脚',
#   '明显',
#   '残缺',
#   '通常',
#   '看到',
#   '木乃伊',
#   '双手',
#   '合十',
#   '木乃伊',
#   '表面',
#   '似乎',
#   '剧烈',
#   '挣扎',
#   '不免',
#   '木乃伊',
#   '出现',
#   '年代',
#   '身份',
#   '经历',
#   '产生',
#   '猜测',
#   '记者',
#   '找到',
#   '齐齐哈尔市',
#   '文物',
#   '管理站',
#   '副站长',
#   '辛健',
#   '当时',
#   '发现',
#   '见证人',
#   '多年来',
#   '收集',
#   '细节',
#   '发现',
#   '木乃伊',
#   '生前',
#   '轮廓',
#   '是非',
#   '讲述',
#   '变得',
#   '清晰',
#   '起来',
#   '湿地',
#   '干尸',
#   '纯属',
#   '偶然',
#   '湿地',
#   '干尸',
#   '纯属',
#   '偶然',
#   '齐齐哈尔市',
#   '扎龙',
#   '湿地',
#   '保护',
#   '附近',
#   '扎龙',
#   '村民',
#   '修路',
#   '取土',
#   '意外',
#   '发现',
#   '一座',
#   '青砖',
#   '墓室',
#   '发现',
#   '棺材',
#   '棺材',
#   '尸体',
#   '已经',
#   '变成',
#   '木乃伊',
#   '棺材',
#   '尸体',
#   '剩下',
#   '比较',
#   '完整',
#   '头骨',
#   '扎龙',
#   '自然保护区',
#   '位于',
#   '黑龙江省',
#   '齐齐哈尔市',
#   '东南',
#   '芦苇沼泽',
#   '广袤',
#   '湖泊',
#   '星罗棋布',
#   '居住',
#   '鸟类',
#   '更是',
#   '丹顶鹤',
#   '重要',
#   '栖息地',
#   '地理',
#   '常识',
#   '扎龙',
#   '湿地',
#   '保护',
#   '空气',
#   '潮湿',
#   '容易',
#   '滋生',
#   '寄生虫',
#   '微生物',
#   '区域',
#   '棺木',
#   '尸体',
#   '应该',
#   '比较',
#   '容易',
#   '腐烂',
#   '棺木',
#   '保存',
#   '辛',
#   '介绍',
#   '发现',
#   '墓室',
#   '结构',
#   '讲究',
#   '男女',
#   '木棺',
#   '放在',
#   '西侧',
#   '东侧',
#   '中间',
#   '过道',
#   '男性',
#   '木棺',
#   '镶嵌',
#   '没有',
#   '青砖',
#   '坑里',
#   '女性',
#   '木棺',
#   '两端',
#   '中间',
#   '三道',
#   '青砖',
#   '通风',
#   '条件',
#   '很好',
#   '墓室',
#   '封闭性',
#   '很好',
#   '室内',
#   '未见',
#   '据',
#   '辛健',
#   '分析',
#   '垫起',
#   '比较',
#   '干燥',
#   '木乃伊',
#   '生前',
#   '挣扎',
#   '痕迹',
#   '可能',
#   '氧气',
#   '消耗',
#   '殆尽',
#   '留下',
#   '二氧化碳',
#   '体内',
#   '水分',
#   '消耗',
#   '腹内',
#   '器官',
#   '缓慢',
#   '干瘪',
#   '水分',
#   '迅速',
#   '消失',
#   '形成',
#   '现在',
#   '看到',
#   '木乃伊',
#   '木乃伊',
#   '真实',
#   '身份',
#   '存在',
#   '可能',
#   '保存',
#   '完整',
#   '木乃伊',
#   '生前',
#   '究竟',
#   '男',
#   '主人',
#   '官袍',
#   '一块',
#   '补子',
#   '补子',
#   '祥云',
#   '树木',
#   '花草',
#   '山岗',
#   '丘陵',
#   '金钱豹',
#   '动物',
#   '图案',
#   '相关',
#   '资料',
#   '记载',
#   '补服',
#   '武官',
#   '标志',
#   '出土',
#   '铜钱',
#   '饰物',
#   '清代',
#   '乾隆',
#   '年间',
#   '物品',
#   '辛健',
#   '推断',
#   '清代',
#   '墓葬',
#   '至少',
#   '历史',
#   '男性',
#   '干尸',
#   '一位',
#   '武官',
#   '从',
#   '墓室',
#   '结构',
#   '松动',
#   '青砖',
#   '个人',
#   '后来',
#   '合葬',
#   '一起',
#   '男性',
#   '容貌',
#   '观察',
#   '死亡',
#   '年龄',
#   '大约',
#   '之间',
#   '女性',
#   '年龄',
#   '大约',
#   '之间',
#   '推断',
#   '女性',
#   '主人',
#   '可能',
#   '男性',
#   '主人',
#   '大约',
#   '下葬',
#   '女性',
#   '木乃伊',
#   '应该',
#   '男性',
#   '主人',
#   '夫人',
#   '在',
#   '女性',
#   '棺材',
#   '发现',
#   '满文',
#   '黑龙江省',
#   '满语',
#   '研究所',
#   '研究员',
#   '黄锡会',
#   '专门',
#   '研究',
#   '满文',
#   '翻译',
#   '上面',
#   '记载',
#   '诰封',
#   '墨尔根觉罗',
#   '史料',
#   '记载',
#   '满族',
#   '姓氏',
#   '没有',
#   '墨尔根觉罗',
#   '专家',
#   '分析',
#   '确定',
#   '可能',
#   '文字',
#   '标注',
#   '祭地',
#   '赐姓',
#   '女真',
#   '一支',
#   '木乃伊',
#   '真实',
#   '姓名',
#   '无法',
#   '核实',
#   '研究',
#   '专家',
#   '叫做',
#   '孟氏',
#   '中毒',
#   '难产',
#   '中毒',
#   '难产',
#   '记载',
#   '文字',
#   '随葬品',
#   '孟氏',
#   '木乃伊',
#   '留下',
#   '费解',
#   '胎盘',
#   '胎盘',
#   '臀部',
#   '连着',
#   '胎盘',
#   '分明',
#   '看出',
#   '没有',
#   '处理',
#   '辛健',
#   '回忆说',
#   '女性',
#   '干尸',
#   '出土',
#   '主人',
#   '皮肤',
#   '发黄',
#   '头发',
#   '眉毛',
#   '清晰可见',
#   '主人',
#   '脸上',
#   '辨别',
#   '木乃伊',
#   '身上',
#   '出现',
#   '一层',
#   '黄白',
#   '相间',
#   '有点',
#   '生活',
#   '看到',
#   '芥菜',
#   '疙瘩',
#   '表面',
#   '可能',
#   '木乃伊',
#   '体内',
#   '药物',
#   '皮肤',
#   '显现',
#   '一种',
#   '出现',
#   '难道',
#   '药物',
#   '中毒',
#   '木乃伊',
#   '张大',
#   '口里',
#   '文物',
#   '专家',
#   '发现',
#   '牙齿',
#   '左右',
#   '女性',
#   '剩下',
#   '牙齿',
#   '并不',
#   '寻常',
#   '齐齐哈尔市',
#   '医学院',
#   '解剖学',
#   '专家',
#   '医师',
#   '看到',
#   '木乃伊',
#   '认为',
#   '女子',
#   '牙齿',
#   '可能',
#   '体弱多病',
#   '服用',
#   '滋补品',
#   '草药',
#   '制品',
#   '引起',
#   '药物中毒',
#   '中毒',
#   '导致',
#   '部分',
#   '牙齿松动',
#   '脱落',
#   '胎盘',
#   '医师',
#   '分析',
#   '可能',
#   '孟氏',
#   '骨盆',
#   '口角',
#   '比较',
#   '窄小',
#   '分娩',
#   '遇上',
#   '难产',
#   '小时',
#   '痛苦',
#   '拼搏',
#   '之后',
#   '孩子',
#   '终于',
#   '降生',
#   '体弱多病',
#   '再加',
#   '难产',
#   '孟氏',
#   '体力',
#   '支而',
#   '昏死',
#   '过去',
#   '当时',
#   '医疗',
#   '水平',
#   '有限',
#   '也许',
#   '孟氏',
#   '家人',
#   '昏厥',
#   '假死',
#   '认为',
#   '真正',
#   '死亡',
#   '准备',
#   '后事',
#   '造成',
#   '女子',
#   '永久性',
#   '真正',
#   '死亡',
#   '复活',
#   '女尸',
#   '曾经',
#   '复活',
#   '从',
#   '满文',
#   '证明',
#   '孟氏',
#   '满族人',
#   '满族人',
#   '丧葬',
#   '习俗',
#   '家人',
#   '喜欢',
#   '服装',
#   '头饰',
#   '手工',
#   '绣制',
#   '身上',
#   '落叶归根',
#   '故里',
#   '说法',
#   '墓地',
#   '选择',
#   '扎龙',
#   '村南',
#   '月牙形',
#   '土岗',
#   '孟氏',
#   '下葬',
#   '可能',
#   '过度',
#   '颠簸',
#   '过来',
#   '发现',
#   '躺在',
#   '棺材',
#   '用力',
#   '挣扎',
#   '无济于事',
#   '拼命',
#   '挣扎',
#   '活动',
#   '左腿',
#   '捆绑',
#   '丝带',
#   '左脚',
#   '鞋袜',
#   '脱落',
#   '脚趾',
#   '手指',
#   '击打',
#   '棺板',
#   '受伤',
#   '木乃伊',
#   '棺盖',
#   '打开',
#   '专家',
#   '发现',
#   '盖上有',
#   '明显',
#   '抓痕',
#   '左手',
#   '左脚',
#   '明显',
#   '残缺',
#   '辛健',
#   '后来',
#   '推断',
#   '皮外伤',
#   '引起',
#   '感染',
#   '导致',
#   '腐烂',
#   '造成',
#   '时间',
#   '应该',
#   '下葬',
#   '右脚',
#   '深黄色',
#   '素面',
#   '丝绢',
#   '用纸',
#   '鞋底',
#   '圆口',
#   '黑色',
#   '绣花鞋',
#   '左脚',
#   '裸露',
#   '外面',
#   '后在',
#   '棺木',
#   '底部',
#   '左侧',
#   '边角',
#   '找到',
#   '发现',
#   '丝带',
#   '松散',
#   '右腿',
#   '关节',
#   '位置',
#   '孟',
#   '肯定',
#   '答案',
#   '不解',
#   '棺木',
#   '出现',
#   '湿地',
#   '年前',
#   '扎龙',
#   '处于',
#   '政治',
#   '历史',
#   '地位',
#   '专家',
#   '认为',
#   '木乃伊',
#   '出土',
#   '研究',
#   '满族',
#   '部落',
#   '历史',
#   '文化',
#   '提供',
#   '有力',
#   '史料',
#   '目前',
#   '正作',
#   '细致',
#   '研究',
#   '希望',
#   '揭开',
#   '更多',
#   '谜团',
#   '来源',
#   '2'],
#  ['信息产业部',
#   '近日',
#   '公布',
#   '违规',
#   '移动信息',
#   '举报',
#   '电话',
#   '信息产业部',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '010-12300',
#   '北京市',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '010-68212300',
#   '地区',
#   '电信',
#   '用户',
#   '申诉',
#   '受理',
#   '中心',
#   '直辖市',
#   '省会',
#   '区号',
#   '用户',
#   '登录',
#   '信息',
#   '产业',
#   '网站',
#   'www',
#   'mii',
#   'gov',
#   'cn',
#   '进行',
#   '投诉',
#   '举报',
#   '了解',
#   '信息产业部',
#   '利用',
#   '左右',
#   '时间',
#   '全国',
#   '范围内',
#   '开展',
#   '治理',
#   '规范',
#   '信息',
#   '服务',
#   '企业',
#   '资费',
#   '收费',
#   '活动',
#   '明码',
#   '标价',
#   '信息',
#   '订购',
#   '计费',
#   '流程',
#   '收费',
#   '方式',
#   '资费',
#   '争议',
#   '处理',
#   '方面',
#   '相关',
#   '企业',
#   '进行',
#   '规范',
#   '加大',
#   '广播',
#   '电视',
#   '报纸',
#   '互联网',
#   '媒体',
#   '参与',
#   '互动',
#   '短信',
#   '规范',
#   '查处',
#   '力度'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '柯达',
#   '公司',
#   '公布',
#   '今年',
#   '季度',
#   '财报',
#   '公司',
#   '转移',
#   '数字',
#   '摄影',
#   '技术',
#   '季度',
#   '亏损',
#   '公司',
#   '季度',
#   '出现',
#   '亏损',
#   '柯达',
#   '公司',
#   '正在',
#   '考虑',
#   '出售',
#   '医疗',
#   '成像',
#   '部门',
#   '公司',
#   '股票',
#   '下跌',
#   '幅度',
#   '超过',
#   '4%',
#   '柯达',
#   '公司',
#   '表示',
#   '今年',
#   '季度',
#   '业务',
#   '重组',
#   '费用',
#   '亏损',
#   '相比之下',
#   '去年',
#   '同期',
#   '亏损',
#   '公司',
#   '销售',
#   '收入',
#   '增长',
#   '2%',
#   '达到',
#   '去年',
#   '季度',
#   '销售',
#   '收入',
#   '包括',
#   '先前',
#   '费用',
#   '柯达',
#   '公司',
#   '今年',
#   '季度',
#   '亏损',
#   '没有',
#   '达到',
#   '分析师',
#   '预期',
#   '市场',
#   '调研',
#   '机构',
#   'Thomson',
#   'Financia',
#   '公司',
#   '多数',
#   '分析',
#   '预期',
#   '柯达',
#   '公司',
#   '今年',
#   '季度',
#   '利润',
#   '胶卷',
#   '销售',
#   '迅速',
#   '下滑',
#   '打击',
#   '柯达',
#   '公司',
#   '收入',
#   '稳定',
#   '进入',
#   '数字',
#   '时代',
#   '柯达',
#   '公司',
#   '得到',
#   '安慰',
#   '今年',
#   '季度',
#   '公司',
#   '数字',
#   '部门',
#   '销售',
#   '非常',
#   '强劲',
#   '同比',
#   '增长',
#   '29%',
#   '达到',
#   '胶卷',
#   '传统',
#   '产品',
#   '化学',
#   '业务',
#   '同比',
#   '下滑',
#   '20%',
#   '去年',
#   '夏季',
#   '历史',
#   '柯达',
#   '公司',
#   '宣布',
#   '削减',
#   '员工',
#   '裁员',
#   '举措',
#   '一月',
#   '决定',
#   '最高',
#   '削减',
#   '员工',
#   '计划',
#   '柯达',
#   '公司',
#   '发言人',
#   'David',
#   'Lanzillo',
#   '表示',
#   '公司',
#   '正在',
#   '医疗',
#   '部门',
#   '进行',
#   '战略',
#   '选择',
#   '医疗',
#   '部门',
#   '包括',
#   '胶卷',
#   '医学',
#   '打印',
#   '医疗',
#   '成像',
#   '产品',
#   '服务',
#   '战略',
#   '选择',
#   '包括',
#   '经营',
#   '彻底',
#   '出售',
#   '选择',
#   '柯达',
#   '公司',
#   '医疗',
#   '部门',
#   '去年',
#   '收入',
#   '柯达',
#   '公司',
#   '首席',
#   '执行官',
#   '安东尼奥-佩雷斯',
#   'Antonio',
#   'Perez',
#   '声明',
#   '医疗',
#   '商务',
#   '数字',
#   '基础',
#   '业务',
#   '享受',
#   '强劲',
#   '增长',
#   '注意到',
#   '行业',
#   '进行',
#   '合并',
#   '有价值',
#   '资产',
#   '市场',
#   '前景',
#   '变化',
#   '目前',
#   '医疗',
#   '部门',
#   '战略',
#   '选择',
#   '进行',
#   '研究',
#   '今年',
#   '季度',
#   '柯达',
#   '公司',
#   '胶卷',
#   '照相',
#   '洗印',
#   '服务',
#   '收入',
#   '去年',
#   '同期',
#   '下滑',
#   '运作',
#   '利润',
#   '下滑',
#   '医疗',
#   '成像',
#   '销售',
#   '收入',
#   '下滑',
#   '7%',
#   '运作',
#   '利润',
#   '下滑',
#   '相比之下',
#   '图象',
#   '通信',
#   '业务',
#   '销售',
#   '收入',
#   '同比',
#   '增长',
#   '136%',
#   '达到',
#   '运作',
#   '利润',
#   '本',
#   '周四',
#   '柯达',
#   '公司',
#   '预期',
#   '今年',
#   '数字',
#   '部门',
#   '利润',
#   '增长',
#   '数字',
#   '部门',
#   '销售',
#   '收入',
#   '增长',
#   '16%',
#   '22%',
#   '在',
#   '纽约',
#   '股票',
#   '市场',
#   '柯达',
#   '公司',
#   '股票',
#   '下跌',
#   '4.2%',
#   '交易',
#   '柯达',
#   '公司',
#   '股票',
#   '之间',
#   '浮动'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '国外',
#   '媒体',
#   '报道',
#   '索尼',
#   'PlayStation3',
#   '游戏机',
#   '登场',
#   '蹒跚',
#   '殃及',
#   '全球',
#   '游戏',
#   '软件',
#   '开发商',
#   '电子',
#   '艺术',
#   '公司',
#   'EA',
#   '公司',
#   '宣布',
#   '今年',
#   '一季度',
#   '公司',
#   '去年',
#   '一季度',
#   'EA',
#   '盈利',
#   '盈利',
#   '索尼',
#   'PlayStation',
#   '定于',
#   '上市',
#   '任天堂公司',
#   '下一代',
#   '游戏机',
#   'Wii',
#   '预计',
#   '左右',
#   '上市',
#   '微软',
#   'Xbox',
#   '已经',
#   '去年',
#   '推出'],
#  ['摘要',
#   '微软',
#   '首席',
#   '执行官',
#   '鲍尔默',
#   '表示',
#   '重视',
#   '服务化',
#   '软件',
#   '微软',
#   '计划',
#   'MSN',
#   '部门',
#   '研发',
#   '预算',
#   '翻一番',
#   '天极网',
#   '消息',
#   '孙淑艳',
#   '编译',
#   '外电',
#   '报道',
#   '美国',
#   '时间',
#   '本周',
#   '微软',
#   '首席',
#   '执行官',
#   '鲍尔默',
#   '表示',
#   '重视',
#   '服务化',
#   '软件',
#   '微软',
#   '计划',
#   'MSN',
#   '部门',
#   '研发',
#   '预算',
#   '微软',
#   '公布',
#   '牺牲',
#   '利润',
#   '用于',
#   '投资',
#   '业务',
#   '领域',
#   '计划',
#   '投资者',
#   '大吃一惊',
#   '抱怨',
#   '微软',
#   'Google',
#   '雅虎',
#   '竞争',
#   '计划',
#   '缺乏',
#   '透明性',
#   '在',
#   '推广',
#   '微软',
#   '在线',
#   '广告',
#   '一次',
#   '会议',
#   '发言',
#   '鲍尔默',
#   '投资',
#   '微软',
#   '决心',
#   '成为',
#   'Web',
#   '领域',
#   '领头羊',
#   '信号',
#   '表示',
#   '公司',
#   '能够',
#   '真正',
#   '提供',
#   '消费者',
#   '广告主',
#   '要求',
#   '同步',
#   '基础设施',
#   '微软',
#   '计划',
#   'MSN',
#   '部门',
#   '研发',
#   '预算',
#   '提高',
#   '微软',
#   '计划',
#   '资本',
#   '投资',
#   '提高',
#   '鲍尔默',
#   '表示',
#   '研发',
#   '预算',
#   '达到',
#   '没有',
#   '表明',
#   '时间',
#   '框架',
#   '研发',
#   '团队',
#   '明白',
#   '优先',
#   '任务',
#   '服务化',
#   '软件'],
#  ['赛迪网',
#   '消息',
#   '高通',
#   '微软',
#   '联合',
#   '宣布',
#   '一项',
#   '合作',
#   '计划',
#   '合作',
#   '计划',
#   '微软',
#   'Windows',
#   'Mobile',
#   '操作系统',
#   '移植',
#   '高通',
#   'MSM',
#   '移动工作站',
#   '调制解调器',
#   '芯片组',
#   '据',
#   'webwire',
#   'com',
#   '网站',
#   '报道',
#   '高通',
#   '合作',
#   '设备',
#   '厂商',
#   '开发',
#   '便宜',
#   '功能',
#   '丰富',
#   '采用',
#   '微软',
#   'Windows',
#   'Mobile',
#   '操作系统',
#   '高通',
#   'MSM',
#   '芯片组',
#   '手机',
#   '缩短',
#   '厂商',
#   '产品',
#   '开发',
#   '时间',
#   '高通',
#   '高度',
#   '集成',
#   'MSM',
#   '芯片组',
#   '支持',
#   'Windows',
#   'Mobile',
#   '平台',
#   '能够',
#   '用户',
#   '运行',
#   '商业',
#   '娱乐',
#   '应用',
#   '程序',
#   '延长',
#   '电池',
#   '使用',
#   '寿命',
#   '高',
#   '负责',
#   'CDMA',
#   '技术',
#   '总裁',
#   'Sanjay',
#   'Jha',
#   '博士',
#   '高通',
#   'MSM',
#   '芯片组',
#   '支持',
#   '微软',
#   'Windows',
#   'Mobile',
#   '操作',
#   '系统',
#   '下一代',
#   '具有',
#   '诱人',
#   '外形',
#   '更轻',
#   '手机',
#   '带来',
#   '熟悉',
#   '软件',
#   '体验',
#   '客户',
#   '能够',
#   '更快',
#   '设计',
#   '成本',
#   '效率',
#   '创新',
#   '设备',
#   '发挥',
#   '融合',
#   '平台',
#   '双处理器',
#   '解决方案',
#   '优势',
#   '微软',
#   '移动',
#   '嵌入式',
#   '设备',
#   '部门',
#   '通信',
#   '行业',
#   '部门',
#   '高级',
#   '副总裁',
#   'Pieter',
#   'Knook',
#   '知道',
#   '移动',
#   '运营商',
#   '迫切',
#   '需要',
#   '使用',
#   '配置',
#   'Windows',
#   'Mobile',
#   '操作系统',
#   '设备',
#   '吸引',
#   '保留',
#   '用户',
#   '越来越',
#   '移动',
#   '用户',
#   '需要',
#   '移动',
#   '电子邮件',
#   'Office',
#   '办公',
#   '软件',
#   '功能',
#   '能够',
#   '使用',
#   '计算机',
#   '软件',
#   '熟悉',
#   '方便',
#   '高通',
#   '硬件',
#   '平台',
#   '微软',
#   '软件',
#   '能够',
#   '实现',
#   '目的',
#   '微软',
#   '高通',
#   '合作',
#   '能够',
#   '设备',
#   '厂商',
#   '移动',
#   '运营商',
#   '销售',
#   '能够',
#   '产生',
#   '更多',
#   '收入',
#   '广泛',
#   '移动',
#   '设备',
#   '微软',
#   '高通',
#   '进行',
#   '全面',
#   '整合',
#   '测试',
#   '高通',
#   '融合',
#   '平台',
#   '7XXX',
#   '系列',
#   'MSM',
#   '芯片组',
#   '支持',
#   '微软',
#   'Windows',
#   'Mobile',
#   '操作系统',
#   '高通',
#   '平台',
#   '采用',
#   '双内核',
#   '架构',
#   '配置',
#   '集成',
#   'ARM11',
#   '应用',
#   '处理器',
#   '用于',
#   '高级',
#   '性能',
#   'ARM9',
#   '调制解调器',
#   '处理器',
#   '高',
#   '计划',
#   '下半年',
#   '融合',
#   '平台',
#   'MSM',
#   '芯片组',
#   '支持',
#   '微软',
#   'Windows',
#   'Mobile',
#   '5.0',
#   '操作系统',
#   '微软',
#   '高通',
#   '融合',
#   '平台',
#   '解决方案',
#   '新的',
#   '板卡',
#   '支持',
#   '包和',
#   '接口',
#   '结合',
#   '微软',
#   '未来',
#   '版本',
#   'Windows',
#   'Mobile',
#   '平台',
#   '发布',
#   '采用',
#   '支持',
#   'Windows',
#   'Mobile',
#   '平台',
#   'MSM',
#   '解决方案',
#   '手机',
#   '预计',
#   '上市'],
#  ['据',
#   '国际',
#   '先驱',
#   '论坛报',
#   '报道',
#   '日本',
#   'NEC公司',
#   '收到',
#   '私下',
#   '举报',
#   '有一',
#   '假冒',
#   'NEC公司',
#   '假冒',
#   'NEC公司',
#   '中国',
#   '运营',
#   '似乎',
#   '日本',
#   '台湾',
#   '组织',
#   '进行',
#   '控制',
#   '调查',
#   '发现',
#   '假冒',
#   'NEC公司',
#   '开发',
#   '大约',
#   '假冒',
#   'NEC',
#   '产品',
#   '包括',
#   '家庭',
#   '娱乐',
#   '系统',
#   'MP3',
#   '播放器',
#   '电池',
#   '麦克风',
#   'DVD',
#   '播放器',
#   '模仿',
#   'NEC',
#   '产品',
#   '以外',
#   '公司',
#   '开发',
#   '产品',
#   'NEC',
#   '管辖权',
#   '之内',
#   '假冒',
#   'NEC公司',
#   '方面',
#   '象是',
#   '一家',
#   '合法',
#   '公司',
#   'NEC',
#   '品牌',
#   '名义',
#   '中国',
#   '企业',
#   '签署',
#   '制造',
#   '协议',
#   '发放',
#   '设计',
#   '授权',
#   'NEC',
#   '高级',
#   '副总裁',
#   'Fujio',
#   'Okada',
#   '表示',
#   '复杂',
#   '组织',
#   '位于',
#   '台湾',
#   '日本',
#   '组织',
#   '进行',
#   '关键性',
#   '协调',
#   '试图',
#   '完全',
#   '假冒',
#   'NEC',
#   'NEC',
#   '法律',
#   '原因',
#   '为由',
#   '拒绝',
#   '透露',
#   '罪犯',
#   '目前',
#   '难以',
#   '估计',
#   '违法',
#   '公司',
#   '出售',
#   '商品',
#   '价值',
#   '编译',
#   '搜狐',
#   'IT',
#   'Unifytruth'],
#  ['eNet',
#   '硅谷动力',
#   '消息',
#   '国外',
#   '媒体',
#   '报道',
#   '美国',
#   '零售',
#   '巨头',
#   '沃尔玛',
#   '日前',
#   '宣布',
#   '全美三',
#   '零售店',
#   '销售',
#   'DIY',
#   '电脑',
#   '消费者',
#   '自行',
#   '挑选',
#   '不同',
#   '品牌',
#   '回家',
#   '组装',
#   '心目中',
#   '理想',
#   '电脑',
#   '此前',
#   '沃尔玛',
#   '一直',
#   '销售',
#   '品牌',
#   '电脑',
#   '整机',
#   '附件',
#   '未来',
#   '消费者',
#   'DIY',
#   '柜台',
#   '购买',
#   '沃尔玛',
#   '提供',
#   '散件',
#   '包括',
#   '处理器',
#   '显示器',
#   '键盘',
#   '鼠标',
#   '一台',
#   '电脑',
#   '消费者',
#   '购物车',
#   '散件',
#   '拉走',
#   '回家',
#   '电脑',
#   '沃尔玛',
#   '去年',
#   '已经',
#   '尝试',
#   '电脑',
#   '散件',
#   '业务',
#   '连锁店',
#   '沃尔玛',
#   '发言人',
#   '斯图尔特',
#   '路透社',
#   '记者',
#   '表示',
#   '沃尔玛',
#   '全美',
#   '连锁店',
#   '销售',
#   '年底',
#   '销售',
#   '散件',
#   '连锁店',
#   '增加',
#   '路透社',
#   '分析',
#   '认为',
#   '实力',
#   '雄厚',
#   '沃尔玛',
#   '进入',
#   'DIY',
#   '电脑',
#   '领域',
#   '品牌',
#   '电脑',
#   '厂商',
#   '带来',
#   '巨大',
#   '压力',
#   '过去',
#   '沃尔玛',
#   '销售',
#   '玩具',
#   '蔬菜',
#   '专业',
#   '公司',
#   '被迫',
#   '倒闭',
#   '关门',
#   '沃尔玛',
#   '模式',
#   '戴尔',
#   '厂商',
#   '不同',
#   '戴尔',
#   '负责',
#   '攒机',
#   '市场',
#   '企业',
#   '个人',
#   '消费者',
#   '全球',
#   '零售',
#   '巨头',
#   '沃尔玛',
#   '狗食',
#   '钻石',
#   '领域',
#   '销售',
#   '冠军',
#   '电脑',
#   '领域',
#   '一直',
#   '未能',
#   '占据',
#   '重要',
#   '低位',
#   '去年',
#   '沃尔玛',
#   '联手',
#   '惠普',
#   '公司',
#   '推出',
#   '笔记本',
#   '电脑',
#   '美国',
#   '掀起',
#   '波澜',
#   '值得一提的是',
#   '沃尔玛',
#   '近来',
#   '增加',
#   '利润',
#   '高科技',
#   '产品',
#   '进货',
#   '平板',
#   '电视机',
#   '高级',
#   '时装',
#   '显然',
#   '沃尔玛',
#   '希望',
#   '消费者',
#   '购买',
#   '利润',
#   '用品',
#   '购买',
#   '奢侈品']]

# %%
sentences[0]
# Out:
# ['本报讯',
#  '记者',
#  '王京',
#  '联想',
#  'THINKPAD',
#  '近期',
#  '几乎',
#  '系列',
#  '笔记本',
#  '电脑',
#  '降价促销',
#  '最高',
#  '降幅',
#  '达到',
#  '降幅',
#  '达到',
#  '42%',
#  '记者',
#  '联想',
#  '美国',
#  '官方',
#  '网站',
#  '发现',
#  '联想',
#  '相关',
#  '人士',
#  '表示',
#  '纪念',
#  '联想',
#  '成立',
#  '美国',
#  '市场',
#  '推出',
#  '促销',
#  '产品',
#  '包括',
#  'THINKPAD',
#  'T',
#  '系列',
#  '笔记本',
#  '促销',
#  '价格战',
#  'THINK',
#  '品牌',
#  '高端',
#  '商务',
#  '路线',
#  '方向',
#  '不会',
#  '改变']

# %%
import gensim
# Create the tagged document needed for Doc2Vec
for i in range(len(sentences)):
    sentences[i] = gensim.models.doc2vec.TaggedDocument(words = sentences[i], tags = [i]) 
train_data=sentences

# %%
type(sentences)
# Out:
# list

# %% [markdown]
# 模型训练
# ```py
# model = Doc2Vec(documents = sentences, dm = 1, size = 100, window = 3, min_count = 1, iter = 10, workers = Pool()._processes)
# ```
# 参数说明
# * documents: training data (has to be iterable TaggedDocument instances)
# * size: 向量的维度
# * dm: 1 PV-DM, 0 PV-DBOW
# * window: 上下文词语离当前词语的最大距离
# * min_count: 词频小于min_count的词会被忽略
# * iter: 在整个语料上的迭代次数(epochs)，推荐10到20
# * workers: number of worker threads to train

# %%
# Init the Doc2Vec model
model = gensim.models.doc2vec.Doc2Vec(dm=1, size=100, window=5, min_count=2, workers=4)

# Build the Volabulary
model.build_vocab(sentences)

# Train the Doc2Vec model
model.train(sentences, total_examples=model.corpus_count, epochs=5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\doc2vec.py:580: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
# 与标签‘0’最相似的
model.docvecs.most_similar(0)
# Out:
# [(123, 0.9938210248947144),
#  (198, 0.9937419891357422),
#  (34, 0.9937158823013306),
#  (142, 0.9935526847839355),
#  (28, 0.9935396313667297),
#  (73, 0.9935389757156372),
#  (118, 0.9934990406036377),
#  (13, 0.9934804439544678),
#  (196, 0.9934653043746948),
#  (112, 0.9934574961662292)]

# %%
# 进行相关性比较
model.docvecs.similarity(0,2)
# Out:
# 0.99245334

# %%
# 输出标签为‘0’句子的向量
model.docvecs[0]
# Out:
# array([ 8.47692415e-03, -5.72356349e-03, -1.33544700e-02, -9.71434265e-03,
#        -5.76193165e-03,  1.55212674e-02,  1.67094283e-02, -7.87180557e-04,
#        -1.75144132e-02, -2.30682592e-04,  1.02153644e-02, -9.31500457e-04,
#        -6.03267252e-02,  4.28329669e-02,  2.23814696e-02, -2.74674296e-02,
#        -2.81390324e-02, -1.34990746e-02, -1.88973173e-02, -1.78640764e-02,
#        -2.14541499e-02, -1.77538954e-02,  2.65041683e-02,  2.09890604e-05,
#        -2.06341520e-02, -8.08069482e-03,  1.58628321e-03,  2.99699288e-02,
#         2.19879672e-02,  5.02292961e-02, -3.25703025e-02, -1.95940338e-05,
#        -5.34596182e-02, -2.14272812e-02, -3.04102257e-04, -8.49840324e-03,
#        -3.55653698e-03, -2.86286250e-02, -4.96886931e-02, -1.47072719e-02,
#         4.41317447e-02,  3.20917889e-02, -1.28480755e-02,  4.28970810e-03,
#        -4.83294800e-02, -2.44745128e-02,  1.03392766e-03, -1.20740533e-02,
#        -1.42332725e-02, -2.30670664e-02, -1.01170214e-02,  7.17609236e-03,
#         1.70315132e-02, -2.49684192e-02, -7.73219019e-03,  3.02876160e-02,
#        -4.30409499e-02,  1.21190550e-03,  1.72342341e-02, -1.08242128e-02,
#         2.15090979e-02, -1.03071285e-02, -1.97118074e-02,  1.54874241e-02,
#         8.28586332e-03,  3.01247984e-02,  2.22114529e-02, -4.29999344e-02,
#        -6.41033659e-03,  2.13247165e-02, -5.08395024e-04, -1.16506510e-03,
#         1.03048217e-02,  6.63105678e-03,  1.18750858e-03,  1.05208522e-02,
#         6.83853915e-03, -3.38718258e-02, -1.13679375e-02, -2.00950764e-02,
#         0.19886343, -0.11879745, -0.21870501,  0.18406904,  0.0334943 ,
#         0.296223  ,  0.19541647, -0.41524127, -0.09041841,  0.19069591,
#         0.03861274,  0.0019743 ,  0.0729991 ,  0.02599322,  0.01976608,
#         0.14876896,  0.02833349, -0.31278118, -0.15525122, -0.19381312,
#         0.17848021, -0.036528  ,  0.19714507, -0.02154064, -0.46863303,
#        -0.16735676, -0.06152235,  0.324895  , -0.2355245 , -0.22272134,
#        -0.4550202 , -0.36031803, -0.08379163, -0.4696229 , -0.52468646,
#         0.1316993 ,  0.14141077, -0.2770265 ,  0.006664  ,  0.17207418],
#       dtype=float32)

# %% [markdown]
# ## 6.案例实践
# #### 电商产品评论数据情感分析
#
# * 随着网上购物越来越流行，人们对于网上购物的需求变得越来越高，这让京东、淘宝等电商平台得到了很大的发展机遇。在这种电商平台激烈竞争的大背景下，除了提高商品质量、压低商品价格外，了解更多消费者的心声对于电商平台来说也变得越来越有必要，其中非常重要的方式就是对消费者的文本评论数据进行内在信息的数据挖掘分析，有利于对应商品的生产厂家自身竞争力的提升。
# *  针对京东商城上“美的”品牌的热水器的消费者的文本评论数据，在对文本进行基本的机器预处理、中文分词、停用词过滤后，通过建立包括栈式自编码深度学习、语义网络与LDA主题模型等多种数据挖掘模型，实现对文本评论数据的倾向性判断以及所隐藏的信息挖掘并分析，以期望得到有价值的内在内容。
#
# ### 数据文件
# * 京东用户评论数据
#
# ### 本节任务
#
# 对京东平台上的热水器评论进行文本挖掘分析
# * 分析某一品牌热水器的用户情感倾向
# * 从评论文本中挖掘出该品牌热水器的优点与不足

# %%
import jieba
import pandas as pd
from gensim import corpora, models
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-61-ee17344aa279> in <module>
# ----> 1 import jieba
#       2 import pandas as pd
#       3 from gensim import corpora, models
#
# ModuleNotFoundError: No module named 'jieba'

# %% [markdown]
# ### 1.提取评论数据
#
# 将品牌为“美的”的评论一列抽取，另存为meidi_jd.txt，编码为UTF-8

# %%
inputfile = "data/huizong.csv"
outputfile = "data/meidi_jd.txt"
data = pd.read_csv(inputfile, encoding="utf-8")
data = data[[u"评论"]][data[u"品牌"] == u"美的"]
data.to_csv(outputfile, index=False, header=False, encoding="utf8")

# %%
data

# %% [markdown]
# ### 2.评论预处理
# * 取到文本后，首先要进行文本评论数据的预处理。文本评论数据里存在大量价值含量很低甚至没有价值含量的条目，如果将这些评论数据也引入进行分词、词频统计乃至情感分析等，必然会对分析造成很大的影响，得到的结果的质量也必然是存在问题的。那么，在利用这些文本评论数据之前就必须先进行文本预处理，把大量的此类无价值含量的评论去除。
# * 文本评论数据的预处理主要由3个部分组成：文本去重、机械压缩去词以及短句删除。

# %% [markdown]
# #### 删除重复评论

# %%
inputfile = "data/meidi_jd.txt"
outputfile = "data/meidi_jd_process_1.txt"
data = pd.read_csv(inputfile, encoding="utf8", header=None)
l1 = len(data)

data = pd.DataFrame(data[0].unique())
l2 = len(data)
data.to_csv(outputfile, index=False, header=False, encoding="utf8")
print(u"删除了%s条评论" % (l1 - l2))

# %% [markdown]
# #### 删除前缀评分
# 利用正则去除一些数据

# %%
inputfile1 = u"data/meidi_jd_process_end_负面情感结果.txt"
inputfile2 = u"data/meidi_jd_process_end_正面情感结果.txt"
outputfile1 = "data/meidi_jd_neg.txt"
outputfile2 = "data/meidi_jd_pos.txt"

data1 = pd.read_csv(inputfile1, encoding="utf8", header=None)
data2 = pd.read_csv(inputfile2, encoding="utf8", header=None)
data1.head()

# %%
data1 = pd.DataFrame(data1[0].str.replace(".*?\d+?\\t ", ""))
data2 = pd.DataFrame(data2[0].str.replace(".*?\d+?\\t ", ""))

data1.to_csv(outputfile1, index=False, header=False, encoding="utf8")
data2.to_csv(outputfile2, index=False, header=False, encoding="utf8")
data1.head()

# %% [markdown]
# #### 分词
# 使用jieba分词

# %%
inputfile1 = "data/meidi_jd_neg.txt"
inputfile2 = "data/meidi_jd_pos.txt"
outputfile1 = "data/meidi_jd_neg_cut.txt"
outputfile2 = "data/meidi_jd_pos_cut.txt"

data1 = pd.read_csv(inputfile1, encoding="utf8", header=None)
data2 = pd.read_csv(inputfile2, encoding="utf8", header=None)

def mycut(s): return " ".join(jieba.cut(s))

data1 = data1[0].apply(mycut)
data2 = data2[0].apply(mycut)

data1.to_csv(outputfile1, index=False, header=False, encoding="utf8")
data2.to_csv(outputfile2, index=False, header=False, encoding="utf8")

# %% [markdown]
# ### 3.评论数据分析

# %% [markdown]
# #### LDA
# 分词之后的语义分析，LDA模型分析正面负面情感

# %%
negfile = "data/meidi_jd_neg_cut.txt"
posfile = "data/meidi_jd_pos_cut.txt"
stoplist = "data/stoplist.txt"

neg = pd.read_csv(negfile, encoding="utf8", header=None)
pos = pd.read_csv(posfile, encoding="utf8", header=None)
"""
sep设置分割词，由于csv默认半角逗号为分割词，而且该词恰好位于停用词表中
所以会导致读取错误
解决办法是手动设置一个不存在的分割词，这里使用的是tipdm
参数engine加上，指定引擎，避免警告
"""
stop = pd.read_csv(stoplist, encoding="utf8", header=None, sep="tipdm", engine="python")

# pandas自动过滤了空格，这里手动添加
stop = [" ", ""] + list(stop[0])

# 定义分割函数，然后用apply进行广播， 去掉停用词
neg[1] = neg[0].apply(lambda s: s.split(" "))
neg[2] = neg[1].apply(lambda x: [i for i in x if i not in stop])
pos[1] = pos[0].apply(lambda s: s.split(" "))
pos[2] = pos[1].apply(lambda x: [i for i in x if i not in stop])

neg

# %%
# 负面主题分析
# 建立词典
neg_dict = corpora.Dictionary(neg[2]) #词袋模型，将每个单词编码为整数
# 建立语料库
neg_corpus = [neg_dict.doc2bow(i) for i in neg[2]]  # bag of word 词袋模型编码
# LDA模型训练
neg_lda = models.LdaModel(neg_corpus, num_topics=3, id2word=neg_dict)

for i in range(3):
    print(neg_lda.print_topic(i))  #输出一个主题

# %%
# 正面主题分析
# 以下同上
pos_dict = corpora.Dictionary(pos[2])
pos_corpus = [pos_dict.doc2bow(i) for i in pos[2]]
pos_lda = models.LdaModel(pos_corpus, num_topics=3, id2word=pos_dict)

for i in range(3):
    print(pos_lda.print_topic(i))

# %% [markdown]
# # Any Questions?
